# %% [markdown]
# discovering the Higgs boson
# This notebook uses ATLAS Open Data http://opendata.atlas.cern to show you the steps to rediscover the Higgs boson
#
# ATLAS Open Data provides open access to proton-proton collision data at the LHC for educational purposes. ATLAS Open Data resources are ideal for students.
#
#
# The idea is that cuts increase the ratio of signal ($H \rightarrow ZZ \rightarrow \ell\ell\ell\ell$) to background ($Z, t\bar{t}, ZZ \rightarrow \ell\ell\ell\ell$)
#
# First, the amount of $Z$ and $t\bar{t}$ background is reduced, since these are quite different to the signal.
#
# Then, the amount of $ZZ \rightarrow \ell\ell\ell\ell$ is reduced, whilst keeping as much $H \rightarrow ZZ \rightarrow \ell\ell\ell\ell$ signal as possible.
#
# The datasets used in this notebook have already been filtered to include at least 4 leptons per event, so that processing is quicker.

# %% [markdown]
# <a id='contents'></a>

# %% [markdown]
# <a id='running'></a>

# %% [markdown]
# <a id='setup_computer'></a>

# %%
import sys
# update the pip package installer
# !{sys.executable} -m pip install --upgrade --user pip
# install required packages
# !{sys.executable} -m pip install --upgrade --user uproot awkward vector numpy matplotlib
# Out:
# Requirement already satisfied: pip in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (23.2.1)
# Requirement already satisfied: uproot in c:\users\root_vincent\appdata\roaming\python\python39\site-packages (5.0.11)
# Requirement already satisfied: awkward in c:\users\root_vincent\appdata\roaming\python\python39\site-packages (2.3.3)
# Requirement already satisfied: vector in c:\users\root_vincent\appdata\roaming\python\python39\site-packages (1.1.0)
# Requirement already satisfied: numpy in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (1.25.2)
# Requirement already satisfied: matplotlib in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (3.7.2)
# Requirement already satisfied: packaging in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (from uproot) (23.1)
# Requirement already satisfied: awkward-cpp==22 in c:\users\root_vincent\appdata\roaming\python\python39\site-packages (from awkward) (22)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (from awkward) (4.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (6.0.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.16.2)
# Requirement already satisfied: six>=1.5 in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# <a id='setup_everytime'></a>

# %%
import uproot # for reading .root files
import awkward as ak # to represent nested data in columnar format
import vector # for 4-momentum calculations
import time # to measure time to analyse
import math # for mathematical functions such as square root
import numpy as np # for numerical calculations such as histogramming
import matplotlib.pyplot as plt # for plotting
from matplotlib.ticker import AutoMinorLocator # for minor ticks

import infofile # local file containing cross-sections, sums of weights, dataset IDs

# %% [markdown]
# <a id='fraction'></a>

# %%
lumi = 10 

fraction = 1.0                                                                                                                                  
 
tuple_path = "https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/4lep/"

# %% [markdown]
# <a id='samples'></a>

# %% [markdown]
# samples processing

# %%
samples = {

    'data': {
        'list' : ['data_A','data_B','data_C','data_D'],
    },

    r'Background $Z,t\bar{t}$' : { # Z + ttbar
        'list' : ['Zee','Zmumu','ttbar_lep'],
        'color' : "#6b59d3" # purple
    },

    r'Background $ZZ^*$' : { # ZZ
        'list' : ['llll'],
        'color' : "#ff0000" # red
    },

    r'Signal ($m_H$ = 125 GeV)' : { # H -> ZZ -> llll
        'list' : ['ggH125_ZZ4lep','VBFH125_ZZ4lep','WH125_ZZ4lep','ZH125_ZZ4lep'],
        'color' : "#00cdff" # light blue
    },

}

# %% [markdown]
# Units, as stored in the data files

# %%
MeV = 0.001
GeV = 1.0

# %% [markdown]
# Define function to get data from files.
#
# The datasets used in this notebook have already been filtered to include at least 4 leptons per event, so that processing is quicker.

# %%
def get_data_from_files():

    data = {} # define empty dictionary to hold awkward arrays
    for s in samples: # loop over samples
        print('Processing '+s+' samples') # print which sample
        frames = [] # define empty list to hold data
        for val in samples[s]['list']: # loop over each file
            if s == 'data': prefix = "Data/" # Data prefix
            else: # MC prefix
                prefix = "MC/mc_"+str(infofile.infos[val]["DSID"])+"."
            fileString = tuple_path+prefix+val+".4lep.root" # file name to open
            temp = read_file(fileString,val) # call the function read_file defined below
            frames.append(temp) # append array returned from read_file to list of awkward arrays
        data[s] = ak.concatenate(frames) # dictionary entry is concatenated awkward arrays
    
    return data # return dictionary of awkward arrays

# %% [markdown]
# define function to calculate weight of MC event

# %%
def calc_weight(xsec_weight, events):
    return (
        xsec_weight
        * events.mcWeight
        * events.scaleFactor_PILEUP
        * events.scaleFactor_ELE
        * events.scaleFactor_MUON 
        * events.scaleFactor_LepTRIGGER
    )

# %% [markdown]
# define function to get cross-section weight

# %%
def get_xsec_weight(sample):
    info = infofile.infos[sample] # open infofile
    xsec_weight = (lumi*1000*info["xsec"])/(info["sumw"]*info["red_eff"]) #*1000 to go from fb-1 to pb-1
    return xsec_weight # return cross-section weight

# %% [markdown]
# define function to calculate 4-lepton invariant mass.
#
# Note: `lep_(pt|eta|phi|E)` are variable length lists of lepton momentum components for each event, represented by awkward arrays.

# %%
def calc_mllll(lep_pt, lep_eta, lep_phi, lep_E):
    # construct awkward 4-vector array
    p4 = vector.zip({"pt": lep_pt, "eta": lep_eta, "phi": lep_phi, "E": lep_E})
    # calculate invariant mass of first 4 leptons
    # [:, i] selects the i-th lepton in each event
    # .M calculates the invariant mass
    return (p4[:, 0] + p4[:, 1] + p4[:, 2] + p4[:, 3]).M * MeV

# %% [markdown]
# <a id='changing_cut'></a>

# %%
# cut on lepton charge
# paper: "selecting two pairs of isolated leptons, each of which is comprised of two leptons with the same flavour and opposite charge"
def cut_lep_charge(lep_charge):
# throw away when sum of lepton charges is not equal to 0
# first lepton in each event is [:, 0], 2nd lepton is [:, 1] etc
    return lep_charge[:, 0] + lep_charge[:, 1] + lep_charge[:, 2] + lep_charge[:, 3] != 0

# cut on lepton type
# paper: "selecting two pairs of isolated leptons, each of which is comprised of two leptons with the same flavour and opposite charge"
def cut_lep_type(lep_type):
# for an electron lep_type is 11
# for a muon lep_type is 13
# throw away when none of eeee, mumumumu, eemumu
    sum_lep_type = lep_type[:, 0] + lep_type[:, 1] + lep_type[:, 2] + lep_type[:, 3]
    return (sum_lep_type != 44) & (sum_lep_type != 48) & (sum_lep_type != 52)

# %% [markdown]
# <a id='applying_cut'></a>

# %%
def read_file(path,sample):
    start = time.time() # start the clock
    print("\tProcessing: "+sample) # print which sample is being processed
    data_all = [] # define empty list to hold all data for this sample
    
    # open the tree called mini using a context manager (will automatically close files/resources)
    with uproot.open(path + ":mini") as tree:
        numevents = tree.num_entries # number of events
        if 'data' not in sample: xsec_weight = get_xsec_weight(sample) # get cross-section weight
        for data in tree.iterate(['lep_pt','lep_eta','lep_phi',
                                  'lep_E','lep_charge','lep_type', 
                                  # add more variables here if you make cuts on them 
                                  'mcWeight','scaleFactor_PILEUP',
                                  'scaleFactor_ELE','scaleFactor_MUON',
                                  'scaleFactor_LepTRIGGER'], # variables to calculate Monte Carlo weight
                                 library="ak", # choose output type as awkward array
                                 entry_stop=numevents*fraction): # process up to numevents*fraction

            nIn = len(data) # number of events in this batch

            if 'data' not in sample: # only do this for Monte Carlo simulation files
                # multiply all Monte Carlo weights and scale factors together to give total weight
                data['totalWeight'] = calc_weight(xsec_weight, data)

            # cut on lepton charge using the function cut_lep_charge defined above
            data = data[~cut_lep_charge(data.lep_charge)]

            # cut on lepton type using the function cut_lep_type defined above
            data = data[~cut_lep_type(data.lep_type)]

            # calculation of 4-lepton invariant mass using the function calc_mllll defined above
            data['mllll'] = calc_mllll(data.lep_pt, data.lep_eta, data.lep_phi, data.lep_E)

            # array contents can be printed at any stage like this
            #print(data)

            # array column can be printed at any stage like this
            #print(data['lep_pt'])

            # multiple array columns can be printed at any stage like this
            #print(data[['lep_pt','lep_eta']])

            nOut = len(data) # number of events passing cuts in this batch
            data_all.append(data) # append array from this batch
            elapsed = time.time() - start # time taken to process
            print("\t\t nIn: "+str(nIn)+",\t nOut: \t"+str(nOut)+"\t in "+str(round(elapsed,1))+"s") # events before and after
    
    return ak.concatenate(data_all) # return array containing events passing all cuts

# %% [markdown]
# This is where the processing happens

# %%
start = time.time() # time at start of whole processing
data = get_data_from_files() # process all files
elapsed = time.time() - start # time after whole processing
print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
# Out:
# Processing data samples
# 	Processing: data_A
# 		 nIn: 1,	 nOut: 	0	 in 20.2s
# 		 nIn: 1,	 nOut: 	1	 in 21.3s
# 		 nIn: 1,	 nOut: 	1	 in 21.5s
# 		 nIn: 1,	 nOut: 	0	 in 21.7s
# 		 nIn: 1,	 nOut: 	1	 in 21.9s
# 		 nIn: 1,	 nOut: 	1	 in 22.3s
# 		 nIn: 1,	 nOut: 	0	 in 22.4s
# 		 nIn: 1,	 nOut: 	1	 in 22.8s
# 		 nIn: 1,	 nOut: 	1	 in 23.0s
# 		 nIn: 1,	 nOut: 	1	 in 23.1s
# 		 nIn: 1,	 nOut: 	0	 in 23.3s
# 		 nIn: 1,	 nOut: 	0	 in 23.5s
# 		 nIn: 1,	 nOut: 	0	 in 23.7s
# 		 nIn: 1,	 nOut: 	0	 in 23.8s
# 		 nIn: 1,	 nOut: 	1	 in 24.0s
# 		 nIn: 1,	 nOut: 	1	 in 24.2s
# 		 nIn: 1,	 nOut: 	1	 in 24.4s
# 		 nIn: 1,	 nOut: 	1	 in 24.5s
# 		 nIn: 1,	 nOut: 	1	 in 24.7s
# 		 nIn: 1,	 nOut: 	1	 in 24.9s
# 		 nIn: 1,	 nOut: 	1	 in 25.1s
# 		 nIn: 1,	 nOut: 	1	 in 25.2s
# 		 nIn: 1,	 nOut: 	1	 in 25.4s
# 		 nIn: 1,	 nOut: 	1	 in 25.6s
# 		 nIn: 1,	 nOut: 	1	 in 25.8s
# 		 nIn: 1,	 nOut: 	1	 in 25.9s
# 		 nIn: 1,	 nOut: 	0	 in 26.1s
# 		 nIn: 1,	 nOut: 	1	 in 26.3s
# 		 nIn: 1,	 nOut: 	0	 in 26.4s
# 		 nIn: 1,	 nOut: 	1	 in 26.6s
# 		 nIn: 1,	 nOut: 	1	 in 26.8s
# 		 nIn: 1,	 nOut: 	0	 in 27.0s
# 		 nIn: 1,	 nOut: 	0	 in 27.2s
# 		 nIn: 1,	 nOut: 	1	 in 27.4s
# 		 nIn: 1,	 nOut: 	1	 in 27.6s
# 		 nIn: 1,	 nOut: 	1	 in 27.8s
# 		 nIn: 1,	 nOut: 	1	 in 28.0s
# 		 nIn: 1,	 nOut: 	1	 in 28.1s
# 		 nIn: 1,	 nOut: 	0	 in 28.3s
# 	Processing: data_B
# 		 nIn: 1,	 nOut: 	1	 in 11.1s
# 		 nIn: 1,	 nOut: 	1	 in 11.9s
# 		 nIn: 1,	 nOut: 	1	 in 12.1s
# 		 nIn: 1,	 nOut: 	0	 in 12.3s
# 		 nIn: 1,	 nOut: 	0	 in 12.5s
# 		 nIn: 1,	 nOut: 	0	 in 12.6s
# 		 nIn: 1,	 nOut: 	1	 in 12.8s
# 		 nIn: 1,	 nOut: 	1	 in 12.9s
# 		 nIn: 1,	 nOut: 	0	 in 13.2s
# 		 nIn: 1,	 nOut: 	1	 in 13.3s
# 		 nIn: 1,	 nOut: 	1	 in 13.5s
# 		 nIn: 1,	 nOut: 	0	 in 13.8s
# 		 nIn: 1,	 nOut: 	1	 in 13.9s
# 		 nIn: 1,	 nOut: 	0	 in 14.1s
# 		 nIn: 1,	 nOut: 	0	 in 14.3s
# 		 nIn: 1,	 nOut: 	0	 in 14.4s
# 		 nIn: 1,	 nOut: 	0	 in 14.6s
# 		 nIn: 1,	 nOut: 	1	 in 14.8s
# 		 nIn: 1,	 nOut: 	1	 in 15.0s
# 		 nIn: 1,	 nOut: 	0	 in 15.1s
# 		 nIn: 1,	 nOut: 	1	 in 15.3s
# 		 nIn: 1,	 nOut: 	0	 in 15.5s
# 		 nIn: 1,	 nOut: 	0	 in 15.8s
# 		 nIn: 1,	 nOut: 	1	 in 16.1s
# 		 nIn: 1,	 nOut: 	1	 in 16.3s
# 		 nIn: 1,	 nOut: 	0	 in 16.5s
# 		 nIn: 1,	 nOut: 	0	 in 16.7s
# 		 nIn: 1,	 nOut: 	1	 in 16.8s
# 		 nIn: 1,	 nOut: 	1	 in 17.1s
# 		 nIn: 1,	 nOut: 	0	 in 17.4s
# 		 nIn: 1,	 nOut: 	1	 in 17.6s
# 		 nIn: 1,	 nOut: 	1	 in 17.8s
# 		 nIn: 1,	 nOut: 	0	 in 18.0s
# 		 nIn: 1,	 nOut: 	1	 in 18.2s
# 		 nIn: 1,	 nOut: 	1	 in 18.6s
# 		 nIn: 1,	 nOut: 	1	 in 18.8s
# 		 nIn: 1,	 nOut: 	1	 in 19.1s
# 		 nIn: 1,	 nOut: 	0	 in 19.4s
# 		 nIn: 1,	 nOut: 	0	 in 19.7s
# 		 nIn: 1,	 nOut: 	1	 in 20.0s
# 		 nIn: 1,	 nOut: 	1	 in 20.2s
# 		 nIn: 1,	 nOut: 	1	 in 20.4s
# 		 nIn: 1,	 nOut: 	0	 in 20.7s
# 		 nIn: 1,	 nOut: 	1	 in 21.1s
# 		 nIn: 1,	 nOut: 	0	 in 21.3s
# 		 nIn: 1,	 nOut: 	1	 in 21.6s
# 		 nIn: 1,	 nOut: 	0	 in 21.9s
# 		 nIn: 1,	 nOut: 	1	 in 22.1s
# 		 nIn: 1,	 nOut: 	0	 in 22.3s
# 		 nIn: 1,	 nOut: 	1	 in 22.5s
# 		 nIn: 1,	 nOut: 	0	 in 22.7s
# 		 nIn: 1,	 nOut: 	0	 in 22.8s
# 		 nIn: 1,	 nOut: 	0	 in 23.0s
# 		 nIn: 1,	 nOut: 	1	 in 23.3s
# 		 nIn: 1,	 nOut: 	0	 in 23.5s
# 		 nIn: 1,	 nOut: 	1	 in 23.7s
# 		 nIn: 1,	 nOut: 	0	 in 23.8s
# 		 nIn: 1,	 nOut: 	0	 in 24.0s
# 		 nIn: 1,	 nOut: 	0	 in 24.2s
# 		 nIn: 1,	 nOut: 	0	 in 24.4s
# 		 nIn: 1,	 nOut: 	1	 in 24.5s
# 		 nIn: 1,	 nOut: 	0	 in 24.7s
# 		 nIn: 1,	 nOut: 	1	 in 25.0s
# 		 nIn: 1,	 nOut: 	1	 in 25.5s
# 		 nIn: 1,	 nOut: 	1	 in 25.8s
# 		 nIn: 1,	 nOut: 	0	 in 26.1s
# 		 nIn: 1,	 nOut: 	1	 in 26.4s
# 		 nIn: 1,	 nOut: 	1	 in 26.7s
# 		 nIn: 1,	 nOut: 	1	 in 26.9s
# 		 nIn: 1,	 nOut: 	1	 in 27.3s
# 		 nIn: 1,	 nOut: 	0	 in 27.6s
# 		 nIn: 1,	 nOut: 	0	 in 28.0s
# 		 nIn: 1,	 nOut: 	1	 in 28.4s
# 		 nIn: 1,	 nOut: 	1	 in 28.5s
# 		 nIn: 1,	 nOut: 	1	 in 28.7s
# 		 nIn: 1,	 nOut: 	1	 in 28.9s
# 		 nIn: 1,	 nOut: 	1	 in 29.2s
# 		 nIn: 1,	 nOut: 	1	 in 29.5s
# 		 nIn: 1,	 nOut: 	0	 in 29.6s
# 		 nIn: 1,	 nOut: 	0	 in 29.8s
# 		 nIn: 1,	 nOut: 	0	 in 30.1s
# 		 nIn: 1,	 nOut: 	0	 in 30.4s
# 		 nIn: 1,	 nOut: 	0	 in 30.5s
# 		 nIn: 1,	 nOut: 	0	 in 30.8s
# 		 nIn: 1,	 nOut: 	0	 in 31.1s
# 		 nIn: 1,	 nOut: 	1	 in 31.3s
# 		 nIn: 1,	 nOut: 	1	 in 31.5s
# 		 nIn: 1,	 nOut: 	0	 in 31.7s
# 		 nIn: 1,	 nOut: 	1	 in 31.9s
# 		 nIn: 1,	 nOut: 	0	 in 32.1s
# 		 nIn: 1,	 nOut: 	1	 in 32.2s
# 		 nIn: 1,	 nOut: 	1	 in 32.5s
# 		 nIn: 1,	 nOut: 	0	 in 32.8s
# 		 nIn: 1,	 nOut: 	0	 in 33.2s
# 		 nIn: 1,	 nOut: 	1	 in 33.4s
# 		 nIn: 1,	 nOut: 	0	 in 33.6s
# 		 nIn: 1,	 nOut: 	0	 in 33.8s
# 		 nIn: 1,	 nOut: 	0	 in 34.0s
# 		 nIn: 1,	 nOut: 	1	 in 34.1s
# 		 nIn: 1,	 nOut: 	0	 in 34.3s
# 		 nIn: 1,	 nOut: 	0	 in 34.5s
# 		 nIn: 1,	 nOut: 	1	 in 34.7s
# 		 nIn: 1,	 nOut: 	1	 in 34.9s
# 		 nIn: 1,	 nOut: 	1	 in 35.2s
# 		 nIn: 1,	 nOut: 	0	 in 35.4s
# 		 nIn: 1,	 nOut: 	1	 in 35.6s
# 		 nIn: 1,	 nOut: 	1	 in 36.1s
# 		 nIn: 1,	 nOut: 	1	 in 36.4s
# 		 nIn: 1,	 nOut: 	0	 in 36.6s
# 		 nIn: 1,	 nOut: 	1	 in 36.9s
# 		 nIn: 1,	 nOut: 	1	 in 37.1s
# 		 nIn: 1,	 nOut: 	1	 in 37.3s
# 		 nIn: 1,	 nOut: 	0	 in 37.4s
# 		 nIn: 1,	 nOut: 	1	 in 37.7s
# 		 nIn: 1,	 nOut: 	1	 in 37.9s
# 		 nIn: 1,	 nOut: 	0	 in 38.2s
# 		 nIn: 1,	 nOut: 	1	 in 38.3s
# 		 nIn: 1,	 nOut: 	0	 in 38.5s
# 		 nIn: 1,	 nOut: 	0	 in 38.7s
# 		 nIn: 1,	 nOut: 	1	 in 38.9s
# 		 nIn: 1,	 nOut: 	0	 in 39.2s
# 		 nIn: 1,	 nOut: 	1	 in 39.5s
# 		 nIn: 1,	 nOut: 	0	 in 39.7s
# 		 nIn: 1,	 nOut: 	1	 in 39.9s
# 		 nIn: 1,	 nOut: 	1	 in 40.1s
# 		 nIn: 1,	 nOut: 	1	 in 40.3s
# 		 nIn: 1,	 nOut: 	0	 in 40.5s
# 		 nIn: 1,	 nOut: 	1	 in 40.7s
# 		 nIn: 1,	 nOut: 	0	 in 40.9s
# 		 nIn: 1,	 nOut: 	0	 in 41.1s
# 		 nIn: 1,	 nOut: 	1	 in 41.3s
# 		 nIn: 1,	 nOut: 	1	 in 41.5s
# 		 nIn: 1,	 nOut: 	1	 in 41.8s
# 		 nIn: 1,	 nOut: 	1	 in 42.0s
# 		 nIn: 1,	 nOut: 	1	 in 42.2s
# 		 nIn: 1,	 nOut: 	1	 in 42.4s
# 		 nIn: 1,	 nOut: 	1	 in 42.6s
# 		 nIn: 1,	 nOut: 	1	 in 42.8s
# 		 nIn: 1,	 nOut: 	1	 in 43.0s
# 		 nIn: 1,	 nOut: 	0	 in 43.2s
# 		 nIn: 1,	 nOut: 	1	 in 43.4s
# 		 nIn: 1,	 nOut: 	1	 in 43.6s
# 		 nIn: 1,	 nOut: 	0	 in 43.8s
# 		 nIn: 1,	 nOut: 	1	 in 44.0s
# 		 nIn: 1,	 nOut: 	0	 in 44.2s
# 		 nIn: 1,	 nOut: 	1	 in 44.4s
# 		 nIn: 1,	 nOut: 	0	 in 44.6s
# 		 nIn: 1,	 nOut: 	1	 in 44.8s
# 		 nIn: 1,	 nOut: 	1	 in 45.0s
# 		 nIn: 1,	 nOut: 	0	 in 45.2s
# 		 nIn: 1,	 nOut: 	1	 in 45.3s
# 		 nIn: 1,	 nOut: 	1	 in 45.5s
# 		 nIn: 1,	 nOut: 	0	 in 45.7s
# 		 nIn: 1,	 nOut: 	0	 in 46.0s
# 		 nIn: 1,	 nOut: 	0	 in 46.2s
# 		 nIn: 1,	 nOut: 	0	 in 46.4s
# 	Processing: data_C
# 		 nIn: 1,	 nOut: 	1	 in 20.5s
# 		 nIn: 1,	 nOut: 	1	 in 21.9s
# 		 nIn: 1,	 nOut: 	1	 in 22.1s
# 		 nIn: 1,	 nOut: 	1	 in 22.2s
# 		 nIn: 1,	 nOut: 	0	 in 22.4s
# 		 nIn: 1,	 nOut: 	1	 in 22.5s
# 		 nIn: 1,	 nOut: 	1	 in 22.6s
# 		 nIn: 1,	 nOut: 	0	 in 22.7s
# 		 nIn: 1,	 nOut: 	1	 in 22.9s
# 		 nIn: 1,	 nOut: 	0	 in 23.0s
# 		 nIn: 1,	 nOut: 	1	 in 23.1s
# 		 nIn: 1,	 nOut: 	0	 in 23.3s
# 		 nIn: 1,	 nOut: 	0	 in 23.4s
# 		 nIn: 1,	 nOut: 	0	 in 23.6s
# 		 nIn: 1,	 nOut: 	1	 in 23.8s
# 		 nIn: 1,	 nOut: 	1	 in 23.9s
# 		 nIn: 1,	 nOut: 	1	 in 24.0s
# 		 nIn: 1,	 nOut: 	0	 in 24.1s
# 		 nIn: 1,	 nOut: 	0	 in 24.3s
# 		 nIn: 1,	 nOut: 	0	 in 24.4s
# 		 nIn: 1,	 nOut: 	1	 in 24.5s
# 		 nIn: 1,	 nOut: 	0	 in 24.7s
# 		 nIn: 1,	 nOut: 	1	 in 24.8s
# 		 nIn: 1,	 nOut: 	0	 in 24.9s
# 		 nIn: 1,	 nOut: 	0	 in 25.1s
# 		 nIn: 1,	 nOut: 	0	 in 25.2s
# 		 nIn: 1,	 nOut: 	1	 in 25.4s
# 		 nIn: 1,	 nOut: 	0	 in 25.6s
# 		 nIn: 1,	 nOut: 	0	 in 25.8s
# 		 nIn: 1,	 nOut: 	1	 in 26.1s
# 		 nIn: 1,	 nOut: 	0	 in 26.3s
# 		 nIn: 1,	 nOut: 	0	 in 26.5s
# 		 nIn: 1,	 nOut: 	1	 in 26.7s
# 		 nIn: 1,	 nOut: 	0	 in 26.9s
# 		 nIn: 1,	 nOut: 	1	 in 27.1s
# 		 nIn: 1,	 nOut: 	1	 in 27.3s
# 		 nIn: 1,	 nOut: 	0	 in 27.5s
# 		 nIn: 1,	 nOut: 	0	 in 27.7s
# 		 nIn: 1,	 nOut: 	1	 in 27.9s
# 		 nIn: 1,	 nOut: 	1	 in 28.1s
# 		 nIn: 1,	 nOut: 	1	 in 28.3s
# 		 nIn: 1,	 nOut: 	0	 in 28.5s
# 		 nIn: 1,	 nOut: 	1	 in 28.7s
# 		 nIn: 1,	 nOut: 	1	 in 29.0s
# 		 nIn: 1,	 nOut: 	0	 in 29.2s
# 		 nIn: 1,	 nOut: 	1	 in 29.4s
# 		 nIn: 1,	 nOut: 	1	 in 29.5s
# 		 nIn: 1,	 nOut: 	1	 in 29.7s
# 		 nIn: 1,	 nOut: 	1	 in 29.9s
# 		 nIn: 1,	 nOut: 	1	 in 30.1s
# 		 nIn: 1,	 nOut: 	1	 in 30.3s
# 		 nIn: 1,	 nOut: 	0	 in 30.5s
# 		 nIn: 1,	 nOut: 	1	 in 30.7s
# 		 nIn: 1,	 nOut: 	0	 in 30.9s
# 		 nIn: 1,	 nOut: 	1	 in 31.1s
# 		 nIn: 1,	 nOut: 	0	 in 31.3s
# 		 nIn: 1,	 nOut: 	1	 in 31.6s
# 		 nIn: 1,	 nOut: 	1	 in 31.9s
# 		 nIn: 1,	 nOut: 	1	 in 32.2s
# 		 nIn: 1,	 nOut: 	1	 in 32.4s
# 		 nIn: 1,	 nOut: 	1	 in 32.6s
# 		 nIn: 1,	 nOut: 	1	 in 32.7s
# 		 nIn: 1,	 nOut: 	1	 in 32.9s
# 		 nIn: 1,	 nOut: 	1	 in 33.1s
# 		 nIn: 1,	 nOut: 	1	 in 33.3s
# 		 nIn: 1,	 nOut: 	0	 in 33.5s
# 		 nIn: 1,	 nOut: 	0	 in 33.7s
# 		 nIn: 1,	 nOut: 	0	 in 33.9s
# 		 nIn: 1,	 nOut: 	0	 in 34.1s
# 		 nIn: 1,	 nOut: 	1	 in 34.3s
# 		 nIn: 1,	 nOut: 	1	 in 34.6s
# 		 nIn: 1,	 nOut: 	1	 in 34.7s
# 		 nIn: 1,	 nOut: 	1	 in 34.9s
# 		 nIn: 1,	 nOut: 	0	 in 35.1s
# 		 nIn: 1,	 nOut: 	1	 in 35.3s
# 		 nIn: 1,	 nOut: 	1	 in 35.5s
# 		 nIn: 1,	 nOut: 	0	 in 35.7s
# 		 nIn: 1,	 nOut: 	1	 in 35.9s
# 		 nIn: 1,	 nOut: 	0	 in 36.1s
# 		 nIn: 1,	 nOut: 	1	 in 36.3s
# 		 nIn: 1,	 nOut: 	1	 in 36.5s
# 		 nIn: 1,	 nOut: 	1	 in 36.7s
# 		 nIn: 1,	 nOut: 	1	 in 36.9s
# 		 nIn: 1,	 nOut: 	0	 in 37.2s
# 		 nIn: 1,	 nOut: 	0	 in 37.4s
# 		 nIn: 1,	 nOut: 	0	 in 37.6s
# 		 nIn: 1,	 nOut: 	1	 in 37.8s
# 		 nIn: 1,	 nOut: 	1	 in 38.0s
# 		 nIn: 1,	 nOut: 	1	 in 38.2s
# 		 nIn: 1,	 nOut: 	0	 in 38.3s
# 		 nIn: 1,	 nOut: 	1	 in 38.5s
# 		 nIn: 1,	 nOut: 	0	 in 38.7s
# 		 nIn: 1,	 nOut: 	0	 in 38.9s
# 		 nIn: 1,	 nOut: 	1	 in 39.2s
# 		 nIn: 1,	 nOut: 	0	 in 39.4s
# 		 nIn: 1,	 nOut: 	1	 in 39.6s
# 		 nIn: 1,	 nOut: 	1	 in 39.8s
# 		 nIn: 1,	 nOut: 	1	 in 40.0s
# 		 nIn: 1,	 nOut: 	0	 in 40.2s
# 		 nIn: 1,	 nOut: 	0	 in 40.4s
# 		 nIn: 1,	 nOut: 	0	 in 40.6s
# 		 nIn: 1,	 nOut: 	1	 in 40.8s
# 		 nIn: 1,	 nOut: 	0	 in 41.0s
# 		 nIn: 1,	 nOut: 	1	 in 41.2s
# 		 nIn: 1,	 nOut: 	0	 in 41.4s
# 		 nIn: 1,	 nOut: 	0	 in 41.5s
# 		 nIn: 1,	 nOut: 	0	 in 41.8s
# 		 nIn: 1,	 nOut: 	0	 in 42.1s
# 		 nIn: 1,	 nOut: 	1	 in 42.3s
# 		 nIn: 1,	 nOut: 	0	 in 42.5s
# 		 nIn: 1,	 nOut: 	1	 in 42.7s
# 		 nIn: 1,	 nOut: 	1	 in 42.9s
# 		 nIn: 1,	 nOut: 	1	 in 43.1s
# 		 nIn: 1,	 nOut: 	0	 in 43.3s
# 		 nIn: 1,	 nOut: 	1	 in 43.5s
# 		 nIn: 1,	 nOut: 	1	 in 43.7s
# 		 nIn: 1,	 nOut: 	1	 in 43.9s
# 		 nIn: 1,	 nOut: 	1	 in 44.1s
# 		 nIn: 1,	 nOut: 	1	 in 44.3s
# 		 nIn: 1,	 nOut: 	0	 in 44.5s
# 		 nIn: 1,	 nOut: 	1	 in 44.7s
# 		 nIn: 1,	 nOut: 	0	 in 44.9s
# 		 nIn: 1,	 nOut: 	1	 in 45.1s
# 		 nIn: 1,	 nOut: 	0	 in 45.3s
# 		 nIn: 1,	 nOut: 	1	 in 45.5s
# 		 nIn: 1,	 nOut: 	1	 in 45.7s
# 		 nIn: 1,	 nOut: 	1	 in 45.9s
# 		 nIn: 1,	 nOut: 	1	 in 46.1s
# 		 nIn: 1,	 nOut: 	1	 in 46.3s
# 		 nIn: 1,	 nOut: 	0	 in 46.5s
# 		 nIn: 1,	 nOut: 	1	 in 46.7s
# 		 nIn: 1,	 nOut: 	1	 in 46.9s
# 		 nIn: 1,	 nOut: 	1	 in 47.2s
# 		 nIn: 1,	 nOut: 	0	 in 47.4s
# 		 nIn: 1,	 nOut: 	1	 in 47.6s
# 		 nIn: 1,	 nOut: 	1	 in 47.8s
# 		 nIn: 1,	 nOut: 	0	 in 48.0s
# 		 nIn: 1,	 nOut: 	1	 in 48.2s
# 		 nIn: 1,	 nOut: 	1	 in 48.4s
# 		 nIn: 1,	 nOut: 	1	 in 48.6s
# 		 nIn: 1,	 nOut: 	1	 in 48.8s
# 		 nIn: 1,	 nOut: 	1	 in 49.0s
# 		 nIn: 1,	 nOut: 	0	 in 49.2s
# 		 nIn: 1,	 nOut: 	1	 in 49.4s
# 		 nIn: 1,	 nOut: 	0	 in 49.6s
# 		 nIn: 1,	 nOut: 	1	 in 49.8s
# 		 nIn: 1,	 nOut: 	0	 in 50.0s
# 		 nIn: 1,	 nOut: 	1	 in 50.2s
# 		 nIn: 1,	 nOut: 	1	 in 50.4s
# 		 nIn: 1,	 nOut: 	1	 in 50.6s
# 		 nIn: 1,	 nOut: 	0	 in 50.8s
# 		 nIn: 1,	 nOut: 	1	 in 51.0s
# 		 nIn: 1,	 nOut: 	1	 in 51.2s
# 		 nIn: 1,	 nOut: 	0	 in 51.4s
# 		 nIn: 1,	 nOut: 	1	 in 51.6s
# 		 nIn: 1,	 nOut: 	1	 in 51.8s
# 		 nIn: 1,	 nOut: 	1	 in 52.0s
# 		 nIn: 1,	 nOut: 	0	 in 52.2s
# 		 nIn: 1,	 nOut: 	0	 in 52.6s
# 		 nIn: 1,	 nOut: 	1	 in 52.8s
# 		 nIn: 1,	 nOut: 	1	 in 53.1s
# 		 nIn: 1,	 nOut: 	1	 in 53.3s
# 		 nIn: 1,	 nOut: 	0	 in 53.5s
# 		 nIn: 1,	 nOut: 	0	 in 53.7s
# 		 nIn: 1,	 nOut: 	0	 in 53.8s
# 		 nIn: 1,	 nOut: 	0	 in 54.1s
# 		 nIn: 1,	 nOut: 	0	 in 54.3s
# 		 nIn: 1,	 nOut: 	1	 in 54.4s
# 		 nIn: 1,	 nOut: 	1	 in 54.6s
# 		 nIn: 1,	 nOut: 	1	 in 54.8s
# 		 nIn: 1,	 nOut: 	1	 in 55.0s
# 		 nIn: 1,	 nOut: 	0	 in 55.2s
# 		 nIn: 1,	 nOut: 	0	 in 55.5s
# 		 nIn: 1,	 nOut: 	1	 in 55.6s
# 		 nIn: 1,	 nOut: 	1	 in 55.8s
# 		 nIn: 1,	 nOut: 	0	 in 56.0s
# 		 nIn: 1,	 nOut: 	1	 in 56.2s
# 		 nIn: 1,	 nOut: 	0	 in 56.4s
# 		 nIn: 1,	 nOut: 	0	 in 56.6s
# 		 nIn: 1,	 nOut: 	0	 in 56.8s
# 		 nIn: 1,	 nOut: 	1	 in 57.0s
# 		 nIn: 1,	 nOut: 	1	 in 57.2s
# 		 nIn: 1,	 nOut: 	1	 in 57.4s
# 		 nIn: 1,	 nOut: 	0	 in 57.6s
# 		 nIn: 1,	 nOut: 	0	 in 57.9s
# 		 nIn: 1,	 nOut: 	1	 in 58.1s
# 		 nIn: 1,	 nOut: 	0	 in 58.3s
# 		 nIn: 1,	 nOut: 	1	 in 58.5s
# 		 nIn: 1,	 nOut: 	1	 in 58.7s
# 		 nIn: 1,	 nOut: 	1	 in 58.9s
# 		 nIn: 1,	 nOut: 	1	 in 59.1s
# 		 nIn: 1,	 nOut: 	0	 in 59.3s
# 		 nIn: 1,	 nOut: 	0	 in 59.5s
# 		 nIn: 1,	 nOut: 	1	 in 59.7s
# 		 nIn: 1,	 nOut: 	1	 in 59.9s
# 		 nIn: 1,	 nOut: 	1	 in 60.1s
# 		 nIn: 1,	 nOut: 	0	 in 60.3s
# 		 nIn: 1,	 nOut: 	0	 in 60.5s
# 		 nIn: 1,	 nOut: 	1	 in 60.7s
# 		 nIn: 1,	 nOut: 	0	 in 60.9s
# 		 nIn: 1,	 nOut: 	1	 in 61.1s
# 		 nIn: 1,	 nOut: 	1	 in 61.3s
# 		 nIn: 1,	 nOut: 	1	 in 61.5s
# 		 nIn: 1,	 nOut: 	1	 in 61.7s
# 		 nIn: 1,	 nOut: 	1	 in 61.9s
# 		 nIn: 1,	 nOut: 	1	 in 62.1s
# 		 nIn: 1,	 nOut: 	0	 in 62.3s
# 		 nIn: 1,	 nOut: 	1	 in 62.5s
# 		 nIn: 1,	 nOut: 	1	 in 62.8s
# 		 nIn: 1,	 nOut: 	0	 in 63.0s
# 		 nIn: 1,	 nOut: 	1	 in 63.2s
# 		 nIn: 1,	 nOut: 	0	 in 63.4s
# 		 nIn: 1,	 nOut: 	0	 in 63.7s
# 		 nIn: 1,	 nOut: 	1	 in 64.0s
# 		 nIn: 1,	 nOut: 	1	 in 64.2s
# 		 nIn: 1,	 nOut: 	1	 in 64.4s
# 		 nIn: 1,	 nOut: 	1	 in 64.6s
# 		 nIn: 1,	 nOut: 	0	 in 64.8s
# 		 nIn: 1,	 nOut: 	0	 in 65.1s
# 		 nIn: 1,	 nOut: 	0	 in 65.3s
# 		 nIn: 1,	 nOut: 	1	 in 65.6s
# 		 nIn: 1,	 nOut: 	1	 in 65.8s
# 		 nIn: 1,	 nOut: 	1	 in 66.0s
# 		 nIn: 1,	 nOut: 	1	 in 66.2s
# 		 nIn: 1,	 nOut: 	1	 in 66.5s
# 		 nIn: 1,	 nOut: 	1	 in 66.7s
# 		 nIn: 1,	 nOut: 	1	 in 66.9s
# 		 nIn: 1,	 nOut: 	1	 in 67.1s
# 		 nIn: 1,	 nOut: 	1	 in 67.3s
# 		 nIn: 1,	 nOut: 	0	 in 67.5s
# 		 nIn: 1,	 nOut: 	0	 in 67.7s
# 		 nIn: 1,	 nOut: 	1	 in 68.0s
# 		 nIn: 1,	 nOut: 	1	 in 68.2s
# 		 nIn: 1,	 nOut: 	1	 in 68.4s
# 		 nIn: 1,	 nOut: 	1	 in 68.6s
# 		 nIn: 1,	 nOut: 	1	 in 68.8s
# 		 nIn: 1,	 nOut: 	0	 in 69.0s
# 	Processing: data_D
# 		 nIn: 1,	 nOut: 	1	 in 13.8s
# 		 nIn: 1,	 nOut: 	0	 in 16.1s
# 		 nIn: 1,	 nOut: 	0	 in 16.3s
# 		 nIn: 1,	 nOut: 	1	 in 16.5s
# 		 nIn: 1,	 nOut: 	0	 in 16.7s
# 		 nIn: 1,	 nOut: 	0	 in 17.0s
# 		 nIn: 1,	 nOut: 	0	 in 17.2s
# 		 nIn: 1,	 nOut: 	0	 in 17.4s
# 		 nIn: 1,	 nOut: 	0	 in 17.6s
# 		 nIn: 1,	 nOut: 	1	 in 17.9s
# 		 nIn: 1,	 nOut: 	0	 in 18.1s
# 		 nIn: 1,	 nOut: 	1	 in 18.3s
# 		 nIn: 1,	 nOut: 	0	 in 18.7s
# 		 nIn: 1,	 nOut: 	1	 in 18.9s
# 		 nIn: 1,	 nOut: 	1	 in 19.1s
# 		 nIn: 1,	 nOut: 	0	 in 19.3s
# 		 nIn: 1,	 nOut: 	0	 in 19.5s
# 		 nIn: 1,	 nOut: 	1	 in 19.7s
# 		 nIn: 1,	 nOut: 	1	 in 19.9s
# 		 nIn: 1,	 nOut: 	0	 in 20.1s
# 		 nIn: 1,	 nOut: 	1	 in 20.3s
# 		 nIn: 1,	 nOut: 	0	 in 20.5s
# 		 nIn: 1,	 nOut: 	1	 in 20.7s
# 		 nIn: 1,	 nOut: 	0	 in 20.9s
# 		 nIn: 1,	 nOut: 	1	 in 21.1s
# 		 nIn: 1,	 nOut: 	0	 in 21.3s
# 		 nIn: 1,	 nOut: 	0	 in 21.5s
# 		 nIn: 1,	 nOut: 	1	 in 21.7s
# 		 nIn: 1,	 nOut: 	0	 in 21.9s
# 		 nIn: 1,	 nOut: 	1	 in 22.1s
# 		 nIn: 1,	 nOut: 	0	 in 22.3s
# 		 nIn: 1,	 nOut: 	1	 in 22.5s
# 		 nIn: 1,	 nOut: 	0	 in 22.8s
# 		 nIn: 1,	 nOut: 	1	 in 23.0s
# 		 nIn: 1,	 nOut: 	1	 in 23.3s
# 		 nIn: 1,	 nOut: 	1	 in 23.5s
# 		 nIn: 1,	 nOut: 	1	 in 23.7s
# 		 nIn: 1,	 nOut: 	1	 in 24.0s
# 		 nIn: 1,	 nOut: 	1	 in 24.2s
# 		 nIn: 1,	 nOut: 	0	 in 24.4s
# 		 nIn: 1,	 nOut: 	0	 in 24.6s
# 		 nIn: 1,	 nOut: 	0	 in 24.8s
# 		 nIn: 1,	 nOut: 	1	 in 25.0s
# 		 nIn: 1,	 nOut: 	1	 in 25.2s
# 		 nIn: 1,	 nOut: 	1	 in 25.4s
# 		 nIn: 1,	 nOut: 	1	 in 25.6s
# 		 nIn: 1,	 nOut: 	1	 in 25.8s
# 		 nIn: 1,	 nOut: 	1	 in 26.0s
# 		 nIn: 1,	 nOut: 	1	 in 26.2s
# 		 nIn: 1,	 nOut: 	1	 in 26.4s
# 		 nIn: 1,	 nOut: 	1	 in 26.6s
# 		 nIn: 1,	 nOut: 	1	 in 26.8s
# 		 nIn: 1,	 nOut: 	1	 in 27.0s
# 		 nIn: 1,	 nOut: 	0	 in 27.2s
# 		 nIn: 1,	 nOut: 	1	 in 27.4s
# 		 nIn: 1,	 nOut: 	0	 in 27.6s
# 		 nIn: 1,	 nOut: 	0	 in 27.8s
# 		 nIn: 1,	 nOut: 	1	 in 28.0s
# 		 nIn: 1,	 nOut: 	1	 in 28.2s
# 		 nIn: 1,	 nOut: 	1	 in 28.4s
# 		 nIn: 1,	 nOut: 	0	 in 28.6s
# 		 nIn: 1,	 nOut: 	1	 in 28.8s
# 		 nIn: 1,	 nOut: 	0	 in 29.0s
# 		 nIn: 1,	 nOut: 	1	 in 29.4s
# 		 nIn: 1,	 nOut: 	0	 in 29.5s
# 		 nIn: 1,	 nOut: 	1	 in 29.7s
# 		 nIn: 1,	 nOut: 	0	 in 30.0s
# 		 nIn: 1,	 nOut: 	1	 in 30.2s
# 		 nIn: 1,	 nOut: 	1	 in 30.4s
# 		 nIn: 1,	 nOut: 	1	 in 30.6s
# 		 nIn: 1,	 nOut: 	0	 in 30.8s
# 		 nIn: 1,	 nOut: 	0	 in 31.0s
# 		 nIn: 1,	 nOut: 	1	 in 31.2s
# 		 nIn: 1,	 nOut: 	0	 in 31.4s
# 		 nIn: 1,	 nOut: 	0	 in 31.6s
# 		 nIn: 1,	 nOut: 	1	 in 31.8s
# 		 nIn: 1,	 nOut: 	1	 in 32.0s
# 		 nIn: 1,	 nOut: 	1	 in 32.2s
# 		 nIn: 1,	 nOut: 	0	 in 32.4s
# 		 nIn: 1,	 nOut: 	1	 in 32.6s
# 		 nIn: 1,	 nOut: 	0	 in 32.9s
# 		 nIn: 1,	 nOut: 	1	 in 33.0s
# 		 nIn: 1,	 nOut: 	0	 in 33.2s
# 		 nIn: 1,	 nOut: 	1	 in 33.4s
# 		 nIn: 1,	 nOut: 	1	 in 33.7s
# 		 nIn: 1,	 nOut: 	1	 in 33.9s
# 		 nIn: 1,	 nOut: 	1	 in 34.1s
# 		 nIn: 1,	 nOut: 	1	 in 34.3s
# 		 nIn: 1,	 nOut: 	1	 in 34.6s
# 		 nIn: 1,	 nOut: 	0	 in 34.8s
# 		 nIn: 1,	 nOut: 	0	 in 35.0s
# 		 nIn: 1,	 nOut: 	0	 in 35.2s
# 		 nIn: 1,	 nOut: 	0	 in 35.4s
# 		 nIn: 1,	 nOut: 	1	 in 35.6s
# 		 nIn: 1,	 nOut: 	1	 in 35.8s
# 		 nIn: 1,	 nOut: 	0	 in 36.0s
# 		 nIn: 1,	 nOut: 	1	 in 36.3s
# 		 nIn: 1,	 nOut: 	0	 in 36.5s
# 		 nIn: 1,	 nOut: 	0	 in 36.7s
# 		 nIn: 1,	 nOut: 	0	 in 36.9s
# 		 nIn: 1,	 nOut: 	0	 in 37.1s
# 		 nIn: 1,	 nOut: 	1	 in 37.3s
# 		 nIn: 1,	 nOut: 	1	 in 37.5s
# 		 nIn: 1,	 nOut: 	1	 in 37.7s
# 		 nIn: 1,	 nOut: 	0	 in 37.9s
# 		 nIn: 1,	 nOut: 	1	 in 38.1s
# 		 nIn: 1,	 nOut: 	1	 in 38.3s
# 		 nIn: 1,	 nOut: 	1	 in 38.5s
# 		 nIn: 1,	 nOut: 	0	 in 38.7s
# 		 nIn: 1,	 nOut: 	1	 in 38.9s
# 		 nIn: 1,	 nOut: 	0	 in 39.1s
# 		 nIn: 1,	 nOut: 	0	 in 39.3s
# 		 nIn: 1,	 nOut: 	1	 in 39.5s
# 		 nIn: 1,	 nOut: 	1	 in 39.7s
# 		 nIn: 1,	 nOut: 	1	 in 40.1s
# 		 nIn: 1,	 nOut: 	1	 in 40.3s
# 		 nIn: 1,	 nOut: 	0	 in 40.4s
# 		 nIn: 1,	 nOut: 	1	 in 40.7s
# 		 nIn: 1,	 nOut: 	0	 in 40.9s
# 		 nIn: 1,	 nOut: 	1	 in 41.1s
# 		 nIn: 1,	 nOut: 	0	 in 41.3s
# 		 nIn: 1,	 nOut: 	0	 in 41.4s
# 		 nIn: 1,	 nOut: 	1	 in 41.7s
# 		 nIn: 1,	 nOut: 	1	 in 41.9s
# 		 nIn: 1,	 nOut: 	1	 in 42.0s
# 		 nIn: 1,	 nOut: 	0	 in 42.3s
# 		 nIn: 1,	 nOut: 	1	 in 42.5s
# 		 nIn: 1,	 nOut: 	1	 in 42.7s
# 		 nIn: 1,	 nOut: 	0	 in 42.9s
# 		 nIn: 1,	 nOut: 	1	 in 43.1s
# 		 nIn: 1,	 nOut: 	1	 in 43.3s
# 		 nIn: 1,	 nOut: 	0	 in 43.5s
# 		 nIn: 1,	 nOut: 	0	 in 43.7s
# 		 nIn: 1,	 nOut: 	1	 in 43.9s
# 		 nIn: 1,	 nOut: 	1	 in 44.1s
# 		 nIn: 1,	 nOut: 	1	 in 44.3s
# 		 nIn: 1,	 nOut: 	1	 in 44.5s
# 		 nIn: 1,	 nOut: 	1	 in 44.7s
# 		 nIn: 1,	 nOut: 	1	 in 45.0s
# 		 nIn: 1,	 nOut: 	0	 in 45.2s
# 		 nIn: 1,	 nOut: 	1	 in 45.4s
# 		 nIn: 1,	 nOut: 	1	 in 45.6s
# 		 nIn: 1,	 nOut: 	1	 in 45.8s
# 		 nIn: 1,	 nOut: 	0	 in 46.0s
# 		 nIn: 1,	 nOut: 	1	 in 46.2s
# 		 nIn: 1,	 nOut: 	1	 in 46.4s
# 		 nIn: 1,	 nOut: 	1	 in 46.7s
# 		 nIn: 1,	 nOut: 	1	 in 46.9s
# 		 nIn: 1,	 nOut: 	1	 in 47.1s
# 		 nIn: 1,	 nOut: 	0	 in 47.3s
# 		 nIn: 1,	 nOut: 	0	 in 47.5s
# 		 nIn: 1,	 nOut: 	1	 in 47.7s
# 		 nIn: 1,	 nOut: 	0	 in 47.9s
# 		 nIn: 1,	 nOut: 	0	 in 48.1s
# 		 nIn: 1,	 nOut: 	0	 in 48.3s
# 		 nIn: 1,	 nOut: 	1	 in 48.5s
# 		 nIn: 1,	 nOut: 	1	 in 48.7s
# 		 nIn: 1,	 nOut: 	1	 in 49.0s
# 		 nIn: 1,	 nOut: 	1	 in 49.3s
# 		 nIn: 1,	 nOut: 	1	 in 49.5s
# 		 nIn: 1,	 nOut: 	1	 in 49.7s
# 		 nIn: 1,	 nOut: 	0	 in 49.9s
# 		 nIn: 1,	 nOut: 	1	 in 50.1s
# 		 nIn: 1,	 nOut: 	0	 in 50.4s
# 		 nIn: 1,	 nOut: 	0	 in 50.6s
# 		 nIn: 1,	 nOut: 	1	 in 50.8s
# 		 nIn: 1,	 nOut: 	0	 in 51.0s
# 		 nIn: 1,	 nOut: 	0	 in 51.2s
# 		 nIn: 1,	 nOut: 	1	 in 51.4s
# 		 nIn: 1,	 nOut: 	0	 in 51.6s
# 		 nIn: 1,	 nOut: 	0	 in 51.8s
# 		 nIn: 1,	 nOut: 	0	 in 52.0s
# 		 nIn: 1,	 nOut: 	1	 in 52.2s
# 		 nIn: 1,	 nOut: 	1	 in 52.5s
# 		 nIn: 1,	 nOut: 	1	 in 52.6s
# 		 nIn: 1,	 nOut: 	1	 in 52.9s
# 		 nIn: 1,	 nOut: 	1	 in 53.1s
# 		 nIn: 1,	 nOut: 	1	 in 53.2s
# 		 nIn: 1,	 nOut: 	1	 in 53.4s
# 		 nIn: 1,	 nOut: 	1	 in 53.7s
# 		 nIn: 1,	 nOut: 	0	 in 53.9s
# 		 nIn: 1,	 nOut: 	1	 in 54.1s
# 		 nIn: 1,	 nOut: 	1	 in 54.3s
# 		 nIn: 1,	 nOut: 	1	 in 54.5s
# 		 nIn: 1,	 nOut: 	0	 in 54.7s
# 		 nIn: 1,	 nOut: 	0	 in 54.9s
# 		 nIn: 1,	 nOut: 	1	 in 55.1s
# 		 nIn: 1,	 nOut: 	0	 in 55.5s
# 		 nIn: 1,	 nOut: 	0	 in 55.7s
# 		 nIn: 1,	 nOut: 	0	 in 56.0s
# 		 nIn: 1,	 nOut: 	0	 in 56.2s
# 		 nIn: 1,	 nOut: 	1	 in 56.9s
# 		 nIn: 1,	 nOut: 	1	 in 57.4s
# 		 nIn: 1,	 nOut: 	0	 in 57.6s
# 		 nIn: 1,	 nOut: 	1	 in 57.8s
# 		 nIn: 1,	 nOut: 	1	 in 58.0s
# 		 nIn: 1,	 nOut: 	1	 in 58.2s
# 		 nIn: 1,	 nOut: 	0	 in 58.4s
# 		 nIn: 1,	 nOut: 	1	 in 58.6s
# 		 nIn: 1,	 nOut: 	1	 in 58.8s
# 		 nIn: 1,	 nOut: 	1	 in 59.0s
# 		 nIn: 1,	 nOut: 	1	 in 59.2s
# 		 nIn: 1,	 nOut: 	0	 in 59.4s
# 		 nIn: 1,	 nOut: 	0	 in 59.6s
# 		 nIn: 1,	 nOut: 	1	 in 59.8s
# 		 nIn: 1,	 nOut: 	0	 in 60.0s
# 		 nIn: 1,	 nOut: 	1	 in 60.2s
# 		 nIn: 1,	 nOut: 	0	 in 60.5s
# 		 nIn: 1,	 nOut: 	1	 in 60.7s
# 		 nIn: 1,	 nOut: 	0	 in 60.9s
# 		 nIn: 1,	 nOut: 	1	 in 61.2s
# 		 nIn: 1,	 nOut: 	1	 in 61.5s
# 		 nIn: 1,	 nOut: 	0	 in 61.7s
# 		 nIn: 1,	 nOut: 	0	 in 61.9s
# 		 nIn: 1,	 nOut: 	0	 in 62.1s
# 		 nIn: 1,	 nOut: 	0	 in 62.3s
# 		 nIn: 1,	 nOut: 	1	 in 62.5s
# 		 nIn: 1,	 nOut: 	0	 in 62.7s
# 		 nIn: 1,	 nOut: 	1	 in 62.9s
# 		 nIn: 1,	 nOut: 	1	 in 63.2s
# 		 nIn: 1,	 nOut: 	1	 in 63.4s
# 		 nIn: 1,	 nOut: 	1	 in 63.5s
# 		 nIn: 1,	 nOut: 	1	 in 63.8s
# 		 nIn: 1,	 nOut: 	1	 in 64.0s
# 		 nIn: 1,	 nOut: 	0	 in 64.2s
# 		 nIn: 1,	 nOut: 	1	 in 64.4s
# 		 nIn: 1,	 nOut: 	0	 in 64.6s
# 		 nIn: 1,	 nOut: 	1	 in 64.7s
# 		 nIn: 1,	 nOut: 	1	 in 64.9s
# 		 nIn: 1,	 nOut: 	0	 in 65.2s
# 		 nIn: 1,	 nOut: 	1	 in 65.4s
# 		 nIn: 1,	 nOut: 	1	 in 65.6s
# 		 nIn: 1,	 nOut: 	1	 in 65.8s
# 		 nIn: 1,	 nOut: 	0	 in 66.0s
# 		 nIn: 1,	 nOut: 	0	 in 66.2s
# 		 nIn: 1,	 nOut: 	1	 in 66.5s
# 		 nIn: 1,	 nOut: 	0	 in 66.7s
# 		 nIn: 1,	 nOut: 	1	 in 66.9s
# 		 nIn: 1,	 nOut: 	1	 in 67.2s
# 		 nIn: 1,	 nOut: 	1	 in 67.4s
# 		 nIn: 1,	 nOut: 	0	 in 67.6s
# 		 nIn: 1,	 nOut: 	1	 in 67.9s
# 		 nIn: 1,	 nOut: 	1	 in 68.1s
# 		 nIn: 1,	 nOut: 	1	 in 68.4s
# 		 nIn: 1,	 nOut: 	0	 in 68.5s
# 		 nIn: 1,	 nOut: 	1	 in 68.8s
# 		 nIn: 1,	 nOut: 	1	 in 69.0s
# 		 nIn: 1,	 nOut: 	1	 in 69.2s
# 		 nIn: 1,	 nOut: 	0	 in 69.4s
# 		 nIn: 1,	 nOut: 	1	 in 69.6s
# 		 nIn: 1,	 nOut: 	1	 in 69.8s
# 		 nIn: 1,	 nOut: 	1	 in 70.0s
# 		 nIn: 1,	 nOut: 	0	 in 70.2s
# 		 nIn: 1,	 nOut: 	1	 in 70.4s
# 		 nIn: 1,	 nOut: 	1	 in 70.6s
# 		 nIn: 1,	 nOut: 	0	 in 70.8s
# 		 nIn: 1,	 nOut: 	0	 in 71.2s
# 		 nIn: 1,	 nOut: 	1	 in 71.4s
# 		 nIn: 1,	 nOut: 	1	 in 71.7s
# 		 nIn: 1,	 nOut: 	0	 in 71.9s
# 		 nIn: 1,	 nOut: 	1	 in 72.2s
# 		 nIn: 1,	 nOut: 	1	 in 72.4s
# 		 nIn: 1,	 nOut: 	1	 in 72.6s
# 		 nIn: 1,	 nOut: 	1	 in 72.8s
# 		 nIn: 1,	 nOut: 	1	 in 73.0s
# 		 nIn: 1,	 nOut: 	1	 in 73.2s
# 		 nIn: 1,	 nOut: 	0	 in 73.4s
# 		 nIn: 1,	 nOut: 	0	 in 73.6s
# 		 nIn: 1,	 nOut: 	1	 in 73.8s
# 		 nIn: 1,	 nOut: 	0	 in 74.0s
# 		 nIn: 1,	 nOut: 	1	 in 74.2s
# 		 nIn: 1,	 nOut: 	1	 in 74.4s
# 		 nIn: 1,	 nOut: 	1	 in 74.6s
# 		 nIn: 1,	 nOut: 	0	 in 74.9s
# 		 nIn: 1,	 nOut: 	1	 in 75.1s
# 		 nIn: 1,	 nOut: 	0	 in 75.3s
# 		 nIn: 1,	 nOut: 	1	 in 75.4s
# 		 nIn: 1,	 nOut: 	1	 in 75.6s
# 		 nIn: 1,	 nOut: 	0	 in 75.9s
# 		 nIn: 1,	 nOut: 	1	 in 76.1s
# 		 nIn: 1,	 nOut: 	0	 in 76.3s
# 		 nIn: 1,	 nOut: 	0	 in 76.6s
# 		 nIn: 1,	 nOut: 	1	 in 76.8s
# 		 nIn: 1,	 nOut: 	1	 in 77.0s
# 		 nIn: 1,	 nOut: 	1	 in 77.2s
# 		 nIn: 1,	 nOut: 	1	 in 77.4s
# 		 nIn: 1,	 nOut: 	1	 in 77.6s
# 		 nIn: 1,	 nOut: 	0	 in 77.8s
# 		 nIn: 1,	 nOut: 	1	 in 78.0s
# 		 nIn: 1,	 nOut: 	0	 in 78.2s
# 		 nIn: 1,	 nOut: 	1	 in 78.5s
# 		 nIn: 1,	 nOut: 	1	 in 78.7s
# 		 nIn: 1,	 nOut: 	0	 in 78.9s
# 		 nIn: 1,	 nOut: 	1	 in 79.1s
# 		 nIn: 1,	 nOut: 	1	 in 79.3s
# 		 nIn: 1,	 nOut: 	1	 in 79.5s
# 		 nIn: 1,	 nOut: 	0	 in 79.8s
# 		 nIn: 1,	 nOut: 	1	 in 80.0s
# 		 nIn: 1,	 nOut: 	1	 in 80.3s
# 		 nIn: 1,	 nOut: 	1	 in 80.5s
# 		 nIn: 1,	 nOut: 	1	 in 80.6s
# 		 nIn: 1,	 nOut: 	0	 in 80.9s
# 		 nIn: 1,	 nOut: 	1	 in 81.1s
# 		 nIn: 1,	 nOut: 	0	 in 81.2s
# 		 nIn: 1,	 nOut: 	1	 in 81.4s
# 		 nIn: 1,	 nOut: 	1	 in 81.7s
# 		 nIn: 1,	 nOut: 	0	 in 81.9s
# 		 nIn: 1,	 nOut: 	0	 in 82.1s
# 		 nIn: 1,	 nOut: 	0	 in 82.3s
# 		 nIn: 1,	 nOut: 	1	 in 82.5s
# 		 nIn: 1,	 nOut: 	1	 in 82.7s
# 		 nIn: 1,	 nOut: 	0	 in 83.0s
# 		 nIn: 1,	 nOut: 	0	 in 83.2s
# 		 nIn: 1,	 nOut: 	1	 in 83.4s
# 		 nIn: 1,	 nOut: 	1	 in 83.6s
# 		 nIn: 1,	 nOut: 	1	 in 83.8s
# 		 nIn: 1,	 nOut: 	1	 in 84.0s
# 		 nIn: 1,	 nOut: 	1	 in 84.2s
# 		 nIn: 1,	 nOut: 	1	 in 84.5s
# 		 nIn: 1,	 nOut: 	1	 in 84.7s
# 		 nIn: 1,	 nOut: 	1	 in 85.0s
# 		 nIn: 1,	 nOut: 	1	 in 85.3s
# 		 nIn: 1,	 nOut: 	1	 in 85.5s
# 		 nIn: 1,	 nOut: 	1	 in 85.8s
# 		 nIn: 1,	 nOut: 	0	 in 86.1s
# 		 nIn: 1,	 nOut: 	1	 in 86.4s
# 		 nIn: 1,	 nOut: 	1	 in 86.8s
# 		 nIn: 1,	 nOut: 	1	 in 87.1s
# 		 nIn: 1,	 nOut: 	1	 in 87.5s
# 		 nIn: 1,	 nOut: 	0	 in 87.7s
# 		 nIn: 1,	 nOut: 	0	 in 87.9s
# 		 nIn: 1,	 nOut: 	0	 in 88.1s
# 		 nIn: 1,	 nOut: 	0	 in 88.3s
# 		 nIn: 1,	 nOut: 	0	 in 88.5s
# 		 nIn: 1,	 nOut: 	0	 in 88.7s
# 		 nIn: 1,	 nOut: 	0	 in 89.0s
# 		 nIn: 1,	 nOut: 	1	 in 89.2s
# 		 nIn: 1,	 nOut: 	1	 in 89.3s
# 		 nIn: 1,	 nOut: 	0	 in 89.5s
# 		 nIn: 1,	 nOut: 	1	 in 89.8s
# 		 nIn: 1,	 nOut: 	1	 in 90.0s
# 		 nIn: 1,	 nOut: 	0	 in 90.2s
# 		 nIn: 1,	 nOut: 	1	 in 90.4s
# 		 nIn: 1,	 nOut: 	1	 in 90.6s
# 		 nIn: 1,	 nOut: 	0	 in 90.8s
# 		 nIn: 1,	 nOut: 	1	 in 91.0s
# 		 nIn: 1,	 nOut: 	0	 in 91.2s
# 		 nIn: 1,	 nOut: 	1	 in 91.4s
# 		 nIn: 1,	 nOut: 	1	 in 91.6s
# 		 nIn: 1,	 nOut: 	1	 in 91.8s
# 		 nIn: 1,	 nOut: 	1	 in 92.0s
# 		 nIn: 1,	 nOut: 	0	 in 92.3s
# 		 nIn: 1,	 nOut: 	1	 in 92.6s
# 		 nIn: 1,	 nOut: 	1	 in 92.8s
# 		 nIn: 1,	 nOut: 	1	 in 93.0s
# 		 nIn: 1,	 nOut: 	1	 in 93.2s
# 		 nIn: 1,	 nOut: 	1	 in 93.6s
# 		 nIn: 1,	 nOut: 	1	 in 93.8s
# 		 nIn: 1,	 nOut: 	0	 in 94.0s
# 		 nIn: 1,	 nOut: 	1	 in 94.2s
# 		 nIn: 1,	 nOut: 	1	 in 94.4s
# 		 nIn: 1,	 nOut: 	1	 in 94.6s
# 		 nIn: 1,	 nOut: 	1	 in 94.8s
# 		 nIn: 1,	 nOut: 	0	 in 95.0s
# 		 nIn: 1,	 nOut: 	1	 in 95.2s
# 		 nIn: 1,	 nOut: 	0	 in 95.4s
# 		 nIn: 1,	 nOut: 	1	 in 95.6s
# 		 nIn: 1,	 nOut: 	1	 in 95.8s
# 		 nIn: 1,	 nOut: 	0	 in 96.0s
# 		 nIn: 1,	 nOut: 	0	 in 96.2s
# 		 nIn: 1,	 nOut: 	1	 in 96.4s
# 		 nIn: 1,	 nOut: 	1	 in 96.6s
# 		 nIn: 1,	 nOut: 	1	 in 96.8s
# 		 nIn: 1,	 nOut: 	1	 in 97.0s
# 		 nIn: 1,	 nOut: 	1	 in 97.3s
# 		 nIn: 1,	 nOut: 	1	 in 97.5s
# 		 nIn: 1,	 nOut: 	1	 in 97.8s
# 		 nIn: 1,	 nOut: 	1	 in 98.0s
# 		 nIn: 1,	 nOut: 	0	 in 98.2s
# 		 nIn: 1,	 nOut: 	0	 in 98.4s
# 		 nIn: 1,	 nOut: 	1	 in 98.6s
# 		 nIn: 1,	 nOut: 	1	 in 98.8s
# 		 nIn: 1,	 nOut: 	1	 in 99.1s
# 		 nIn: 1,	 nOut: 	0	 in 99.3s
# 		 nIn: 1,	 nOut: 	1	 in 99.5s
# 		 nIn: 1,	 nOut: 	0	 in 99.7s
# 		 nIn: 1,	 nOut: 	1	 in 99.9s
# 		 nIn: 1,	 nOut: 	0	 in 100.1s
# 		 nIn: 1,	 nOut: 	1	 in 100.3s
# 		 nIn: 1,	 nOut: 	1	 in 100.5s
# 		 nIn: 1,	 nOut: 	0	 in 100.9s
# 		 nIn: 1,	 nOut: 	0	 in 101.1s
# 		 nIn: 1,	 nOut: 	0	 in 101.3s
# 		 nIn: 1,	 nOut: 	0	 in 101.5s
# 		 nIn: 1,	 nOut: 	1	 in 101.7s
# 		 nIn: 1,	 nOut: 	1	 in 101.9s
# 		 nIn: 1,	 nOut: 	1	 in 102.1s
# 		 nIn: 1,	 nOut: 	0	 in 102.3s
# 		 nIn: 1,	 nOut: 	1	 in 102.5s
# 		 nIn: 1,	 nOut: 	0	 in 102.8s
# Processing Background $Z,t\bar{t}$ samples
# 	Processing: Zee
# 		 nIn: 1,	 nOut: 	0	 in 10.0s
# 		 nIn: 1,	 nOut: 	0	 in 11.7s
# 		 nIn: 1,	 nOut: 	0	 in 11.9s
# 		 nIn: 1,	 nOut: 	1	 in 12.2s
# 		 nIn: 1,	 nOut: 	0	 in 12.5s
# 		 nIn: 1,	 nOut: 	0	 in 12.7s
# 		 nIn: 1,	 nOut: 	0	 in 13.0s
# 		 nIn: 1,	 nOut: 	0	 in 13.3s
# 		 nIn: 1,	 nOut: 	0	 in 13.6s
# 		 nIn: 1,	 nOut: 	0	 in 13.8s
# 		 nIn: 1,	 nOut: 	0	 in 14.1s
# 		 nIn: 1,	 nOut: 	1	 in 14.4s
# 		 nIn: 1,	 nOut: 	0	 in 14.6s
# 		 nIn: 1,	 nOut: 	0	 in 14.9s
# 		 nIn: 1,	 nOut: 	1	 in 15.1s
# 		 nIn: 1,	 nOut: 	0	 in 15.4s
# 		 nIn: 1,	 nOut: 	1	 in 15.8s
# 		 nIn: 1,	 nOut: 	1	 in 16.1s
# 		 nIn: 1,	 nOut: 	0	 in 16.4s
# 		 nIn: 1,	 nOut: 	0	 in 16.7s
# 		 nIn: 1,	 nOut: 	1	 in 17.1s
# 		 nIn: 1,	 nOut: 	1	 in 17.3s
# 		 nIn: 1,	 nOut: 	0	 in 17.6s
# 		 nIn: 1,	 nOut: 	1	 in 17.9s
# 		 nIn: 1,	 nOut: 	0	 in 18.1s
# 		 nIn: 1,	 nOut: 	0	 in 18.4s
# 		 nIn: 1,	 nOut: 	0	 in 18.7s
# 		 nIn: 1,	 nOut: 	0	 in 19.0s
# 		 nIn: 1,	 nOut: 	0	 in 19.3s
# 		 nIn: 1,	 nOut: 	0	 in 19.6s
# 		 nIn: 1,	 nOut: 	0	 in 19.9s
# 		 nIn: 1,	 nOut: 	0	 in 20.2s
# 		 nIn: 1,	 nOut: 	0	 in 20.5s
# 		 nIn: 1,	 nOut: 	0	 in 20.9s
# 		 nIn: 1,	 nOut: 	0	 in 21.2s
# 		 nIn: 1,	 nOut: 	0	 in 21.6s
# 		 nIn: 1,	 nOut: 	0	 in 21.9s
# 		 nIn: 1,	 nOut: 	0	 in 22.2s
# 		 nIn: 1,	 nOut: 	0	 in 22.5s
# 		 nIn: 1,	 nOut: 	0	 in 22.8s
# 		 nIn: 1,	 nOut: 	1	 in 23.1s
# 		 nIn: 1,	 nOut: 	0	 in 23.4s
# 		 nIn: 1,	 nOut: 	1	 in 23.6s
# 		 nIn: 1,	 nOut: 	0	 in 24.0s
# 		 nIn: 1,	 nOut: 	1	 in 24.2s
# 		 nIn: 1,	 nOut: 	0	 in 24.4s
# 		 nIn: 1,	 nOut: 	0	 in 24.6s
# 		 nIn: 1,	 nOut: 	1	 in 24.8s
# 		 nIn: 1,	 nOut: 	1	 in 25.0s
# 		 nIn: 1,	 nOut: 	0	 in 25.3s
# 		 nIn: 1,	 nOut: 	0	 in 25.4s
# 		 nIn: 1,	 nOut: 	0	 in 25.6s
# 		 nIn: 1,	 nOut: 	0	 in 25.9s
# 		 nIn: 1,	 nOut: 	0	 in 26.2s
# 		 nIn: 1,	 nOut: 	1	 in 26.4s
# 		 nIn: 1,	 nOut: 	0	 in 26.6s
# 		 nIn: 1,	 nOut: 	0	 in 26.8s
# 		 nIn: 1,	 nOut: 	0	 in 27.1s
# 		 nIn: 1,	 nOut: 	0	 in 27.3s
# 		 nIn: 1,	 nOut: 	0	 in 27.6s
# 		 nIn: 1,	 nOut: 	1	 in 28.0s
# 		 nIn: 1,	 nOut: 	0	 in 28.2s
# 		 nIn: 1,	 nOut: 	0	 in 28.5s
# 		 nIn: 1,	 nOut: 	0	 in 28.7s
# 		 nIn: 1,	 nOut: 	0	 in 28.9s
# 		 nIn: 1,	 nOut: 	0	 in 29.1s
# 		 nIn: 1,	 nOut: 	0	 in 29.5s
# 		 nIn: 1,	 nOut: 	0	 in 29.7s
# 		 nIn: 1,	 nOut: 	0	 in 29.9s
# 		 nIn: 1,	 nOut: 	0	 in 30.1s
# 		 nIn: 1,	 nOut: 	0	 in 30.4s
# 		 nIn: 1,	 nOut: 	0	 in 30.6s
# 		 nIn: 1,	 nOut: 	1	 in 30.8s
# 		 nIn: 1,	 nOut: 	0	 in 31.0s
# 		 nIn: 1,	 nOut: 	0	 in 31.2s
# 		 nIn: 1,	 nOut: 	1	 in 31.4s
# 		 nIn: 1,	 nOut: 	0	 in 31.6s
# 		 nIn: 1,	 nOut: 	0	 in 31.9s
# 		 nIn: 1,	 nOut: 	0	 in 32.1s
# 		 nIn: 1,	 nOut: 	0	 in 32.3s
# 		 nIn: 1,	 nOut: 	0	 in 32.5s
# 		 nIn: 1,	 nOut: 	1	 in 32.8s
# 		 nIn: 1,	 nOut: 	1	 in 33.1s
# 		 nIn: 1,	 nOut: 	0	 in 33.3s
# 		 nIn: 1,	 nOut: 	0	 in 33.6s
# 		 nIn: 1,	 nOut: 	0	 in 33.8s
# 		 nIn: 1,	 nOut: 	0	 in 34.2s
# 		 nIn: 1,	 nOut: 	0	 in 34.5s
# 		 nIn: 1,	 nOut: 	1	 in 34.7s
# 		 nIn: 1,	 nOut: 	0	 in 35.1s
# 		 nIn: 1,	 nOut: 	0	 in 35.3s
# 		 nIn: 1,	 nOut: 	0	 in 35.5s
# 		 nIn: 1,	 nOut: 	0	 in 35.7s
# 		 nIn: 1,	 nOut: 	0	 in 36.0s
# 		 nIn: 1,	 nOut: 	0	 in 36.2s
# 		 nIn: 1,	 nOut: 	0	 in 36.4s
# 		 nIn: 1,	 nOut: 	1	 in 36.6s
# 		 nIn: 1,	 nOut: 	0	 in 36.8s
# 		 nIn: 1,	 nOut: 	1	 in 37.1s
# 		 nIn: 1,	 nOut: 	1	 in 37.3s
# 		 nIn: 1,	 nOut: 	0	 in 37.5s
# 		 nIn: 1,	 nOut: 	0	 in 37.7s
# 		 nIn: 1,	 nOut: 	1	 in 38.0s
# 		 nIn: 1,	 nOut: 	1	 in 38.3s
# 		 nIn: 1,	 nOut: 	1	 in 38.5s
# 		 nIn: 1,	 nOut: 	0	 in 38.7s
# 		 nIn: 1,	 nOut: 	0	 in 39.0s
# 		 nIn: 1,	 nOut: 	0	 in 39.2s
# 		 nIn: 1,	 nOut: 	1	 in 39.4s
# 		 nIn: 1,	 nOut: 	0	 in 39.8s
# 		 nIn: 1,	 nOut: 	0	 in 40.0s
# 		 nIn: 1,	 nOut: 	0	 in 40.2s
# 		 nIn: 1,	 nOut: 	0	 in 40.5s
# 		 nIn: 1,	 nOut: 	1	 in 40.8s
# 		 nIn: 1,	 nOut: 	0	 in 41.0s
# 		 nIn: 1,	 nOut: 	0	 in 41.3s
# 		 nIn: 1,	 nOut: 	0	 in 41.4s
# 		 nIn: 1,	 nOut: 	0	 in 41.7s
# 		 nIn: 1,	 nOut: 	0	 in 41.9s
# 		 nIn: 1,	 nOut: 	0	 in 42.1s
# 		 nIn: 1,	 nOut: 	0	 in 42.3s
# 		 nIn: 1,	 nOut: 	0	 in 42.5s
# 		 nIn: 1,	 nOut: 	0	 in 42.7s
# 		 nIn: 1,	 nOut: 	1	 in 43.0s
# 		 nIn: 1,	 nOut: 	0	 in 43.2s
# 		 nIn: 1,	 nOut: 	0	 in 43.4s
# 		 nIn: 1,	 nOut: 	0	 in 43.6s
# 		 nIn: 1,	 nOut: 	0	 in 43.8s
# 		 nIn: 1,	 nOut: 	0	 in 44.1s
# 		 nIn: 1,	 nOut: 	0	 in 44.3s
# 		 nIn: 1,	 nOut: 	0	 in 44.5s
# 		 nIn: 1,	 nOut: 	0	 in 44.7s
# 		 nIn: 1,	 nOut: 	0	 in 44.9s
# 		 nIn: 1,	 nOut: 	0	 in 45.2s
# 		 nIn: 1,	 nOut: 	0	 in 45.4s
# 		 nIn: 1,	 nOut: 	1	 in 45.7s
# 		 nIn: 1,	 nOut: 	0	 in 45.9s
# 		 nIn: 1,	 nOut: 	0	 in 46.2s
# 		 nIn: 1,	 nOut: 	0	 in 46.4s
# 		 nIn: 1,	 nOut: 	0	 in 46.6s
# 		 nIn: 1,	 nOut: 	0	 in 46.8s
# 		 nIn: 1,	 nOut: 	1	 in 47.0s
# 		 nIn: 1,	 nOut: 	0	 in 47.2s
# 		 nIn: 1,	 nOut: 	0	 in 47.5s
# 		 nIn: 1,	 nOut: 	0	 in 47.8s
# 		 nIn: 1,	 nOut: 	0	 in 48.0s
# 		 nIn: 1,	 nOut: 	1	 in 48.3s
# 		 nIn: 1,	 nOut: 	1	 in 48.5s
# 		 nIn: 1,	 nOut: 	1	 in 48.7s
# 		 nIn: 1,	 nOut: 	0	 in 48.9s
# 		 nIn: 1,	 nOut: 	0	 in 49.2s
# 		 nIn: 1,	 nOut: 	1	 in 49.4s
# 		 nIn: 1,	 nOut: 	1	 in 49.6s
# 		 nIn: 1,	 nOut: 	0	 in 49.8s
# 		 nIn: 1,	 nOut: 	0	 in 50.0s
# 		 nIn: 1,	 nOut: 	0	 in 50.2s
# 		 nIn: 1,	 nOut: 	1	 in 50.4s
# 		 nIn: 1,	 nOut: 	0	 in 50.7s
# 		 nIn: 1,	 nOut: 	1	 in 51.0s
# 		 nIn: 1,	 nOut: 	0	 in 51.3s
# 		 nIn: 1,	 nOut: 	0	 in 51.5s
# 		 nIn: 1,	 nOut: 	0	 in 51.7s
# 		 nIn: 1,	 nOut: 	1	 in 51.9s
# 		 nIn: 1,	 nOut: 	0	 in 52.1s
# 		 nIn: 1,	 nOut: 	1	 in 52.4s
# 		 nIn: 1,	 nOut: 	1	 in 52.6s
# 		 nIn: 1,	 nOut: 	0	 in 52.8s
# 		 nIn: 1,	 nOut: 	0	 in 53.0s
# 		 nIn: 1,	 nOut: 	0	 in 53.2s
# 		 nIn: 1,	 nOut: 	1	 in 53.5s
# 		 nIn: 1,	 nOut: 	0	 in 53.7s
# 		 nIn: 1,	 nOut: 	0	 in 53.9s
# 		 nIn: 1,	 nOut: 	0	 in 54.1s
# 		 nIn: 1,	 nOut: 	0	 in 54.4s
# 		 nIn: 1,	 nOut: 	0	 in 54.7s
# 		 nIn: 1,	 nOut: 	0	 in 54.9s
# 		 nIn: 1,	 nOut: 	0	 in 55.2s
# 		 nIn: 1,	 nOut: 	0	 in 55.4s
# 		 nIn: 1,	 nOut: 	0	 in 55.6s
# 		 nIn: 1,	 nOut: 	0	 in 55.9s
# 		 nIn: 1,	 nOut: 	0	 in 56.1s
# 		 nIn: 1,	 nOut: 	1	 in 56.4s
# 		 nIn: 1,	 nOut: 	0	 in 56.7s
# 		 nIn: 1,	 nOut: 	0	 in 56.9s
# 		 nIn: 1,	 nOut: 	1	 in 57.1s
# 		 nIn: 1,	 nOut: 	0	 in 57.4s
# 		 nIn: 1,	 nOut: 	0	 in 57.6s
# 		 nIn: 1,	 nOut: 	0	 in 57.9s
# 		 nIn: 1,	 nOut: 	0	 in 58.2s
# 		 nIn: 1,	 nOut: 	1	 in 58.4s
# 		 nIn: 1,	 nOut: 	0	 in 58.7s
# 		 nIn: 1,	 nOut: 	1	 in 58.9s
# 		 nIn: 1,	 nOut: 	0	 in 59.2s
# 		 nIn: 1,	 nOut: 	0	 in 59.5s
# 		 nIn: 1,	 nOut: 	0	 in 59.8s
# 		 nIn: 1,	 nOut: 	0	 in 60.0s
# 		 nIn: 1,	 nOut: 	0	 in 60.2s
# 		 nIn: 1,	 nOut: 	0	 in 60.5s
# 		 nIn: 1,	 nOut: 	0	 in 60.7s
# 		 nIn: 1,	 nOut: 	1	 in 60.9s
# 		 nIn: 1,	 nOut: 	0	 in 61.2s
# 		 nIn: 1,	 nOut: 	0	 in 61.4s
# 		 nIn: 1,	 nOut: 	1	 in 61.6s
# 		 nIn: 1,	 nOut: 	0	 in 61.8s
# 		 nIn: 1,	 nOut: 	0	 in 62.2s
# 		 nIn: 1,	 nOut: 	0	 in 62.4s
# 		 nIn: 1,	 nOut: 	0	 in 62.6s
# 		 nIn: 1,	 nOut: 	0	 in 62.9s
# 		 nIn: 1,	 nOut: 	0	 in 63.1s
# 		 nIn: 1,	 nOut: 	1	 in 63.3s
# 		 nIn: 1,	 nOut: 	0	 in 63.6s
# 		 nIn: 1,	 nOut: 	1	 in 63.9s
# 		 nIn: 1,	 nOut: 	0	 in 64.1s
# 		 nIn: 1,	 nOut: 	0	 in 64.4s
# 		 nIn: 1,	 nOut: 	0	 in 64.7s
# 		 nIn: 1,	 nOut: 	0	 in 65.1s
# 		 nIn: 1,	 nOut: 	0	 in 65.4s
# 		 nIn: 1,	 nOut: 	0	 in 65.6s
# 		 nIn: 1,	 nOut: 	0	 in 65.9s
# 		 nIn: 1,	 nOut: 	0	 in 66.2s
# 		 nIn: 1,	 nOut: 	0	 in 66.4s
# 		 nIn: 1,	 nOut: 	1	 in 66.6s
# 		 nIn: 1,	 nOut: 	0	 in 66.9s
# 		 nIn: 1,	 nOut: 	0	 in 67.1s
# 		 nIn: 1,	 nOut: 	1	 in 67.4s
# 		 nIn: 1,	 nOut: 	1	 in 67.6s
# 		 nIn: 1,	 nOut: 	0	 in 67.9s
# 		 nIn: 1,	 nOut: 	1	 in 68.3s
# 		 nIn: 1,	 nOut: 	0	 in 68.5s
# 		 nIn: 1,	 nOut: 	0	 in 69.0s
# 		 nIn: 1,	 nOut: 	1	 in 69.4s
# 		 nIn: 1,	 nOut: 	1	 in 69.9s
# 		 nIn: 1,	 nOut: 	0	 in 70.1s
# 		 nIn: 1,	 nOut: 	0	 in 70.5s
# 		 nIn: 1,	 nOut: 	0	 in 71.0s
# 		 nIn: 1,	 nOut: 	1	 in 71.2s
# 		 nIn: 1,	 nOut: 	1	 in 71.5s
# 		 nIn: 1,	 nOut: 	1	 in 71.8s
# 		 nIn: 1,	 nOut: 	0	 in 72.1s
# 		 nIn: 1,	 nOut: 	1	 in 72.3s
# 		 nIn: 1,	 nOut: 	0	 in 72.7s
# 		 nIn: 1,	 nOut: 	0	 in 73.0s
# 		 nIn: 1,	 nOut: 	0	 in 73.3s
# 		 nIn: 1,	 nOut: 	0	 in 73.8s
# 		 nIn: 1,	 nOut: 	0	 in 74.1s
# 		 nIn: 1,	 nOut: 	0	 in 74.5s
# 		 nIn: 1,	 nOut: 	0	 in 74.8s
# 		 nIn: 1,	 nOut: 	0	 in 75.0s
# 		 nIn: 1,	 nOut: 	0	 in 75.3s
# 		 nIn: 1,	 nOut: 	0	 in 75.5s
# 		 nIn: 1,	 nOut: 	0	 in 75.8s
# 		 nIn: 1,	 nOut: 	0	 in 76.0s
# 		 nIn: 1,	 nOut: 	0	 in 76.3s
# 		 nIn: 1,	 nOut: 	1	 in 76.5s
# 		 nIn: 1,	 nOut: 	0	 in 76.7s
# 		 nIn: 1,	 nOut: 	1	 in 76.9s
# 		 nIn: 1,	 nOut: 	0	 in 77.2s
# 		 nIn: 1,	 nOut: 	0	 in 77.4s
# 		 nIn: 1,	 nOut: 	0	 in 77.7s
# 		 nIn: 1,	 nOut: 	0	 in 77.9s
# 		 nIn: 1,	 nOut: 	0	 in 78.1s
# 		 nIn: 1,	 nOut: 	0	 in 78.4s
# 		 nIn: 1,	 nOut: 	0	 in 78.6s
# 		 nIn: 1,	 nOut: 	0	 in 78.9s
# 		 nIn: 1,	 nOut: 	0	 in 79.1s
# 		 nIn: 1,	 nOut: 	0	 in 79.3s
# 		 nIn: 1,	 nOut: 	0	 in 79.5s
# 		 nIn: 1,	 nOut: 	0	 in 79.9s
# 		 nIn: 1,	 nOut: 	0	 in 80.1s
# 		 nIn: 1,	 nOut: 	0	 in 80.3s
# 		 nIn: 1,	 nOut: 	0	 in 80.5s
# 		 nIn: 1,	 nOut: 	0	 in 80.7s
# 		 nIn: 1,	 nOut: 	1	 in 80.9s
# 		 nIn: 1,	 nOut: 	0	 in 81.1s
# 		 nIn: 1,	 nOut: 	0	 in 81.3s
# 		 nIn: 1,	 nOut: 	0	 in 81.5s
# 		 nIn: 1,	 nOut: 	0	 in 81.7s
# 		 nIn: 1,	 nOut: 	1	 in 81.8s
# 		 nIn: 1,	 nOut: 	0	 in 82.0s
# 		 nIn: 1,	 nOut: 	0	 in 82.2s
# 		 nIn: 1,	 nOut: 	0	 in 82.4s
# 		 nIn: 1,	 nOut: 	1	 in 82.6s
# 		 nIn: 1,	 nOut: 	0	 in 82.8s
# 		 nIn: 1,	 nOut: 	0	 in 83.0s
# 		 nIn: 1,	 nOut: 	0	 in 83.2s
# 		 nIn: 1,	 nOut: 	0	 in 83.4s
# 		 nIn: 1,	 nOut: 	0	 in 83.6s
# 		 nIn: 1,	 nOut: 	0	 in 83.8s
# 		 nIn: 1,	 nOut: 	0	 in 83.9s
# 		 nIn: 1,	 nOut: 	1	 in 84.1s
# 		 nIn: 1,	 nOut: 	1	 in 84.2s
# 		 nIn: 1,	 nOut: 	1	 in 84.4s
# 		 nIn: 1,	 nOut: 	1	 in 84.5s
# 		 nIn: 1,	 nOut: 	0	 in 84.7s
# 		 nIn: 1,	 nOut: 	0	 in 84.8s
# 		 nIn: 1,	 nOut: 	1	 in 85.0s
# 		 nIn: 1,	 nOut: 	0	 in 85.1s
# 		 nIn: 1,	 nOut: 	0	 in 85.3s
# 		 nIn: 1,	 nOut: 	0	 in 85.4s
# 		 nIn: 1,	 nOut: 	0	 in 85.6s
# 		 nIn: 1,	 nOut: 	0	 in 85.7s
# 		 nIn: 1,	 nOut: 	0	 in 86.0s
# 		 nIn: 1,	 nOut: 	0	 in 86.2s
# 		 nIn: 1,	 nOut: 	0	 in 86.4s
# 		 nIn: 1,	 nOut: 	0	 in 86.5s
# 		 nIn: 1,	 nOut: 	1	 in 86.7s
# 		 nIn: 1,	 nOut: 	1	 in 86.8s
# 		 nIn: 1,	 nOut: 	0	 in 86.9s
# 		 nIn: 1,	 nOut: 	0	 in 87.1s
# 		 nIn: 1,	 nOut: 	0	 in 87.2s
# 		 nIn: 1,	 nOut: 	0	 in 87.4s
# 		 nIn: 1,	 nOut: 	1	 in 87.5s
# 		 nIn: 1,	 nOut: 	1	 in 87.7s
# 		 nIn: 1,	 nOut: 	1	 in 87.9s
# 		 nIn: 1,	 nOut: 	1	 in 88.0s
# 		 nIn: 1,	 nOut: 	0	 in 88.2s
# 		 nIn: 1,	 nOut: 	0	 in 88.3s
# 		 nIn: 1,	 nOut: 	0	 in 88.5s
# 		 nIn: 1,	 nOut: 	1	 in 88.6s
# 		 nIn: 1,	 nOut: 	0	 in 88.8s
# 		 nIn: 1,	 nOut: 	1	 in 88.9s
# 		 nIn: 1,	 nOut: 	1	 in 89.1s
# 		 nIn: 1,	 nOut: 	1	 in 89.2s
# 		 nIn: 1,	 nOut: 	0	 in 89.4s
# 		 nIn: 1,	 nOut: 	0	 in 89.5s
# 		 nIn: 1,	 nOut: 	0	 in 89.7s
# 		 nIn: 1,	 nOut: 	0	 in 89.9s
# 		 nIn: 1,	 nOut: 	0	 in 90.1s
# 		 nIn: 1,	 nOut: 	1	 in 90.2s
# 		 nIn: 1,	 nOut: 	0	 in 90.4s
# 		 nIn: 1,	 nOut: 	0	 in 90.5s
# 		 nIn: 1,	 nOut: 	1	 in 90.7s
# 		 nIn: 1,	 nOut: 	0	 in 90.9s
# 		 nIn: 1,	 nOut: 	0	 in 91.0s
# 		 nIn: 1,	 nOut: 	0	 in 91.2s
# 		 nIn: 1,	 nOut: 	0	 in 91.3s
# 		 nIn: 1,	 nOut: 	1	 in 91.5s
# 		 nIn: 1,	 nOut: 	0	 in 91.6s
# 		 nIn: 1,	 nOut: 	0	 in 91.7s
# 		 nIn: 1,	 nOut: 	0	 in 91.9s
# 		 nIn: 1,	 nOut: 	0	 in 92.1s
# 		 nIn: 1,	 nOut: 	1	 in 92.2s
# 		 nIn: 1,	 nOut: 	0	 in 92.3s
# 		 nIn: 1,	 nOut: 	0	 in 92.5s
# 		 nIn: 1,	 nOut: 	0	 in 92.7s
# 		 nIn: 1,	 nOut: 	0	 in 92.8s
# 		 nIn: 1,	 nOut: 	0	 in 93.0s
# 		 nIn: 1,	 nOut: 	0	 in 93.1s
# 		 nIn: 1,	 nOut: 	0	 in 93.3s
# 		 nIn: 1,	 nOut: 	0	 in 93.4s
# 		 nIn: 1,	 nOut: 	0	 in 93.6s
# 		 nIn: 1,	 nOut: 	0	 in 93.7s
# 		 nIn: 1,	 nOut: 	0	 in 93.9s
# 		 nIn: 1,	 nOut: 	1	 in 94.0s
# 		 nIn: 1,	 nOut: 	0	 in 94.2s
# 		 nIn: 1,	 nOut: 	1	 in 94.4s
# 		 nIn: 1,	 nOut: 	0	 in 94.6s
# 		 nIn: 1,	 nOut: 	0	 in 94.7s
# 		 nIn: 1,	 nOut: 	0	 in 94.9s
# 		 nIn: 1,	 nOut: 	0	 in 95.0s
# 		 nIn: 1,	 nOut: 	1	 in 95.2s
# 		 nIn: 1,	 nOut: 	0	 in 95.3s
# 		 nIn: 1,	 nOut: 	1	 in 95.5s
# 		 nIn: 1,	 nOut: 	0	 in 95.6s
# 		 nIn: 1,	 nOut: 	0	 in 95.8s
# 		 nIn: 1,	 nOut: 	0	 in 95.9s
# 		 nIn: 1,	 nOut: 	1	 in 96.1s
# 		 nIn: 1,	 nOut: 	1	 in 96.3s
# 		 nIn: 1,	 nOut: 	0	 in 96.4s
# 		 nIn: 1,	 nOut: 	0	 in 96.6s
# 		 nIn: 1,	 nOut: 	0	 in 96.7s
# 		 nIn: 1,	 nOut: 	0	 in 96.9s
# 		 nIn: 1,	 nOut: 	0	 in 97.0s
# 		 nIn: 1,	 nOut: 	1	 in 97.1s
# 		 nIn: 1,	 nOut: 	0	 in 97.3s
# 		 nIn: 1,	 nOut: 	0	 in 97.4s
# 		 nIn: 1,	 nOut: 	1	 in 97.7s
# 		 nIn: 1,	 nOut: 	0	 in 97.9s
# 		 nIn: 1,	 nOut: 	0	 in 98.0s
# 		 nIn: 1,	 nOut: 	0	 in 98.2s
# 		 nIn: 1,	 nOut: 	0	 in 98.3s
# 		 nIn: 1,	 nOut: 	0	 in 98.5s
# 		 nIn: 1,	 nOut: 	0	 in 98.6s
# 		 nIn: 1,	 nOut: 	1	 in 98.7s
# 		 nIn: 1,	 nOut: 	0	 in 98.9s
# 		 nIn: 1,	 nOut: 	0	 in 99.0s
# 		 nIn: 1,	 nOut: 	0	 in 99.2s
# 		 nIn: 1,	 nOut: 	0	 in 99.3s
# 		 nIn: 1,	 nOut: 	1	 in 99.5s
# 		 nIn: 1,	 nOut: 	1	 in 99.7s
# 		 nIn: 1,	 nOut: 	0	 in 99.8s
# 		 nIn: 1,	 nOut: 	0	 in 100.0s
# 		 nIn: 1,	 nOut: 	1	 in 100.1s
# 		 nIn: 1,	 nOut: 	1	 in 100.3s
# 		 nIn: 1,	 nOut: 	0	 in 100.4s
# 		 nIn: 1,	 nOut: 	0	 in 100.6s
# 		 nIn: 1,	 nOut: 	0	 in 100.7s
# 		 nIn: 1,	 nOut: 	1	 in 101.0s
# 		 nIn: 1,	 nOut: 	0	 in 101.2s
# 		 nIn: 1,	 nOut: 	0	 in 101.3s
# 		 nIn: 1,	 nOut: 	0	 in 101.5s
# 		 nIn: 1,	 nOut: 	0	 in 101.6s
# 		 nIn: 1,	 nOut: 	1	 in 101.8s
# 		 nIn: 1,	 nOut: 	0	 in 101.9s
# 		 nIn: 1,	 nOut: 	0	 in 102.1s
# 		 nIn: 1,	 nOut: 	0	 in 102.2s
# 		 nIn: 1,	 nOut: 	0	 in 102.4s
# 		 nIn: 1,	 nOut: 	1	 in 102.5s
# 		 nIn: 1,	 nOut: 	0	 in 102.6s
# 		 nIn: 1,	 nOut: 	0	 in 102.8s
# 		 nIn: 1,	 nOut: 	0	 in 102.9s
# 		 nIn: 1,	 nOut: 	1	 in 103.1s
# 		 nIn: 1,	 nOut: 	1	 in 103.2s
# 		 nIn: 1,	 nOut: 	1	 in 103.4s
# 		 nIn: 1,	 nOut: 	0	 in 103.5s
# 		 nIn: 1,	 nOut: 	0	 in 103.7s
# 		 nIn: 1,	 nOut: 	0	 in 103.9s
# 		 nIn: 1,	 nOut: 	1	 in 104.0s
# 		 nIn: 1,	 nOut: 	1	 in 104.3s
# 		 nIn: 1,	 nOut: 	0	 in 104.5s
# 		 nIn: 1,	 nOut: 	0	 in 104.6s
# 		 nIn: 1,	 nOut: 	0	 in 104.9s
# 		 nIn: 1,	 nOut: 	0	 in 105.0s
# 		 nIn: 1,	 nOut: 	1	 in 105.2s
# 		 nIn: 1,	 nOut: 	0	 in 105.4s
# 		 nIn: 1,	 nOut: 	0	 in 105.5s
# 		 nIn: 1,	 nOut: 	0	 in 105.7s
# 		 nIn: 1,	 nOut: 	1	 in 105.8s
# 		 nIn: 1,	 nOut: 	0	 in 106.0s
# 		 nIn: 1,	 nOut: 	0	 in 106.1s
# 		 nIn: 1,	 nOut: 	0	 in 106.3s
# 		 nIn: 1,	 nOut: 	1	 in 106.4s
# 		 nIn: 1,	 nOut: 	0	 in 106.6s
# 		 nIn: 1,	 nOut: 	0	 in 106.7s
# 		 nIn: 1,	 nOut: 	0	 in 106.9s
# 		 nIn: 1,	 nOut: 	0	 in 107.0s
# 		 nIn: 1,	 nOut: 	0	 in 107.2s
# 		 nIn: 1,	 nOut: 	0	 in 107.3s
# 		 nIn: 1,	 nOut: 	0	 in 107.5s
# 		 nIn: 1,	 nOut: 	0	 in 107.6s
# 		 nIn: 1,	 nOut: 	0	 in 107.8s
# 		 nIn: 1,	 nOut: 	1	 in 107.9s
# 		 nIn: 1,	 nOut: 	0	 in 108.2s
# 		 nIn: 1,	 nOut: 	1	 in 108.4s
# 		 nIn: 1,	 nOut: 	0	 in 108.5s
# 		 nIn: 1,	 nOut: 	0	 in 108.7s
# 		 nIn: 1,	 nOut: 	0	 in 108.8s
# 		 nIn: 1,	 nOut: 	0	 in 109.0s
# 		 nIn: 1,	 nOut: 	1	 in 109.1s
# 		 nIn: 1,	 nOut: 	0	 in 109.3s
# 		 nIn: 1,	 nOut: 	0	 in 109.4s
# 		 nIn: 1,	 nOut: 	0	 in 109.6s
# 		 nIn: 1,	 nOut: 	0	 in 109.7s
# 		 nIn: 1,	 nOut: 	0	 in 109.9s
# 		 nIn: 1,	 nOut: 	0	 in 110.0s
# 		 nIn: 1,	 nOut: 	0	 in 110.2s
# 		 nIn: 1,	 nOut: 	0	 in 110.3s
# 		 nIn: 1,	 nOut: 	0	 in 110.5s
# 		 nIn: 1,	 nOut: 	0	 in 110.6s
# 		 nIn: 1,	 nOut: 	0	 in 110.8s
# 		 nIn: 1,	 nOut: 	1	 in 110.9s
# 		 nIn: 1,	 nOut: 	1	 in 111.2s
# 		 nIn: 1,	 nOut: 	1	 in 111.4s
# 		 nIn: 1,	 nOut: 	0	 in 111.5s
# 		 nIn: 1,	 nOut: 	0	 in 111.7s
# 		 nIn: 1,	 nOut: 	1	 in 111.8s
# 		 nIn: 1,	 nOut: 	0	 in 112.0s
# 		 nIn: 1,	 nOut: 	1	 in 112.1s
# 		 nIn: 1,	 nOut: 	1	 in 112.3s
# 		 nIn: 1,	 nOut: 	0	 in 112.4s
# 		 nIn: 1,	 nOut: 	0	 in 112.6s
# 		 nIn: 1,	 nOut: 	0	 in 112.7s
# 		 nIn: 1,	 nOut: 	0	 in 112.9s
# 		 nIn: 1,	 nOut: 	0	 in 113.0s
# 		 nIn: 1,	 nOut: 	1	 in 113.2s
# 		 nIn: 1,	 nOut: 	0	 in 113.3s
# 		 nIn: 1,	 nOut: 	0	 in 113.5s
# 		 nIn: 1,	 nOut: 	0	 in 113.6s
# 		 nIn: 1,	 nOut: 	0	 in 113.8s
# 		 nIn: 1,	 nOut: 	1	 in 113.9s
# 		 nIn: 1,	 nOut: 	0	 in 114.2s
# 		 nIn: 1,	 nOut: 	1	 in 114.3s
# 		 nIn: 1,	 nOut: 	1	 in 114.5s
# 		 nIn: 1,	 nOut: 	0	 in 114.7s
# 		 nIn: 1,	 nOut: 	0	 in 114.8s
# 		 nIn: 1,	 nOut: 	1	 in 115.0s
# 		 nIn: 1,	 nOut: 	1	 in 115.1s
# 		 nIn: 1,	 nOut: 	0	 in 115.3s
# 		 nIn: 1,	 nOut: 	0	 in 115.4s
# 		 nIn: 1,	 nOut: 	0	 in 115.6s
# 		 nIn: 1,	 nOut: 	0	 in 115.7s
# 		 nIn: 1,	 nOut: 	0	 in 115.9s
# 		 nIn: 1,	 nOut: 	1	 in 116.0s
# 		 nIn: 1,	 nOut: 	0	 in 116.2s
# 		 nIn: 1,	 nOut: 	1	 in 116.3s
# 		 nIn: 1,	 nOut: 	0	 in 116.5s
# 		 nIn: 1,	 nOut: 	0	 in 116.6s
# 		 nIn: 1,	 nOut: 	0	 in 116.8s
# 		 nIn: 1,	 nOut: 	0	 in 116.9s
# 		 nIn: 1,	 nOut: 	0	 in 117.2s
# 		 nIn: 1,	 nOut: 	0	 in 117.4s
# 		 nIn: 1,	 nOut: 	1	 in 117.5s
# 		 nIn: 1,	 nOut: 	0	 in 117.7s
# 		 nIn: 1,	 nOut: 	0	 in 117.8s
# 		 nIn: 1,	 nOut: 	0	 in 118.0s
# 		 nIn: 1,	 nOut: 	0	 in 118.1s
# 		 nIn: 1,	 nOut: 	0	 in 118.3s
# 		 nIn: 1,	 nOut: 	1	 in 118.4s
# 		 nIn: 1,	 nOut: 	0	 in 118.6s
# 		 nIn: 1,	 nOut: 	0	 in 118.7s
# 		 nIn: 1,	 nOut: 	0	 in 118.9s
# 		 nIn: 1,	 nOut: 	0	 in 119.0s
# 		 nIn: 1,	 nOut: 	0	 in 119.2s
# 		 nIn: 1,	 nOut: 	1	 in 119.3s
# 		 nIn: 1,	 nOut: 	0	 in 119.5s
# 		 nIn: 1,	 nOut: 	0	 in 119.6s
# 		 nIn: 1,	 nOut: 	0	 in 119.8s
# 		 nIn: 1,	 nOut: 	1	 in 119.9s
# 		 nIn: 1,	 nOut: 	0	 in 120.1s
# 		 nIn: 1,	 nOut: 	1	 in 120.2s
# 		 nIn: 1,	 nOut: 	1	 in 120.5s
# 		 nIn: 1,	 nOut: 	1	 in 120.7s
# 		 nIn: 1,	 nOut: 	0	 in 120.8s
# 		 nIn: 1,	 nOut: 	0	 in 121.0s
# 		 nIn: 1,	 nOut: 	0	 in 121.1s
# 		 nIn: 1,	 nOut: 	1	 in 121.3s
# 		 nIn: 1,	 nOut: 	0	 in 121.4s
# 		 nIn: 1,	 nOut: 	1	 in 121.6s
# 		 nIn: 1,	 nOut: 	0	 in 121.8s
# 		 nIn: 1,	 nOut: 	1	 in 121.9s
# 		 nIn: 1,	 nOut: 	1	 in 122.1s
# 		 nIn: 1,	 nOut: 	0	 in 122.2s
# 		 nIn: 1,	 nOut: 	0	 in 122.3s
# 		 nIn: 1,	 nOut: 	0	 in 122.5s
# 		 nIn: 1,	 nOut: 	0	 in 122.7s
# 		 nIn: 1,	 nOut: 	0	 in 122.8s
# 		 nIn: 1,	 nOut: 	1	 in 123.0s
# 		 nIn: 1,	 nOut: 	0	 in 123.1s
# 		 nIn: 1,	 nOut: 	0	 in 123.2s
# 		 nIn: 1,	 nOut: 	1	 in 123.5s
# 		 nIn: 1,	 nOut: 	0	 in 123.8s
# 		 nIn: 1,	 nOut: 	0	 in 124.1s
# 		 nIn: 1,	 nOut: 	0	 in 124.3s
# 		 nIn: 1,	 nOut: 	0	 in 124.5s
# 		 nIn: 1,	 nOut: 	0	 in 124.6s
# 		 nIn: 1,	 nOut: 	0	 in 124.8s
# 		 nIn: 1,	 nOut: 	0	 in 124.9s
# 		 nIn: 1,	 nOut: 	0	 in 125.1s
# 		 nIn: 1,	 nOut: 	1	 in 125.2s
# 		 nIn: 1,	 nOut: 	0	 in 125.4s
# 		 nIn: 1,	 nOut: 	0	 in 125.5s
# 		 nIn: 1,	 nOut: 	0	 in 125.7s
# 		 nIn: 1,	 nOut: 	0	 in 125.9s
# 		 nIn: 1,	 nOut: 	1	 in 126.1s
# 		 nIn: 1,	 nOut: 	0	 in 126.3s
# 		 nIn: 1,	 nOut: 	0	 in 126.4s
# 		 nIn: 1,	 nOut: 	1	 in 126.6s
# 		 nIn: 1,	 nOut: 	1	 in 126.7s
# 		 nIn: 1,	 nOut: 	0	 in 126.9s
# 		 nIn: 1,	 nOut: 	1	 in 127.1s
# 		 nIn: 1,	 nOut: 	0	 in 127.2s
# 		 nIn: 1,	 nOut: 	0	 in 127.4s
# 		 nIn: 1,	 nOut: 	1	 in 127.5s
# 		 nIn: 1,	 nOut: 	0	 in 127.7s
# 		 nIn: 1,	 nOut: 	1	 in 127.8s
# 		 nIn: 1,	 nOut: 	1	 in 128.0s
# 		 nIn: 1,	 nOut: 	0	 in 128.1s
# 		 nIn: 1,	 nOut: 	1	 in 128.3s
# 		 nIn: 1,	 nOut: 	0	 in 128.4s
# 		 nIn: 1,	 nOut: 	1	 in 128.6s
# 		 nIn: 1,	 nOut: 	0	 in 128.7s
# 		 nIn: 1,	 nOut: 	0	 in 128.9s
# 		 nIn: 1,	 nOut: 	0	 in 129.1s
# 		 nIn: 1,	 nOut: 	0	 in 129.3s
# 		 nIn: 1,	 nOut: 	0	 in 129.4s
# 		 nIn: 1,	 nOut: 	0	 in 129.6s
# 		 nIn: 1,	 nOut: 	0	 in 129.7s
# 		 nIn: 1,	 nOut: 	0	 in 129.9s
# 		 nIn: 1,	 nOut: 	0	 in 130.0s
# 		 nIn: 1,	 nOut: 	1	 in 130.2s
# 		 nIn: 1,	 nOut: 	0	 in 130.3s
# 		 nIn: 1,	 nOut: 	0	 in 130.5s
# 		 nIn: 1,	 nOut: 	0	 in 130.6s
# 		 nIn: 1,	 nOut: 	0	 in 130.8s
# 		 nIn: 1,	 nOut: 	1	 in 131.0s
# 		 nIn: 1,	 nOut: 	0	 in 131.1s
# 		 nIn: 1,	 nOut: 	1	 in 131.2s
# 		 nIn: 1,	 nOut: 	0	 in 131.4s
# 		 nIn: 1,	 nOut: 	0	 in 131.5s
# 		 nIn: 1,	 nOut: 	0	 in 131.7s
# 		 nIn: 1,	 nOut: 	0	 in 131.9s
# 		 nIn: 1,	 nOut: 	0	 in 132.1s
# 		 nIn: 1,	 nOut: 	0	 in 132.3s
# 		 nIn: 1,	 nOut: 	0	 in 132.5s
# 		 nIn: 1,	 nOut: 	1	 in 132.6s
# 		 nIn: 1,	 nOut: 	1	 in 132.8s
# 		 nIn: 1,	 nOut: 	1	 in 132.9s
# 		 nIn: 1,	 nOut: 	0	 in 133.1s
# 		 nIn: 1,	 nOut: 	1	 in 133.2s
# 		 nIn: 1,	 nOut: 	1	 in 133.4s
# 		 nIn: 1,	 nOut: 	0	 in 133.6s
# 		 nIn: 1,	 nOut: 	0	 in 133.7s
# 		 nIn: 1,	 nOut: 	1	 in 133.9s
# 		 nIn: 1,	 nOut: 	0	 in 134.0s
# 		 nIn: 1,	 nOut: 	1	 in 134.2s
# 		 nIn: 1,	 nOut: 	0	 in 134.3s
# 		 nIn: 1,	 nOut: 	0	 in 134.5s
# 		 nIn: 1,	 nOut: 	0	 in 134.6s
# 		 nIn: 1,	 nOut: 	0	 in 134.9s
# 		 nIn: 1,	 nOut: 	0	 in 135.0s
# 		 nIn: 1,	 nOut: 	0	 in 135.2s
# 		 nIn: 1,	 nOut: 	1	 in 135.3s
# 		 nIn: 1,	 nOut: 	0	 in 135.5s
# 		 nIn: 1,	 nOut: 	0	 in 135.6s
# 		 nIn: 1,	 nOut: 	1	 in 135.8s
# 		 nIn: 1,	 nOut: 	0	 in 136.0s
# 		 nIn: 1,	 nOut: 	1	 in 136.1s
# 		 nIn: 1,	 nOut: 	0	 in 136.3s
# 		 nIn: 1,	 nOut: 	0	 in 136.4s
# 		 nIn: 1,	 nOut: 	0	 in 136.6s
# 		 nIn: 1,	 nOut: 	0	 in 136.7s
# 		 nIn: 1,	 nOut: 	0	 in 136.9s
# 		 nIn: 1,	 nOut: 	0	 in 137.0s
# 		 nIn: 1,	 nOut: 	1	 in 137.3s
# 		 nIn: 1,	 nOut: 	1	 in 137.5s
# 		 nIn: 1,	 nOut: 	0	 in 137.6s
# 		 nIn: 1,	 nOut: 	0	 in 137.8s
# 		 nIn: 1,	 nOut: 	0	 in 137.9s
# 		 nIn: 1,	 nOut: 	0	 in 138.1s
# 		 nIn: 1,	 nOut: 	0	 in 138.2s
# 		 nIn: 1,	 nOut: 	0	 in 138.4s
# 		 nIn: 1,	 nOut: 	1	 in 138.5s
# 		 nIn: 1,	 nOut: 	1	 in 138.7s
# 		 nIn: 1,	 nOut: 	1	 in 138.8s
# 		 nIn: 1,	 nOut: 	0	 in 139.0s
# 		 nIn: 1,	 nOut: 	1	 in 139.1s
# 		 nIn: 1,	 nOut: 	1	 in 139.3s
# 		 nIn: 1,	 nOut: 	0	 in 139.5s
# 		 nIn: 1,	 nOut: 	1	 in 139.7s
# 		 nIn: 1,	 nOut: 	0	 in 139.9s
# 		 nIn: 1,	 nOut: 	0	 in 140.1s
# 		 nIn: 1,	 nOut: 	1	 in 140.2s
# 		 nIn: 1,	 nOut: 	0	 in 140.4s
# 		 nIn: 1,	 nOut: 	0	 in 140.5s
# 		 nIn: 1,	 nOut: 	1	 in 140.7s
# 		 nIn: 1,	 nOut: 	0	 in 140.9s
# 		 nIn: 1,	 nOut: 	1	 in 141.0s
# 		 nIn: 1,	 nOut: 	0	 in 141.2s
# 		 nIn: 1,	 nOut: 	0	 in 141.3s
# 		 nIn: 1,	 nOut: 	0	 in 141.5s
# 		 nIn: 1,	 nOut: 	0	 in 141.6s
# 		 nIn: 1,	 nOut: 	1	 in 141.8s
# 		 nIn: 1,	 nOut: 	1	 in 141.9s
# 		 nIn: 1,	 nOut: 	0	 in 142.2s
# 		 nIn: 1,	 nOut: 	1	 in 142.4s
# 		 nIn: 1,	 nOut: 	0	 in 142.5s
# 		 nIn: 1,	 nOut: 	0	 in 142.7s
# 		 nIn: 1,	 nOut: 	0	 in 142.8s
# 		 nIn: 1,	 nOut: 	1	 in 143.0s
# 		 nIn: 1,	 nOut: 	0	 in 143.1s
# 		 nIn: 1,	 nOut: 	0	 in 143.3s
# 		 nIn: 1,	 nOut: 	0	 in 143.4s
# 		 nIn: 1,	 nOut: 	1	 in 143.6s
# 		 nIn: 1,	 nOut: 	0	 in 143.8s
# 		 nIn: 1,	 nOut: 	0	 in 143.9s
# 		 nIn: 1,	 nOut: 	1	 in 144.1s
# 		 nIn: 1,	 nOut: 	0	 in 144.2s
# 		 nIn: 1,	 nOut: 	0	 in 144.4s
# 		 nIn: 1,	 nOut: 	0	 in 144.5s
# 		 nIn: 1,	 nOut: 	0	 in 144.7s
# 		 nIn: 1,	 nOut: 	1	 in 144.9s
# 		 nIn: 1,	 nOut: 	0	 in 145.1s
# 		 nIn: 1,	 nOut: 	0	 in 145.3s
# 		 nIn: 1,	 nOut: 	0	 in 145.4s
# 		 nIn: 1,	 nOut: 	0	 in 145.6s
# 		 nIn: 1,	 nOut: 	1	 in 145.7s
# 		 nIn: 1,	 nOut: 	0	 in 145.9s
# 		 nIn: 1,	 nOut: 	0	 in 146.0s
# 		 nIn: 1,	 nOut: 	1	 in 146.2s
# 		 nIn: 1,	 nOut: 	0	 in 146.3s
# 		 nIn: 1,	 nOut: 	0	 in 146.5s
# 		 nIn: 1,	 nOut: 	0	 in 146.7s
# 		 nIn: 1,	 nOut: 	1	 in 146.8s
# 		 nIn: 1,	 nOut: 	0	 in 147.0s
# 		 nIn: 1,	 nOut: 	1	 in 147.1s
# 		 nIn: 1,	 nOut: 	0	 in 147.3s
# 		 nIn: 1,	 nOut: 	0	 in 147.4s
# 		 nIn: 1,	 nOut: 	0	 in 147.7s
# 		 nIn: 1,	 nOut: 	0	 in 147.9s
# 		 nIn: 1,	 nOut: 	0	 in 148.0s
# 		 nIn: 1,	 nOut: 	0	 in 148.3s
# 		 nIn: 1,	 nOut: 	1	 in 148.5s
# 		 nIn: 1,	 nOut: 	0	 in 148.6s
# 		 nIn: 1,	 nOut: 	0	 in 148.8s
# 		 nIn: 1,	 nOut: 	1	 in 148.9s
# 		 nIn: 1,	 nOut: 	0	 in 149.1s
# 		 nIn: 1,	 nOut: 	0	 in 149.2s
# 		 nIn: 1,	 nOut: 	0	 in 149.4s
# 		 nIn: 1,	 nOut: 	1	 in 149.6s
# 		 nIn: 1,	 nOut: 	1	 in 149.7s
# ...
# 		 nIn: 1,	 nOut: 	1	 in 142.4s
# 		 nIn: 1,	 nOut: 	1	 in 142.6s
# 		 nIn: 1,	 nOut: 	0	 in 142.7s
# 		 nIn: 1,	 nOut: 	0	 in 142.9s
# 		 nIn: 1,	 nOut: 	0	 in 143.1s
# 		 nIn: 1,	 nOut: 	0	 in 143.2s
# 		 nIn: 1,	 nOut: 	1	 in 143.4s
# 		 nIn: 1,	 nOut: 	0	 in 143.6s
# 		 nIn: 1,	 nOut: 	0	 in 143.9s
# 		 nIn: 1,	 nOut: 	1	 in 144.0s
# 		 nIn: 1,	 nOut: 	0	 in 144.2s
# 		 nIn: 1,	 nOut: 	0	 in 144.3s
# 		 nIn: 1,	 nOut: 	0	 in 144.5s
# 		 nIn: 1,	 nOut: 	1	 in 144.7s
# 		 nIn: 1,	 nOut: 	0	 in 144.9s
# 		 nIn: 1,	 nOut: 	0	 in 145.0s
# 		 nIn: 1,	 nOut: 	1	 in 145.2s
# 		 nIn: 1,	 nOut: 	1	 in 145.4s
# 		 nIn: 1,	 nOut: 	1	 in 145.6s
# 		 nIn: 1,	 nOut: 	1	 in 145.8s
# 		 nIn: 1,	 nOut: 	0	 in 145.9s
# 		 nIn: 1,	 nOut: 	1	 in 146.1s
# 		 nIn: 1,	 nOut: 	1	 in 146.3s
# 		 nIn: 1,	 nOut: 	1	 in 146.5s
# 		 nIn: 1,	 nOut: 	0	 in 146.7s
# 		 nIn: 1,	 nOut: 	1	 in 146.8s
# 		 nIn: 1,	 nOut: 	1	 in 147.0s
# 		 nIn: 1,	 nOut: 	0	 in 147.2s
# 		 nIn: 1,	 nOut: 	1	 in 147.4s
# 		 nIn: 1,	 nOut: 	0	 in 147.5s
# 		 nIn: 1,	 nOut: 	0	 in 147.8s
# 		 nIn: 1,	 nOut: 	1	 in 148.0s
# 		 nIn: 1,	 nOut: 	0	 in 148.3s
# 		 nIn: 1,	 nOut: 	0	 in 148.5s
# 		 nIn: 1,	 nOut: 	1	 in 148.7s
# 		 nIn: 1,	 nOut: 	1	 in 148.8s
# 		 nIn: 1,	 nOut: 	0	 in 149.0s
# 		 nIn: 1,	 nOut: 	1	 in 149.1s
# 		 nIn: 1,	 nOut: 	0	 in 149.3s
# 		 nIn: 1,	 nOut: 	0	 in 149.5s
# 		 nIn: 1,	 nOut: 	0	 in 149.9s
# 		 nIn: 1,	 nOut: 	0	 in 150.0s
# 		 nIn: 1,	 nOut: 	0	 in 150.2s
# 		 nIn: 1,	 nOut: 	1	 in 150.4s
# 		 nIn: 1,	 nOut: 	0	 in 150.5s
# 		 nIn: 1,	 nOut: 	0	 in 150.7s
# 		 nIn: 1,	 nOut: 	0	 in 150.8s
# 		 nIn: 1,	 nOut: 	0	 in 151.0s
# 		 nIn: 1,	 nOut: 	0	 in 151.3s
# 		 nIn: 1,	 nOut: 	1	 in 151.5s
# 		 nIn: 1,	 nOut: 	0	 in 151.7s
# 		 nIn: 1,	 nOut: 	0	 in 151.9s
# 		 nIn: 1,	 nOut: 	0	 in 152.1s
# 		 nIn: 1,	 nOut: 	1	 in 152.3s
# 		 nIn: 1,	 nOut: 	1	 in 152.5s
# 		 nIn: 1,	 nOut: 	0	 in 152.7s
# 		 nIn: 1,	 nOut: 	0	 in 152.8s
# 		 nIn: 1,	 nOut: 	1	 in 153.0s
# 		 nIn: 1,	 nOut: 	0	 in 153.2s
# 		 nIn: 1,	 nOut: 	1	 in 153.4s
# 		 nIn: 1,	 nOut: 	0	 in 153.7s
# 		 nIn: 1,	 nOut: 	0	 in 153.9s
# 		 nIn: 1,	 nOut: 	0	 in 154.1s
# 		 nIn: 1,	 nOut: 	0	 in 154.4s
# 		 nIn: 1,	 nOut: 	0	 in 154.6s
# 		 nIn: 1,	 nOut: 	0	 in 154.8s
# 		 nIn: 1,	 nOut: 	1	 in 155.0s
# 		 nIn: 1,	 nOut: 	0	 in 155.2s
# 		 nIn: 1,	 nOut: 	0	 in 155.3s
# 		 nIn: 1,	 nOut: 	0	 in 155.7s
# 		 nIn: 1,	 nOut: 	0	 in 155.9s
# 		 nIn: 1,	 nOut: 	0	 in 156.0s
# 		 nIn: 1,	 nOut: 	0	 in 156.2s
# 		 nIn: 1,	 nOut: 	0	 in 156.3s
# 		 nIn: 1,	 nOut: 	1	 in 156.5s
# 		 nIn: 1,	 nOut: 	1	 in 156.7s
# 		 nIn: 1,	 nOut: 	0	 in 156.9s
# 		 nIn: 1,	 nOut: 	1	 in 157.0s
# 		 nIn: 1,	 nOut: 	0	 in 157.2s
# 		 nIn: 1,	 nOut: 	0	 in 157.4s
# 		 nIn: 1,	 nOut: 	1	 in 157.6s
# 		 nIn: 1,	 nOut: 	1	 in 157.7s
# 		 nIn: 1,	 nOut: 	0	 in 157.9s
# 		 nIn: 1,	 nOut: 	1	 in 158.0s
# 		 nIn: 1,	 nOut: 	1	 in 158.2s
# 		 nIn: 1,	 nOut: 	0	 in 158.6s
# 		 nIn: 1,	 nOut: 	1	 in 158.8s
# 		 nIn: 1,	 nOut: 	0	 in 159.0s
# 		 nIn: 1,	 nOut: 	0	 in 159.1s
# 		 nIn: 1,	 nOut: 	0	 in 159.3s
# 		 nIn: 1,	 nOut: 	1	 in 159.4s
# 		 nIn: 1,	 nOut: 	0	 in 159.6s
# 		 nIn: 1,	 nOut: 	1	 in 159.8s
# 		 nIn: 1,	 nOut: 	0	 in 160.0s
# 		 nIn: 1,	 nOut: 	0	 in 160.2s
# 		 nIn: 1,	 nOut: 	1	 in 160.4s
# 		 nIn: 1,	 nOut: 	0	 in 160.6s
# 		 nIn: 1,	 nOut: 	0	 in 160.8s
# 		 nIn: 1,	 nOut: 	0	 in 160.9s
# 		 nIn: 1,	 nOut: 	1	 in 161.1s
# 		 nIn: 1,	 nOut: 	0	 in 161.3s
# 		 nIn: 1,	 nOut: 	0	 in 161.4s
# 		 nIn: 1,	 nOut: 	1	 in 161.6s
# 		 nIn: 1,	 nOut: 	1	 in 161.9s
# 		 nIn: 1,	 nOut: 	0	 in 162.1s
# 		 nIn: 1,	 nOut: 	0	 in 162.4s
# 		 nIn: 1,	 nOut: 	0	 in 162.6s
# 		 nIn: 1,	 nOut: 	0	 in 162.8s
# 		 nIn: 1,	 nOut: 	0	 in 163.0s
# 		 nIn: 1,	 nOut: 	0	 in 163.2s
# 		 nIn: 1,	 nOut: 	0	 in 163.3s
# 		 nIn: 1,	 nOut: 	0	 in 163.5s
# 		 nIn: 1,	 nOut: 	0	 in 163.7s
# 		 nIn: 1,	 nOut: 	0	 in 163.9s
# 		 nIn: 1,	 nOut: 	0	 in 164.2s
# 		 nIn: 1,	 nOut: 	0	 in 164.3s
# 		 nIn: 1,	 nOut: 	0	 in 164.6s
# 		 nIn: 1,	 nOut: 	0	 in 164.8s
# 		 nIn: 1,	 nOut: 	1	 in 164.9s
# 		 nIn: 1,	 nOut: 	0	 in 165.0s
# 		 nIn: 1,	 nOut: 	0	 in 165.2s
# 		 nIn: 1,	 nOut: 	0	 in 165.4s
# 		 nIn: 1,	 nOut: 	1	 in 165.6s
# 		 nIn: 1,	 nOut: 	0	 in 165.9s
# 		 nIn: 1,	 nOut: 	0	 in 166.1s
# 		 nIn: 1,	 nOut: 	0	 in 166.3s
# 		 nIn: 1,	 nOut: 	1	 in 166.5s
# 		 nIn: 1,	 nOut: 	0	 in 166.7s
# 		 nIn: 1,	 nOut: 	0	 in 166.9s
# 		 nIn: 1,	 nOut: 	0	 in 167.2s
# 		 nIn: 1,	 nOut: 	1	 in 167.5s
# 		 nIn: 1,	 nOut: 	1	 in 167.7s
# 		 nIn: 1,	 nOut: 	1	 in 167.9s
# 		 nIn: 1,	 nOut: 	1	 in 168.2s
# 		 nIn: 1,	 nOut: 	0	 in 168.5s
# 		 nIn: 1,	 nOut: 	0	 in 168.7s
# 		 nIn: 1,	 nOut: 	1	 in 168.9s
# 		 nIn: 1,	 nOut: 	0	 in 169.1s
# 		 nIn: 1,	 nOut: 	1	 in 169.4s
# 		 nIn: 1,	 nOut: 	1	 in 169.6s
# 		 nIn: 1,	 nOut: 	1	 in 169.8s
# 		 nIn: 1,	 nOut: 	0	 in 170.0s
# 		 nIn: 1,	 nOut: 	0	 in 170.2s
# 		 nIn: 1,	 nOut: 	0	 in 170.4s
# 		 nIn: 1,	 nOut: 	0	 in 170.5s
# 		 nIn: 1,	 nOut: 	1	 in 170.7s
# 		 nIn: 1,	 nOut: 	0	 in 171.0s
# 		 nIn: 1,	 nOut: 	0	 in 171.2s
# 		 nIn: 1,	 nOut: 	0	 in 171.4s
# 		 nIn: 1,	 nOut: 	0	 in 171.5s
# 		 nIn: 1,	 nOut: 	0	 in 171.7s
# 		 nIn: 1,	 nOut: 	1	 in 171.9s
# 		 nIn: 1,	 nOut: 	0	 in 172.1s
# 		 nIn: 1,	 nOut: 	0	 in 172.3s
# 		 nIn: 1,	 nOut: 	0	 in 172.4s
# 		 nIn: 1,	 nOut: 	0	 in 172.6s
# 		 nIn: 1,	 nOut: 	0	 in 172.8s
# 		 nIn: 1,	 nOut: 	0	 in 173.1s
# 		 nIn: 1,	 nOut: 	0	 in 173.2s
# 		 nIn: 1,	 nOut: 	1	 in 173.4s
# 		 nIn: 1,	 nOut: 	0	 in 173.6s
# 		 nIn: 1,	 nOut: 	0	 in 173.8s
# 		 nIn: 1,	 nOut: 	0	 in 174.0s
# 		 nIn: 1,	 nOut: 	0	 in 174.2s
# 		 nIn: 1,	 nOut: 	1	 in 174.3s
# 		 nIn: 1,	 nOut: 	0	 in 174.5s
# 		 nIn: 1,	 nOut: 	1	 in 174.8s
# 		 nIn: 1,	 nOut: 	0	 in 175.0s
# 		 nIn: 1,	 nOut: 	0	 in 175.2s
# 		 nIn: 1,	 nOut: 	0	 in 175.4s
# 		 nIn: 1,	 nOut: 	0	 in 175.6s
# 		 nIn: 1,	 nOut: 	0	 in 175.8s
# 		 nIn: 1,	 nOut: 	1	 in 175.9s
# 		 nIn: 1,	 nOut: 	0	 in 176.1s
# 		 nIn: 1,	 nOut: 	0	 in 176.2s
# 		 nIn: 1,	 nOut: 	1	 in 176.4s
# 		 nIn: 1,	 nOut: 	0	 in 176.6s
# 		 nIn: 1,	 nOut: 	0	 in 176.8s
# 		 nIn: 1,	 nOut: 	0	 in 177.0s
# 		 nIn: 1,	 nOut: 	0	 in 177.2s
# 		 nIn: 1,	 nOut: 	0	 in 177.3s
# 		 nIn: 1,	 nOut: 	1	 in 177.5s
# 		 nIn: 1,	 nOut: 	0	 in 177.7s
# 		 nIn: 1,	 nOut: 	0	 in 177.8s
# 		 nIn: 1,	 nOut: 	0	 in 178.0s
# 		 nIn: 1,	 nOut: 	0	 in 178.1s
# 		 nIn: 1,	 nOut: 	0	 in 178.4s
# 		 nIn: 1,	 nOut: 	1	 in 178.6s
# 		 nIn: 1,	 nOut: 	1	 in 178.7s
# 		 nIn: 1,	 nOut: 	0	 in 178.9s
# 		 nIn: 1,	 nOut: 	0	 in 179.1s
# 		 nIn: 1,	 nOut: 	1	 in 179.2s
# 		 nIn: 1,	 nOut: 	0	 in 179.4s
# 		 nIn: 1,	 nOut: 	1	 in 179.6s
# 		 nIn: 1,	 nOut: 	0	 in 179.8s
# 		 nIn: 1,	 nOut: 	0	 in 180.0s
# 		 nIn: 1,	 nOut: 	0	 in 180.1s
# 		 nIn: 1,	 nOut: 	0	 in 180.3s
# 		 nIn: 1,	 nOut: 	0	 in 180.4s
# 		 nIn: 1,	 nOut: 	1	 in 180.6s
# 		 nIn: 1,	 nOut: 	1	 in 180.7s
# 		 nIn: 1,	 nOut: 	1	 in 180.9s
# 		 nIn: 1,	 nOut: 	1	 in 181.2s
# 		 nIn: 1,	 nOut: 	0	 in 181.3s
# 		 nIn: 1,	 nOut: 	1	 in 181.5s
# 		 nIn: 1,	 nOut: 	0	 in 181.7s
# 		 nIn: 1,	 nOut: 	1	 in 181.9s
# 		 nIn: 1,	 nOut: 	1	 in 182.2s
# 		 nIn: 1,	 nOut: 	0	 in 182.3s
# 		 nIn: 1,	 nOut: 	0	 in 182.5s
# 		 nIn: 1,	 nOut: 	0	 in 182.6s
# 		 nIn: 1,	 nOut: 	1	 in 182.8s
# 		 nIn: 1,	 nOut: 	0	 in 183.0s
# 		 nIn: 1,	 nOut: 	1	 in 183.1s
# 		 nIn: 1,	 nOut: 	0	 in 183.3s
# 		 nIn: 1,	 nOut: 	0	 in 183.4s
# 		 nIn: 1,	 nOut: 	0	 in 183.6s
# 		 nIn: 1,	 nOut: 	0	 in 183.8s
# 		 nIn: 1,	 nOut: 	1	 in 183.9s
# 		 nIn: 1,	 nOut: 	1	 in 184.1s
# 		 nIn: 1,	 nOut: 	0	 in 184.3s
# 		 nIn: 1,	 nOut: 	0	 in 184.6s
# 		 nIn: 1,	 nOut: 	0	 in 184.8s
# 		 nIn: 1,	 nOut: 	0	 in 184.9s
# 		 nIn: 1,	 nOut: 	0	 in 185.1s
# 		 nIn: 1,	 nOut: 	1	 in 185.4s
# 		 nIn: 1,	 nOut: 	0	 in 185.7s
# 		 nIn: 1,	 nOut: 	1	 in 185.8s
# 		 nIn: 1,	 nOut: 	0	 in 186.1s
# 		 nIn: 1,	 nOut: 	0	 in 186.3s
# 		 nIn: 1,	 nOut: 	0	 in 186.5s
# 		 nIn: 1,	 nOut: 	0	 in 186.7s
# 		 nIn: 1,	 nOut: 	0	 in 186.8s
# 		 nIn: 1,	 nOut: 	1	 in 187.0s
# 		 nIn: 1,	 nOut: 	0	 in 187.2s
# 		 nIn: 1,	 nOut: 	1	 in 187.5s
# 		 nIn: 1,	 nOut: 	0	 in 187.8s
# 		 nIn: 1,	 nOut: 	0	 in 188.0s
# 		 nIn: 1,	 nOut: 	0	 in 188.2s
# 		 nIn: 1,	 nOut: 	0	 in 188.4s
# 		 nIn: 1,	 nOut: 	0	 in 188.7s
# 		 nIn: 1,	 nOut: 	1	 in 188.9s
# 		 nIn: 1,	 nOut: 	0	 in 189.0s
# 		 nIn: 1,	 nOut: 	1	 in 189.2s
# 		 nIn: 1,	 nOut: 	0	 in 189.4s
# 		 nIn: 1,	 nOut: 	1	 in 189.6s
# 		 nIn: 1,	 nOut: 	1	 in 189.8s
# 		 nIn: 1,	 nOut: 	0	 in 190.1s
# 		 nIn: 1,	 nOut: 	1	 in 190.2s
# 		 nIn: 1,	 nOut: 	1	 in 190.4s
# 		 nIn: 1,	 nOut: 	1	 in 190.6s
# 		 nIn: 1,	 nOut: 	0	 in 190.7s
# 		 nIn: 1,	 nOut: 	1	 in 190.9s
# 		 nIn: 1,	 nOut: 	0	 in 191.1s
# 		 nIn: 1,	 nOut: 	0	 in 191.3s
# 		 nIn: 1,	 nOut: 	0	 in 191.5s
# 		 nIn: 1,	 nOut: 	0	 in 191.8s
# 		 nIn: 1,	 nOut: 	0	 in 192.0s
# 		 nIn: 1,	 nOut: 	0	 in 192.2s
# 		 nIn: 1,	 nOut: 	1	 in 192.4s
# 		 nIn: 1,	 nOut: 	0	 in 192.6s
# 		 nIn: 1,	 nOut: 	1	 in 192.8s
# 		 nIn: 1,	 nOut: 	1	 in 193.1s
# 		 nIn: 1,	 nOut: 	0	 in 193.3s
# 		 nIn: 1,	 nOut: 	0	 in 193.6s
# 		 nIn: 1,	 nOut: 	0	 in 193.8s
# 		 nIn: 1,	 nOut: 	1	 in 194.0s
# 		 nIn: 1,	 nOut: 	0	 in 194.2s
# 		 nIn: 1,	 nOut: 	0	 in 194.4s
# 		 nIn: 1,	 nOut: 	1	 in 194.6s
# 		 nIn: 1,	 nOut: 	0	 in 194.8s
# 		 nIn: 1,	 nOut: 	0	 in 195.0s
# 		 nIn: 1,	 nOut: 	1	 in 195.1s
# 		 nIn: 1,	 nOut: 	1	 in 195.3s
# 		 nIn: 1,	 nOut: 	1	 in 195.6s
# 		 nIn: 1,	 nOut: 	1	 in 195.9s
# 		 nIn: 1,	 nOut: 	0	 in 196.1s
# 		 nIn: 1,	 nOut: 	1	 in 196.3s
# 		 nIn: 1,	 nOut: 	0	 in 196.4s
# 		 nIn: 1,	 nOut: 	0	 in 196.6s
# 		 nIn: 1,	 nOut: 	0	 in 196.9s
# 		 nIn: 1,	 nOut: 	0	 in 197.1s
# 		 nIn: 1,	 nOut: 	0	 in 197.3s
# 		 nIn: 1,	 nOut: 	0	 in 197.5s
# 		 nIn: 1,	 nOut: 	0	 in 197.8s
# 		 nIn: 1,	 nOut: 	1	 in 198.1s
# 		 nIn: 1,	 nOut: 	0	 in 198.3s
# 		 nIn: 1,	 nOut: 	0	 in 198.6s
# 		 nIn: 1,	 nOut: 	0	 in 198.8s
# 		 nIn: 1,	 nOut: 	0	 in 199.0s
# 		 nIn: 1,	 nOut: 	0	 in 199.2s
# 		 nIn: 1,	 nOut: 	1	 in 199.4s
# 		 nIn: 1,	 nOut: 	0	 in 199.6s
# 		 nIn: 1,	 nOut: 	0	 in 199.7s
# 		 nIn: 1,	 nOut: 	0	 in 199.9s
# 		 nIn: 1,	 nOut: 	1	 in 200.1s
# 		 nIn: 1,	 nOut: 	0	 in 200.3s
# 		 nIn: 1,	 nOut: 	0	 in 200.5s
# 		 nIn: 1,	 nOut: 	1	 in 200.7s
# 		 nIn: 1,	 nOut: 	1	 in 200.8s
# 		 nIn: 1,	 nOut: 	0	 in 201.0s
# 		 nIn: 1,	 nOut: 	1	 in 201.2s
# 		 nIn: 1,	 nOut: 	0	 in 201.3s
# 		 nIn: 1,	 nOut: 	0	 in 201.5s
# 		 nIn: 1,	 nOut: 	0	 in 201.7s
# 		 nIn: 1,	 nOut: 	0	 in 202.0s
# 		 nIn: 1,	 nOut: 	1	 in 202.2s
# 		 nIn: 1,	 nOut: 	0	 in 202.4s
# 		 nIn: 1,	 nOut: 	0	 in 202.6s
# 		 nIn: 1,	 nOut: 	1	 in 202.9s
# 		 nIn: 1,	 nOut: 	1	 in 203.1s
# 		 nIn: 1,	 nOut: 	1	 in 203.4s
# 		 nIn: 1,	 nOut: 	0	 in 203.7s
# 		 nIn: 1,	 nOut: 	0	 in 203.9s
# 		 nIn: 1,	 nOut: 	1	 in 204.2s
# 		 nIn: 1,	 nOut: 	0	 in 204.5s
# 		 nIn: 1,	 nOut: 	1	 in 204.8s
# 		 nIn: 1,	 nOut: 	1	 in 205.1s
# 		 nIn: 1,	 nOut: 	0	 in 205.3s
# 		 nIn: 1,	 nOut: 	1	 in 205.5s
# 		 nIn: 1,	 nOut: 	0	 in 205.8s
# 		 nIn: 1,	 nOut: 	0	 in 206.1s
# 		 nIn: 1,	 nOut: 	0	 in 206.3s
# 		 nIn: 1,	 nOut: 	0	 in 206.6s
# 		 nIn: 1,	 nOut: 	0	 in 206.8s
# 		 nIn: 1,	 nOut: 	0	 in 207.0s
# 		 nIn: 1,	 nOut: 	1	 in 207.3s
# 		 nIn: 1,	 nOut: 	1	 in 207.5s
# 		 nIn: 1,	 nOut: 	0	 in 207.7s
# 		 nIn: 1,	 nOut: 	0	 in 208.0s
# 		 nIn: 1,	 nOut: 	0	 in 208.2s
# 		 nIn: 1,	 nOut: 	0	 in 208.5s
# 		 nIn: 1,	 nOut: 	0	 in 208.8s
# 		 nIn: 1,	 nOut: 	1	 in 209.0s
# 		 nIn: 1,	 nOut: 	1	 in 209.3s
# 		 nIn: 1,	 nOut: 	1	 in 209.5s
# 		 nIn: 1,	 nOut: 	1	 in 209.7s
# 		 nIn: 1,	 nOut: 	0	 in 209.9s
# 		 nIn: 1,	 nOut: 	0	 in 210.3s
# 		 nIn: 1,	 nOut: 	0	 in 210.5s
# 		 nIn: 1,	 nOut: 	1	 in 210.8s
# 		 nIn: 1,	 nOut: 	1	 in 211.0s
# 		 nIn: 1,	 nOut: 	0	 in 211.3s
# 		 nIn: 1,	 nOut: 	0	 in 211.5s
# 		 nIn: 1,	 nOut: 	0	 in 211.8s
# 		 nIn: 1,	 nOut: 	1	 in 212.0s
# 		 nIn: 1,	 nOut: 	0	 in 212.2s
# 		 nIn: 1,	 nOut: 	1	 in 212.4s
# 		 nIn: 1,	 nOut: 	0	 in 212.6s
# 		 nIn: 1,	 nOut: 	1	 in 212.8s
# 		 nIn: 1,	 nOut: 	1	 in 213.0s
# 		 nIn: 1,	 nOut: 	0	 in 213.2s
# 		 nIn: 1,	 nOut: 	1	 in 213.4s
# 		 nIn: 1,	 nOut: 	0	 in 213.6s
# 		 nIn: 1,	 nOut: 	1	 in 213.9s
# 		 nIn: 1,	 nOut: 	0	 in 214.1s
# 		 nIn: 1,	 nOut: 	0	 in 214.3s
# 		 nIn: 1,	 nOut: 	1	 in 214.5s
# 		 nIn: 1,	 nOut: 	0	 in 214.7s
# 		 nIn: 1,	 nOut: 	1	 in 215.0s
# 		 nIn: 1,	 nOut: 	1	 in 215.2s
# 		 nIn: 1,	 nOut: 	1	 in 215.4s
# 		 nIn: 1,	 nOut: 	0	 in 215.6s
# 		 nIn: 1,	 nOut: 	0	 in 215.8s
# 		 nIn: 1,	 nOut: 	1	 in 216.0s
# 		 nIn: 1,	 nOut: 	1	 in 216.2s
# 		 nIn: 1,	 nOut: 	0	 in 216.4s
# 		 nIn: 1,	 nOut: 	0	 in 216.6s
# 		 nIn: 1,	 nOut: 	0	 in 216.8s
# 		 nIn: 1,	 nOut: 	0	 in 217.0s
# 		 nIn: 1,	 nOut: 	0	 in 217.2s
# 		 nIn: 1,	 nOut: 	0	 in 217.4s
# 		 nIn: 1,	 nOut: 	0	 in 217.6s
# 		 nIn: 1,	 nOut: 	1	 in 217.8s
# 		 nIn: 1,	 nOut: 	1	 in 218.0s
# 		 nIn: 1,	 nOut: 	1	 in 218.1s
# 		 nIn: 1,	 nOut: 	0	 in 218.3s
# 		 nIn: 1,	 nOut: 	1	 in 218.5s
# 		 nIn: 1,	 nOut: 	0	 in 218.7s
# 		 nIn: 1,	 nOut: 	0	 in 218.9s
# 		 nIn: 1,	 nOut: 	0	 in 219.0s
# 		 nIn: 1,	 nOut: 	0	 in 219.2s
# 		 nIn: 1,	 nOut: 	0	 in 219.4s
# 		 nIn: 1,	 nOut: 	0	 in 219.6s
# 		 nIn: 1,	 nOut: 	0	 in 219.8s
# 		 nIn: 1,	 nOut: 	1	 in 219.9s
# 		 nIn: 1,	 nOut: 	1	 in 220.1s
# 		 nIn: 1,	 nOut: 	0	 in 220.3s
# 		 nIn: 1,	 nOut: 	1	 in 220.5s
# 		 nIn: 1,	 nOut: 	0	 in 220.7s
# 		 nIn: 1,	 nOut: 	0	 in 220.9s
# 		 nIn: 1,	 nOut: 	1	 in 221.3s
# 		 nIn: 1,	 nOut: 	0	 in 221.6s
# 		 nIn: 1,	 nOut: 	0	 in 221.8s
# 		 nIn: 1,	 nOut: 	0	 in 222.0s
# 		 nIn: 1,	 nOut: 	0	 in 222.2s
# 		 nIn: 1,	 nOut: 	0	 in 222.3s
# 		 nIn: 1,	 nOut: 	1	 in 222.5s
# 		 nIn: 1,	 nOut: 	1	 in 222.8s
# 		 nIn: 1,	 nOut: 	0	 in 223.0s
# 		 nIn: 1,	 nOut: 	0	 in 223.2s
# 		 nIn: 1,	 nOut: 	0	 in 223.4s
# 		 nIn: 1,	 nOut: 	1	 in 223.6s
# 		 nIn: 1,	 nOut: 	0	 in 223.7s
# 		 nIn: 1,	 nOut: 	0	 in 223.9s
# 		 nIn: 1,	 nOut: 	0	 in 224.1s
# 		 nIn: 1,	 nOut: 	0	 in 224.3s
# 		 nIn: 1,	 nOut: 	0	 in 224.5s
# 		 nIn: 1,	 nOut: 	1	 in 224.7s
# 		 nIn: 1,	 nOut: 	0	 in 224.9s
# 		 nIn: 1,	 nOut: 	0	 in 225.1s
# 		 nIn: 1,	 nOut: 	0	 in 225.3s
# 		 nIn: 1,	 nOut: 	0	 in 225.5s
# 		 nIn: 1,	 nOut: 	0	 in 225.6s
# 		 nIn: 1,	 nOut: 	1	 in 225.8s
# 		 nIn: 1,	 nOut: 	1	 in 226.0s
# 		 nIn: 1,	 nOut: 	1	 in 226.1s
# 		 nIn: 1,	 nOut: 	0	 in 226.3s
# 		 nIn: 1,	 nOut: 	0	 in 226.5s
# 		 nIn: 1,	 nOut: 	1	 in 226.7s
# 		 nIn: 1,	 nOut: 	0	 in 226.9s
# 		 nIn: 1,	 nOut: 	0	 in 227.1s
# 		 nIn: 1,	 nOut: 	1	 in 227.3s
# 		 nIn: 1,	 nOut: 	1	 in 227.5s
# 		 nIn: 1,	 nOut: 	1	 in 227.8s
# 		 nIn: 1,	 nOut: 	1	 in 228.0s
# 		 nIn: 1,	 nOut: 	0	 in 228.2s
# 		 nIn: 1,	 nOut: 	0	 in 228.4s
# 		 nIn: 1,	 nOut: 	0	 in 228.6s
# 		 nIn: 1,	 nOut: 	0	 in 228.8s
# 		 nIn: 1,	 nOut: 	0	 in 229.0s
# 		 nIn: 1,	 nOut: 	0	 in 229.1s
# 		 nIn: 1,	 nOut: 	0	 in 229.3s
# 		 nIn: 1,	 nOut: 	0	 in 229.5s
# 		 nIn: 1,	 nOut: 	1	 in 229.8s
# 		 nIn: 1,	 nOut: 	1	 in 230.0s
# 		 nIn: 1,	 nOut: 	1	 in 230.1s
# 		 nIn: 1,	 nOut: 	0	 in 230.3s
# 		 nIn: 1,	 nOut: 	0	 in 230.5s
# 		 nIn: 1,	 nOut: 	1	 in 230.7s
# 		 nIn: 1,	 nOut: 	0	 in 231.0s
# 		 nIn: 1,	 nOut: 	0	 in 231.5s
# 		 nIn: 1,	 nOut: 	1	 in 231.7s
# 		 nIn: 1,	 nOut: 	1	 in 231.9s
# 		 nIn: 1,	 nOut: 	0	 in 232.0s
# 		 nIn: 1,	 nOut: 	0	 in 232.2s
# 		 nIn: 1,	 nOut: 	0	 in 232.3s
# 		 nIn: 1,	 nOut: 	1	 in 232.5s
# 		 nIn: 1,	 nOut: 	1	 in 232.7s
# 		 nIn: 1,	 nOut: 	0	 in 233.0s
# 		 nIn: 1,	 nOut: 	0	 in 233.2s
# 		 nIn: 1,	 nOut: 	0	 in 233.5s
# 		 nIn: 1,	 nOut: 	0	 in 233.9s
# 		 nIn: 1,	 nOut: 	0	 in 234.1s
# 		 nIn: 1,	 nOut: 	0	 in 234.4s
# 		 nIn: 1,	 nOut: 	0	 in 234.5s
# 		 nIn: 1,	 nOut: 	0	 in 234.8s
# 		 nIn: 1,	 nOut: 	0	 in 235.2s
# 		 nIn: 1,	 nOut: 	1	 in 235.9s
# 		 nIn: 1,	 nOut: 	1	 in 236.5s
# 		 nIn: 1,	 nOut: 	0	 in 237.0s
# 		 nIn: 1,	 nOut: 	1	 in 237.4s
# 		 nIn: 1,	 nOut: 	1	 in 237.8s
# 		 nIn: 1,	 nOut: 	0	 in 238.2s
# 		 nIn: 1,	 nOut: 	0	 in 238.6s
# 		 nIn: 1,	 nOut: 	1	 in 238.9s
# 		 nIn: 1,	 nOut: 	0	 in 239.1s
# 		 nIn: 1,	 nOut: 	0	 in 239.3s
# 		 nIn: 1,	 nOut: 	0	 in 239.4s
# 		 nIn: 1,	 nOut: 	0	 in 239.7s
# 		 nIn: 1,	 nOut: 	1	 in 239.8s
# 		 nIn: 1,	 nOut: 	1	 in 240.0s
# 		 nIn: 1,	 nOut: 	0	 in 240.2s
# 		 nIn: 1,	 nOut: 	0	 in 240.4s
# 		 nIn: 1,	 nOut: 	0	 in 240.6s
# 		 nIn: 1,	 nOut: 	1	 in 240.7s
# 		 nIn: 1,	 nOut: 	0	 in 240.9s
# 		 nIn: 1,	 nOut: 	0	 in 241.1s
# 		 nIn: 1,	 nOut: 	0	 in 241.3s
# 		 nIn: 1,	 nOut: 	1	 in 241.5s
# 		 nIn: 1,	 nOut: 	0	 in 241.6s
# 		 nIn: 1,	 nOut: 	0	 in 241.7s
# 		 nIn: 1,	 nOut: 	1	 in 241.9s
# 		 nIn: 1,	 nOut: 	1	 in 242.0s
# 		 nIn: 1,	 nOut: 	0	 in 242.2s
# 		 nIn: 1,	 nOut: 	0	 in 242.3s
# Processing Background $ZZ^*$ samples
# 	Processing: llll
# 		 nIn: 554279,	 nOut: 	523957	 in 551.5s
# Processing Signal ($m_H$ = 125 GeV) samples
# 	Processing: ggH125_ZZ4lep
# 		 nIn: 164716,	 nOut: 	161451	 in 242.4s
# 	Processing: VBFH125_ZZ4lep
# 		 nIn: 191126,	 nOut: 	186870	 in 141.4s
# 	Processing: WH125_ZZ4lep
# 		 nIn: 15379,	 nOut: 	9772	 in 27.0s
# 	Processing: ZH125_ZZ4lep
# 		 nIn: 14485,	 nOut: 	11947	 in 8.4s
# Time taken: 1820.4s

# %% [markdown]
# <a id='plotting'></a>

# %% [markdown]
# <a id='plotting'></a>

# %%
def plot_data(data):

    xmin = 80 * GeV
    xmax = 250 * GeV
    step_size = 5 * GeV

    bin_edges = np.arange(start=xmin, # The interval includes this value
                     stop=xmax+step_size, # The interval doesn't include this value
                     step=step_size ) # Spacing between values
    bin_centres = np.arange(start=xmin+step_size/2, # The interval includes this value
                            stop=xmax+step_size/2, # The interval doesn't include this value
                            step=step_size ) # Spacing between values

    data_x,_ = np.histogram(ak.to_numpy(data['data']['mllll']), 
                            bins=bin_edges ) # histogram the data
    data_x_errors = np.sqrt( data_x ) # statistical error on the data

    signal_x = ak.to_numpy(data[r'Signal ($m_H$ = 125 GeV)']['mllll']) # histogram the signal
    signal_weights = ak.to_numpy(data[r'Signal ($m_H$ = 125 GeV)'].totalWeight) # get the weights of the signal events
    signal_color = samples[r'Signal ($m_H$ = 125 GeV)']['color'] # get the colour for the signal bar

    mc_x = [] # define list to hold the Monte Carlo histogram entries
    mc_weights = [] # define list to hold the Monte Carlo weights
    mc_colors = [] # define list to hold the colors of the Monte Carlo bars
    mc_labels = [] # define list to hold the legend labels of the Monte Carlo bars

    for s in samples: # loop over samples
        if s not in ['data', r'Signal ($m_H$ = 125 GeV)']: # if not data nor signal
            mc_x.append( ak.to_numpy(data[s]['mllll']) ) # append to the list of Monte Carlo histogram entries
            mc_weights.append( ak.to_numpy(data[s].totalWeight) ) # append to the list of Monte Carlo weights
            mc_colors.append( samples[s]['color'] ) # append to the list of Monte Carlo bar colors
            mc_labels.append( s ) # append to the list of Monte Carlo legend labels
    


    # *************
    # Main plot 
    # *************
    main_axes = plt.gca() # get current axes
    
    # plot the data points
    main_axes.errorbar(x=bin_centres, y=data_x, yerr=data_x_errors,
                       fmt='ko', 
                       label='Data') 
    
    # Monte Carlo bars
    mc_heights = main_axes.hist(mc_x, bins=bin_edges, 
                                weights=mc_weights, stacked=True, 
                                color=mc_colors, label=mc_labels )
    
    mc_x_tot = mc_heights[0][-1] # stacked background MC y-axis value
    
    # calculate MC statistical uncertainty: sqrt(sum w^2)
    mc_x_err = np.sqrt(np.histogram(np.hstack(mc_x), bins=bin_edges, weights=np.hstack(mc_weights)**2)[0])
    
    # plot the signal bar
    main_axes.hist(signal_x, bins=bin_edges, bottom=mc_x_tot, 
                   weights=signal_weights, color=signal_color,
                   label=r'Signal ($m_H$ = 125 GeV)')
    
    # plot the statistical uncertainty
    main_axes.bar(bin_centres, # x
                  2*mc_x_err, # heights
                  alpha=0.5, # half transparency
                  bottom=mc_x_tot-mc_x_err, color='none', 
                  hatch="////", width=step_size, label='Stat. Unc.' )

    # set the x-limit of the main axes
    main_axes.set_xlim( left=xmin, right=xmax ) 
    
    # separation of x axis minor ticks
    main_axes.xaxis.set_minor_locator( AutoMinorLocator() ) 
    
    # set the axis tick parameters for the main axes
    main_axes.tick_params(which='both', # ticks on both x and y axes
                          direction='in', # Put ticks inside and outside the axes
                          top=True, # draw ticks on the top axis
                          right=True ) # draw ticks on right axis
    
    # x-axis label
    main_axes.set_xlabel(r'4-lepton invariant mass $\mathrm{m_{4l}}$ [GeV]',
                        fontsize=13, x=1, horizontalalignment='right' )
    
    # write y-axis label for main axes
    main_axes.set_ylabel('Events / '+str(step_size)+' GeV',
                         y=1, horizontalalignment='right') 
    
    # set y-axis limits for main axes
    main_axes.set_ylim( bottom=0, top=np.amax(data_x)*1.6 )
    
    # add minor ticks on y-axis for main axes
    main_axes.yaxis.set_minor_locator( AutoMinorLocator() ) 

    
    plt.text(0.05, # x
             0.93, # y             
             'subatomic particles rel', # text
             transform=main_axes.transAxes, # coordinate system used is that of main_axes
             fontsize=13 ) 
    
    
    plt.text(0.05, # x
             0.88, # y
             'CERN Atlas Data',
             transform=main_axes.transAxes, # coordinate system used is that of main_axes
             style='italic',
             fontsize=8 ) 
    
    # Add energy and luminosity
    lumi_used = str(lumi*fraction) # luminosity to write on the plot
    plt.text(0.05, # x
             0.82, # y
             '$\sqrt{s}$=13 TeV,$\int$L dt = '+lumi_used+' fb$^{-1}$', # text
             transform=main_axes.transAxes ) # coordinate system used is that of main_axes
    
    # Add a label for the analysis carried out
    plt.text(0.05, # x
             0.76, # y
             r'$H \rightarrow ZZ^* \rightarrow 4\ell$', # text 
             transform=main_axes.transAxes ) # coordinate system used is that of main_axes

    # draw the legend
    main_axes.legend( frameon=False ) # no box around the legend
    
    return

# %% [markdown]
# Call the function to plot the data

# %%
plot_data(data)

# %% [markdown]
# <a id='going_further'></a>
