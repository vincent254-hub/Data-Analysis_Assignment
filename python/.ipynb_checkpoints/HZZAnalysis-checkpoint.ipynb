# %% [markdown]
# discovering the Higgs boson
# This notebook uses ATLAS Open Data http://opendata.atlas.cern to show you the steps to rediscover the Higgs boson
#
# ATLAS Open Data provides open access to proton-proton collision data at the LHC for educational purposes. ATLAS Open Data resources are ideal for students.
#
#
# The idea is that cuts increase the ratio of signal ($H \rightarrow ZZ \rightarrow \ell\ell\ell\ell$) to background ($Z, t\bar{t}, ZZ \rightarrow \ell\ell\ell\ell$)
#
# First, the amount of $Z$ and $t\bar{t}$ background is reduced, since these are quite different to the signal.
#
# Then, the amount of $ZZ \rightarrow \ell\ell\ell\ell$ is reduced, whilst keeping as much $H \rightarrow ZZ \rightarrow \ell\ell\ell\ell$ signal as possible.
#
# The datasets used in this notebook have already been filtered to include at least 4 leptons per event, so that processing is quicker.

# %% [markdown]
# <a id='contents'></a>

# %% [markdown]
# <a id='running'></a>

# %% [markdown]
# <a id='setup_computer'></a>

# %%
import sys
# update the pip package installer
# !{sys.executable} -m pip install --upgrade --user pip
# install required packages
# !{sys.executable} -m pip install --upgrade --user uproot awkward vector numpy matplotlib
# Out:
# Requirement already satisfied: pip in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (23.2.1)
# Requirement already satisfied: uproot in c:\users\root_vincent\appdata\roaming\python\python39\site-packages (5.0.11)
# Requirement already satisfied: awkward in c:\users\root_vincent\appdata\roaming\python\python39\site-packages (2.3.3)
# Requirement already satisfied: vector in c:\users\root_vincent\appdata\roaming\python\python39\site-packages (1.1.0)
# Requirement already satisfied: numpy in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (1.25.2)
# Requirement already satisfied: matplotlib in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (3.7.2)
# Requirement already satisfied: packaging in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (from uproot) (23.1)
# Requirement already satisfied: awkward-cpp==22 in c:\users\root_vincent\appdata\roaming\python\python39\site-packages (from awkward) (22)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (from awkward) (4.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (6.0.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.16.2)
# Requirement already satisfied: six>=1.5 in c:\users\root_vincent\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# <a id='setup_everytime'></a>

# %%
import uproot # for reading .root files
import awkward as ak # to represent nested data in columnar format
import vector # for 4-momentum calculations
import time # to measure time to analyse
import math # for mathematical functions such as square root
import numpy as np # for numerical calculations such as histogramming
import matplotlib.pyplot as plt # for plotting
from matplotlib.ticker import AutoMinorLocator # for minor ticks

import infofile # local file containing cross-sections, sums of weights, dataset IDs

# %% [markdown]
# <a id='fraction'></a>

# %%
lumi = 10 

fraction = 1.0                                                                                                                                  
 
tuple_path = "https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/4lep/"

# %% [markdown]
# <a id='samples'></a>

# %% [markdown]
# samples processing

# %%
samples = {

    'data': {
        'list' : ['data_A','data_B','data_C','data_D'],
    },

    r'Background $Z,t\bar{t}$' : { # Z + ttbar
        'list' : ['Zee','Zmumu','ttbar_lep'],
        'color' : "#6b59d3" # purple
    },

    r'Background $ZZ^*$' : { # ZZ
        'list' : ['llll'],
        'color' : "#ff0000" # red
    },

    r'Signal ($m_H$ = 125 GeV)' : { # H -> ZZ -> llll
        'list' : ['ggH125_ZZ4lep','VBFH125_ZZ4lep','WH125_ZZ4lep','ZH125_ZZ4lep'],
        'color' : "#00cdff" # light blue
    },

}

# %% [markdown]
# Units, as stored in the data files

# %%
MeV = 0.001
GeV = 1.0

# %% [markdown]
# Define function to get data from files.
#
# The datasets used in this notebook have already been filtered to include at least 4 leptons per event, so that processing is quicker.

# %%
def get_data_from_files():

    data = {} # define empty dictionary to hold awkward arrays
    for s in samples: # loop over samples
        print('Processing '+s+' samples') # print which sample
        frames = [] # define empty list to hold data
        for val in samples[s]['list']: # loop over each file
            if s == 'data': prefix = "Data/" # Data prefix
            else: # MC prefix
                prefix = "MC/mc_"+str(infofile.infos[val]["DSID"])+"."
            fileString = tuple_path+prefix+val+".4lep.root" # file name to open
            temp = read_file(fileString,val) # call the function read_file defined below
            frames.append(temp) # append array returned from read_file to list of awkward arrays
        data[s] = ak.concatenate(frames) # dictionary entry is concatenated awkward arrays
    
    return data # return dictionary of awkward arrays

# %% [markdown]
# define function to calculate weight of MC event

# %%
def calc_weight(xsec_weight, events):
    return (
        xsec_weight
        * events.mcWeight
        * events.scaleFactor_PILEUP
        * events.scaleFactor_ELE
        * events.scaleFactor_MUON 
        * events.scaleFactor_LepTRIGGER
    )

# %% [markdown]
# define function to get cross-section weight

# %%
def get_xsec_weight(sample):
    info = infofile.infos[sample] # open infofile
    xsec_weight = (lumi*1000*info["xsec"])/(info["sumw"]*info["red_eff"]) #*1000 to go from fb-1 to pb-1
    return xsec_weight # return cross-section weight

# %% [markdown]
# define function to calculate 4-lepton invariant mass.
#
# Note: `lep_(pt|eta|phi|E)` are variable length lists of lepton momentum components for each event, represented by awkward arrays.

# %%
def calc_mllll(lep_pt, lep_eta, lep_phi, lep_E):
    # construct awkward 4-vector array
    p4 = vector.zip({"pt": lep_pt, "eta": lep_eta, "phi": lep_phi, "E": lep_E})
    # calculate invariant mass of first 4 leptons
    # [:, i] selects the i-th lepton in each event
    # .M calculates the invariant mass
    return (p4[:, 0] + p4[:, 1] + p4[:, 2] + p4[:, 3]).M * MeV

# %% [markdown]
# <a id='changing_cut'></a>

# %%
# cut on lepton charge
# paper: "selecting two pairs of isolated leptons, each of which is comprised of two leptons with the same flavour and opposite charge"
def cut_lep_charge(lep_charge):
# throw away when sum of lepton charges is not equal to 0
# first lepton in each event is [:, 0], 2nd lepton is [:, 1] etc
    return lep_charge[:, 0] + lep_charge[:, 1] + lep_charge[:, 2] + lep_charge[:, 3] != 0

# cut on lepton type
# paper: "selecting two pairs of isolated leptons, each of which is comprised of two leptons with the same flavour and opposite charge"
def cut_lep_type(lep_type):
# for an electron lep_type is 11
# for a muon lep_type is 13
# throw away when none of eeee, mumumumu, eemumu
    sum_lep_type = lep_type[:, 0] + lep_type[:, 1] + lep_type[:, 2] + lep_type[:, 3]
    return (sum_lep_type != 44) & (sum_lep_type != 48) & (sum_lep_type != 52)

# %% [markdown]
# <a id='applying_cut'></a>

# %%
def read_file(path,sample):
    start = time.time() # start the clock
    print("\tProcessing: "+sample) # print which sample is being processed
    data_all = [] # define empty list to hold all data for this sample
    
    # open the tree called mini using a context manager (will automatically close files/resources)
    with uproot.open(path + ":mini") as tree:
        numevents = tree.num_entries # number of events
        if 'data' not in sample: xsec_weight = get_xsec_weight(sample) # get cross-section weight
        for data in tree.iterate(['lep_pt','lep_eta','lep_phi',
                                  'lep_E','lep_charge','lep_type', 
                                  # add more variables here if you make cuts on them 
                                  'mcWeight','scaleFactor_PILEUP',
                                  'scaleFactor_ELE','scaleFactor_MUON',
                                  'scaleFactor_LepTRIGGER'], # variables to calculate Monte Carlo weight
                                 library="ak", # choose output type as awkward array
                                 entry_stop=numevents*fraction): # process up to numevents*fraction

            nIn = len(data) # number of events in this batch

            if 'data' not in sample: # only do this for Monte Carlo simulation files
                # multiply all Monte Carlo weights and scale factors together to give total weight
                data['totalWeight'] = calc_weight(xsec_weight, data)

            # cut on lepton charge using the function cut_lep_charge defined above
            data = data[~cut_lep_charge(data.lep_charge)]

            # cut on lepton type using the function cut_lep_type defined above
            data = data[~cut_lep_type(data.lep_type)]

            # calculation of 4-lepton invariant mass using the function calc_mllll defined above
            data['mllll'] = calc_mllll(data.lep_pt, data.lep_eta, data.lep_phi, data.lep_E)

            # array contents can be printed at any stage like this
            #print(data)

            # array column can be printed at any stage like this
            #print(data['lep_pt'])

            # multiple array columns can be printed at any stage like this
            #print(data[['lep_pt','lep_eta']])

            nOut = len(data) # number of events passing cuts in this batch
            data_all.append(data) # append array from this batch
            elapsed = time.time() - start # time taken to process
            print("\t\t nIn: "+str(nIn)+",\t nOut: \t"+str(nOut)+"\t in "+str(round(elapsed,1))+"s") # events before and after
    
    return ak.concatenate(data_all) # return array containing events passing all cuts

# %% [markdown]
# This is where the processing happens

# %%
start = time.time() # time at start of whole processing
data = get_data_from_files() # process all files
elapsed = time.time() - start # time after whole processing
print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
# Out:
# Processing data samples
# 	Processing: data_A
# 		 nIn: 1,	 nOut: 	0	 in 80.9s
# 		 nIn: 1,	 nOut: 	1	 in 82.3s
# 		 nIn: 1,	 nOut: 	1	 in 82.5s
# 		 nIn: 1,	 nOut: 	0	 in 82.6s
# 		 nIn: 1,	 nOut: 	1	 in 82.8s
# 		 nIn: 1,	 nOut: 	1	 in 82.9s
# 		 nIn: 1,	 nOut: 	0	 in 83.1s
# 		 nIn: 1,	 nOut: 	1	 in 83.2s
# 		 nIn: 1,	 nOut: 	1	 in 83.4s
# 		 nIn: 1,	 nOut: 	1	 in 83.5s
# 		 nIn: 1,	 nOut: 	0	 in 83.7s
# 		 nIn: 1,	 nOut: 	0	 in 83.8s
# 		 nIn: 1,	 nOut: 	0	 in 84.0s
# 		 nIn: 1,	 nOut: 	0	 in 84.1s
# 		 nIn: 1,	 nOut: 	1	 in 84.3s
# 		 nIn: 1,	 nOut: 	1	 in 84.4s
# 		 nIn: 1,	 nOut: 	1	 in 84.6s
# 		 nIn: 1,	 nOut: 	1	 in 84.7s
# 		 nIn: 1,	 nOut: 	1	 in 84.8s
# 		 nIn: 1,	 nOut: 	1	 in 85.0s
# 		 nIn: 1,	 nOut: 	1	 in 85.2s
# 		 nIn: 1,	 nOut: 	1	 in 85.4s
# 		 nIn: 1,	 nOut: 	1	 in 85.5s
# 		 nIn: 1,	 nOut: 	1	 in 85.6s
# 		 nIn: 1,	 nOut: 	1	 in 85.8s
# 		 nIn: 1,	 nOut: 	1	 in 85.9s
# 		 nIn: 1,	 nOut: 	0	 in 86.1s
# 		 nIn: 1,	 nOut: 	1	 in 86.3s
# 		 nIn: 1,	 nOut: 	0	 in 86.5s
# 		 nIn: 1,	 nOut: 	1	 in 86.6s
# 		 nIn: 1,	 nOut: 	1	 in 86.7s
# 		 nIn: 1,	 nOut: 	0	 in 86.9s
# 		 nIn: 1,	 nOut: 	0	 in 87.0s
# 		 nIn: 1,	 nOut: 	1	 in 87.2s
# 		 nIn: 1,	 nOut: 	1	 in 87.4s
# 		 nIn: 1,	 nOut: 	1	 in 87.6s
# 		 nIn: 1,	 nOut: 	1	 in 87.7s
# 		 nIn: 1,	 nOut: 	1	 in 87.8s
# 		 nIn: 1,	 nOut: 	0	 in 88.0s
# 	Processing: data_B
# 		 nIn: 1,	 nOut: 	1	 in 6.9s
# 		 nIn: 1,	 nOut: 	1	 in 8.3s
# 		 nIn: 1,	 nOut: 	1	 in 8.6s
# 		 nIn: 1,	 nOut: 	0	 in 8.9s
# 		 nIn: 1,	 nOut: 	0	 in 9.2s
# 		 nIn: 1,	 nOut: 	0	 in 9.4s
# 		 nIn: 1,	 nOut: 	1	 in 9.8s
# 		 nIn: 1,	 nOut: 	1	 in 10.0s
# 		 nIn: 1,	 nOut: 	0	 in 10.2s
# 		 nIn: 1,	 nOut: 	1	 in 10.5s
# 		 nIn: 1,	 nOut: 	1	 in 10.8s
# 		 nIn: 1,	 nOut: 	0	 in 11.0s
# 		 nIn: 1,	 nOut: 	1	 in 11.3s
# 		 nIn: 1,	 nOut: 	0	 in 11.5s
# 		 nIn: 1,	 nOut: 	0	 in 11.7s
# 		 nIn: 1,	 nOut: 	0	 in 12.0s
# 		 nIn: 1,	 nOut: 	0	 in 12.3s
# 		 nIn: 1,	 nOut: 	1	 in 12.5s
# 		 nIn: 1,	 nOut: 	1	 in 12.8s
# 		 nIn: 1,	 nOut: 	0	 in 13.0s
# 		 nIn: 1,	 nOut: 	1	 in 13.3s
# 		 nIn: 1,	 nOut: 	0	 in 13.5s
# 		 nIn: 1,	 nOut: 	0	 in 13.7s
# 		 nIn: 1,	 nOut: 	1	 in 13.9s
# 		 nIn: 1,	 nOut: 	1	 in 14.2s
# 		 nIn: 1,	 nOut: 	0	 in 14.4s
# 		 nIn: 1,	 nOut: 	0	 in 14.8s
# 		 nIn: 1,	 nOut: 	1	 in 15.1s
# 		 nIn: 1,	 nOut: 	1	 in 15.4s
# 		 nIn: 1,	 nOut: 	0	 in 15.8s
# 		 nIn: 1,	 nOut: 	1	 in 16.1s
# 		 nIn: 1,	 nOut: 	1	 in 16.4s
# 		 nIn: 1,	 nOut: 	0	 in 16.7s
# 		 nIn: 1,	 nOut: 	1	 in 16.9s
# 		 nIn: 1,	 nOut: 	1	 in 17.2s
# 		 nIn: 1,	 nOut: 	1	 in 17.4s
# 		 nIn: 1,	 nOut: 	1	 in 17.7s
# 		 nIn: 1,	 nOut: 	0	 in 18.0s
# 		 nIn: 1,	 nOut: 	0	 in 18.2s
# 		 nIn: 1,	 nOut: 	1	 in 18.4s
# 		 nIn: 1,	 nOut: 	1	 in 18.6s
# 		 nIn: 1,	 nOut: 	1	 in 18.9s
# 		 nIn: 1,	 nOut: 	0	 in 19.3s
# 		 nIn: 1,	 nOut: 	1	 in 19.5s
# 		 nIn: 1,	 nOut: 	0	 in 19.7s
# 		 nIn: 1,	 nOut: 	1	 in 20.0s
# 		 nIn: 1,	 nOut: 	0	 in 20.2s
# 		 nIn: 1,	 nOut: 	1	 in 20.5s
# 		 nIn: 1,	 nOut: 	0	 in 20.7s
# 		 nIn: 1,	 nOut: 	1	 in 21.0s
# 		 nIn: 1,	 nOut: 	0	 in 21.3s
# 		 nIn: 1,	 nOut: 	0	 in 21.5s
# 		 nIn: 1,	 nOut: 	0	 in 21.8s
# 		 nIn: 1,	 nOut: 	1	 in 22.0s
# 		 nIn: 1,	 nOut: 	0	 in 22.3s
# 		 nIn: 1,	 nOut: 	1	 in 22.7s
# 		 nIn: 1,	 nOut: 	0	 in 23.0s
# 		 nIn: 1,	 nOut: 	0	 in 23.4s
# 		 nIn: 1,	 nOut: 	0	 in 23.6s
# 		 nIn: 1,	 nOut: 	0	 in 23.9s
# 		 nIn: 1,	 nOut: 	1	 in 24.2s
# 		 nIn: 1,	 nOut: 	0	 in 24.5s
# 		 nIn: 1,	 nOut: 	1	 in 24.7s
# 		 nIn: 1,	 nOut: 	1	 in 25.0s
# 		 nIn: 1,	 nOut: 	1	 in 25.2s
# 		 nIn: 1,	 nOut: 	0	 in 25.5s
# 		 nIn: 1,	 nOut: 	1	 in 25.7s
# 		 nIn: 1,	 nOut: 	1	 in 26.0s
# 		 nIn: 1,	 nOut: 	1	 in 26.5s
# 		 nIn: 1,	 nOut: 	1	 in 26.7s
# 		 nIn: 1,	 nOut: 	0	 in 26.9s
# 		 nIn: 1,	 nOut: 	0	 in 27.2s
# 		 nIn: 1,	 nOut: 	1	 in 27.5s
# 		 nIn: 1,	 nOut: 	1	 in 27.7s
# 		 nIn: 1,	 nOut: 	1	 in 27.9s
# 		 nIn: 1,	 nOut: 	1	 in 28.2s
# 		 nIn: 1,	 nOut: 	1	 in 28.5s
# 		 nIn: 1,	 nOut: 	1	 in 28.7s
# 		 nIn: 1,	 nOut: 	0	 in 28.9s
# 		 nIn: 1,	 nOut: 	0	 in 29.2s
# 		 nIn: 1,	 nOut: 	0	 in 29.5s
# 		 nIn: 1,	 nOut: 	0	 in 29.8s
# 		 nIn: 1,	 nOut: 	0	 in 30.0s
# 		 nIn: 1,	 nOut: 	0	 in 30.2s
# 		 nIn: 1,	 nOut: 	0	 in 30.5s
# 		 nIn: 1,	 nOut: 	1	 in 30.7s
# 		 nIn: 1,	 nOut: 	1	 in 30.9s
# 		 nIn: 1,	 nOut: 	0	 in 31.2s
# 		 nIn: 1,	 nOut: 	1	 in 31.4s
# 		 nIn: 1,	 nOut: 	0	 in 31.6s
# 		 nIn: 1,	 nOut: 	1	 in 31.9s
# 		 nIn: 1,	 nOut: 	1	 in 32.1s
# 		 nIn: 1,	 nOut: 	0	 in 32.3s
# 		 nIn: 1,	 nOut: 	0	 in 32.6s
# 		 nIn: 1,	 nOut: 	1	 in 32.9s
# 		 nIn: 1,	 nOut: 	0	 in 33.1s
# 		 nIn: 1,	 nOut: 	0	 in 33.4s
# 		 nIn: 1,	 nOut: 	0	 in 33.7s
# 		 nIn: 1,	 nOut: 	1	 in 33.9s
# 		 nIn: 1,	 nOut: 	0	 in 34.1s
# 		 nIn: 1,	 nOut: 	0	 in 34.4s
# 		 nIn: 1,	 nOut: 	1	 in 34.6s
# 		 nIn: 1,	 nOut: 	1	 in 34.9s
# 		 nIn: 1,	 nOut: 	1	 in 35.1s
# 		 nIn: 1,	 nOut: 	0	 in 35.3s
# 		 nIn: 1,	 nOut: 	1	 in 35.6s
# 		 nIn: 1,	 nOut: 	1	 in 35.9s
# 		 nIn: 1,	 nOut: 	1	 in 36.3s
# 		 nIn: 1,	 nOut: 	0	 in 36.5s
# 		 nIn: 1,	 nOut: 	1	 in 36.8s
# 		 nIn: 1,	 nOut: 	1	 in 37.1s
# 		 nIn: 1,	 nOut: 	1	 in 37.4s
# 		 nIn: 1,	 nOut: 	0	 in 37.6s
# 		 nIn: 1,	 nOut: 	1	 in 37.8s
# 		 nIn: 1,	 nOut: 	1	 in 38.1s
# 		 nIn: 1,	 nOut: 	0	 in 38.3s
# 		 nIn: 1,	 nOut: 	1	 in 38.5s
# 		 nIn: 1,	 nOut: 	0	 in 38.7s
# 		 nIn: 1,	 nOut: 	0	 in 38.9s
# 		 nIn: 1,	 nOut: 	1	 in 39.2s
# 		 nIn: 1,	 nOut: 	0	 in 39.5s
# 		 nIn: 1,	 nOut: 	1	 in 39.8s
# 		 nIn: 1,	 nOut: 	0	 in 40.0s
# 		 nIn: 1,	 nOut: 	1	 in 40.3s
# 		 nIn: 1,	 nOut: 	1	 in 40.6s
# 		 nIn: 1,	 nOut: 	1	 in 40.8s
# 		 nIn: 1,	 nOut: 	0	 in 41.0s
# 		 nIn: 1,	 nOut: 	1	 in 41.3s
# 		 nIn: 1,	 nOut: 	0	 in 41.5s
# 		 nIn: 1,	 nOut: 	0	 in 41.7s
# 		 nIn: 1,	 nOut: 	1	 in 41.9s
# 		 nIn: 1,	 nOut: 	1	 in 42.2s
# 		 nIn: 1,	 nOut: 	1	 in 42.5s
# 		 nIn: 1,	 nOut: 	1	 in 42.8s
# 		 nIn: 1,	 nOut: 	1	 in 43.0s
# 		 nIn: 1,	 nOut: 	1	 in 43.2s
# 		 nIn: 1,	 nOut: 	1	 in 43.5s
# 		 nIn: 1,	 nOut: 	1	 in 43.8s
# 		 nIn: 1,	 nOut: 	1	 in 44.0s
# 		 nIn: 1,	 nOut: 	0	 in 44.2s
# 		 nIn: 1,	 nOut: 	1	 in 44.4s
# 		 nIn: 1,	 nOut: 	1	 in 44.7s
# 		 nIn: 1,	 nOut: 	0	 in 45.0s
# 		 nIn: 1,	 nOut: 	1	 in 45.2s
# 		 nIn: 1,	 nOut: 	0	 in 45.4s
# 		 nIn: 1,	 nOut: 	1	 in 45.7s
# 		 nIn: 1,	 nOut: 	0	 in 46.1s
# 		 nIn: 1,	 nOut: 	1	 in 46.3s
# 		 nIn: 1,	 nOut: 	1	 in 46.5s
# 		 nIn: 1,	 nOut: 	0	 in 46.8s
# 		 nIn: 1,	 nOut: 	1	 in 47.0s
# 		 nIn: 1,	 nOut: 	1	 in 47.3s
# 		 nIn: 1,	 nOut: 	0	 in 47.5s
# 		 nIn: 1,	 nOut: 	0	 in 47.8s
# 		 nIn: 1,	 nOut: 	0	 in 48.0s
# 		 nIn: 1,	 nOut: 	0	 in 48.2s
# 	Processing: data_C
# 		 nIn: 1,	 nOut: 	1	 in 6.6s
# 		 nIn: 1,	 nOut: 	1	 in 8.6s
# 		 nIn: 1,	 nOut: 	1	 in 8.7s
# 		 nIn: 1,	 nOut: 	1	 in 8.8s
# 		 nIn: 1,	 nOut: 	0	 in 9.0s
# 		 nIn: 1,	 nOut: 	1	 in 9.1s
# 		 nIn: 1,	 nOut: 	1	 in 9.3s
# 		 nIn: 1,	 nOut: 	0	 in 9.4s
# 		 nIn: 1,	 nOut: 	1	 in 9.6s
# 		 nIn: 1,	 nOut: 	0	 in 9.7s
# 		 nIn: 1,	 nOut: 	1	 in 9.8s
# 		 nIn: 1,	 nOut: 	0	 in 9.9s
# 		 nIn: 1,	 nOut: 	0	 in 10.1s
# 		 nIn: 1,	 nOut: 	0	 in 10.2s
# 		 nIn: 1,	 nOut: 	1	 in 10.3s
# 		 nIn: 1,	 nOut: 	1	 in 10.5s
# 		 nIn: 1,	 nOut: 	1	 in 10.7s
# 		 nIn: 1,	 nOut: 	0	 in 10.8s
# 		 nIn: 1,	 nOut: 	0	 in 10.9s
# 		 nIn: 1,	 nOut: 	0	 in 11.0s
# 		 nIn: 1,	 nOut: 	1	 in 11.2s
# 		 nIn: 1,	 nOut: 	0	 in 11.4s
# 		 nIn: 1,	 nOut: 	1	 in 11.5s
# 		 nIn: 1,	 nOut: 	0	 in 11.7s
# 		 nIn: 1,	 nOut: 	0	 in 11.8s
# 		 nIn: 1,	 nOut: 	0	 in 11.9s
# 		 nIn: 1,	 nOut: 	1	 in 12.0s
# 		 nIn: 1,	 nOut: 	0	 in 12.2s
# 		 nIn: 1,	 nOut: 	0	 in 12.4s
# 		 nIn: 1,	 nOut: 	1	 in 12.5s
# 		 nIn: 1,	 nOut: 	0	 in 12.7s
# 		 nIn: 1,	 nOut: 	0	 in 12.8s
# 		 nIn: 1,	 nOut: 	1	 in 13.0s
# 		 nIn: 1,	 nOut: 	0	 in 13.1s
# 		 nIn: 1,	 nOut: 	1	 in 13.3s
# 		 nIn: 1,	 nOut: 	1	 in 13.4s
# 		 nIn: 1,	 nOut: 	0	 in 13.6s
# 		 nIn: 1,	 nOut: 	0	 in 13.8s
# 		 nIn: 1,	 nOut: 	1	 in 14.0s
# 		 nIn: 1,	 nOut: 	1	 in 14.1s
# 		 nIn: 1,	 nOut: 	1	 in 14.3s
# 		 nIn: 1,	 nOut: 	0	 in 14.5s
# 		 nIn: 1,	 nOut: 	1	 in 14.7s
# 		 nIn: 1,	 nOut: 	1	 in 14.9s
# 		 nIn: 1,	 nOut: 	0	 in 15.1s
# 		 nIn: 1,	 nOut: 	1	 in 15.3s
# 		 nIn: 1,	 nOut: 	1	 in 15.6s
# 		 nIn: 1,	 nOut: 	1	 in 15.8s
# 		 nIn: 1,	 nOut: 	1	 in 16.0s
# 		 nIn: 1,	 nOut: 	1	 in 16.3s
# 		 nIn: 1,	 nOut: 	1	 in 16.6s
# 		 nIn: 1,	 nOut: 	0	 in 16.8s
# 		 nIn: 1,	 nOut: 	1	 in 17.0s
# 		 nIn: 1,	 nOut: 	0	 in 17.3s
# 		 nIn: 1,	 nOut: 	1	 in 17.5s
# 		 nIn: 1,	 nOut: 	0	 in 17.9s
# 		 nIn: 1,	 nOut: 	1	 in 18.1s
# 		 nIn: 1,	 nOut: 	1	 in 18.3s
# 		 nIn: 1,	 nOut: 	1	 in 18.7s
# 		 nIn: 1,	 nOut: 	1	 in 18.8s
# 		 nIn: 1,	 nOut: 	1	 in 19.1s
# 		 nIn: 1,	 nOut: 	1	 in 19.3s
# 		 nIn: 1,	 nOut: 	1	 in 19.5s
# 		 nIn: 1,	 nOut: 	1	 in 19.8s
# 		 nIn: 1,	 nOut: 	1	 in 20.0s
# 		 nIn: 1,	 nOut: 	0	 in 20.2s
# 		 nIn: 1,	 nOut: 	0	 in 20.4s
# 		 nIn: 1,	 nOut: 	0	 in 20.7s
# 		 nIn: 1,	 nOut: 	0	 in 21.0s
# 		 nIn: 1,	 nOut: 	1	 in 21.3s
# 		 nIn: 1,	 nOut: 	1	 in 21.5s
# 		 nIn: 1,	 nOut: 	1	 in 21.8s
# 		 nIn: 1,	 nOut: 	1	 in 22.0s
# 		 nIn: 1,	 nOut: 	0	 in 22.2s
# 		 nIn: 1,	 nOut: 	1	 in 22.5s
# 		 nIn: 1,	 nOut: 	1	 in 22.7s
# 		 nIn: 1,	 nOut: 	0	 in 23.0s
# 		 nIn: 1,	 nOut: 	1	 in 23.2s
# 		 nIn: 1,	 nOut: 	0	 in 23.5s
# 		 nIn: 1,	 nOut: 	1	 in 23.7s
# 		 nIn: 1,	 nOut: 	1	 in 24.0s
# 		 nIn: 1,	 nOut: 	1	 in 24.3s
# 		 nIn: 1,	 nOut: 	1	 in 24.6s
# 		 nIn: 1,	 nOut: 	0	 in 24.8s
# 		 nIn: 1,	 nOut: 	0	 in 25.1s
# 		 nIn: 1,	 nOut: 	0	 in 25.3s
# 		 nIn: 1,	 nOut: 	1	 in 25.5s
# 		 nIn: 1,	 nOut: 	1	 in 25.8s
# 		 nIn: 1,	 nOut: 	1	 in 26.0s
# 		 nIn: 1,	 nOut: 	0	 in 26.3s
# 		 nIn: 1,	 nOut: 	1	 in 26.5s
# 		 nIn: 1,	 nOut: 	0	 in 26.8s
# 		 nIn: 1,	 nOut: 	0	 in 27.0s
# 		 nIn: 1,	 nOut: 	1	 in 27.3s
# 		 nIn: 1,	 nOut: 	0	 in 27.5s
# 		 nIn: 1,	 nOut: 	1	 in 27.8s
# 		 nIn: 1,	 nOut: 	1	 in 28.1s
# 		 nIn: 1,	 nOut: 	1	 in 28.4s
# 		 nIn: 1,	 nOut: 	0	 in 28.6s
# 		 nIn: 1,	 nOut: 	0	 in 28.9s
# 		 nIn: 1,	 nOut: 	0	 in 29.1s
# 		 nIn: 1,	 nOut: 	1	 in 29.4s
# 		 nIn: 1,	 nOut: 	0	 in 29.7s
# 		 nIn: 1,	 nOut: 	1	 in 30.0s
# 		 nIn: 1,	 nOut: 	0	 in 30.3s
# 		 nIn: 1,	 nOut: 	0	 in 30.5s
# 		 nIn: 1,	 nOut: 	0	 in 30.8s
# 		 nIn: 1,	 nOut: 	0	 in 31.2s
# 		 nIn: 1,	 nOut: 	1	 in 31.4s
# 		 nIn: 1,	 nOut: 	0	 in 31.6s
# 		 nIn: 1,	 nOut: 	1	 in 31.9s
# 		 nIn: 1,	 nOut: 	1	 in 32.1s
# 		 nIn: 1,	 nOut: 	1	 in 32.3s
# 		 nIn: 1,	 nOut: 	0	 in 32.5s
# 		 nIn: 1,	 nOut: 	1	 in 32.8s
# 		 nIn: 1,	 nOut: 	1	 in 33.0s
# 		 nIn: 1,	 nOut: 	1	 in 33.3s
# 		 nIn: 1,	 nOut: 	1	 in 33.5s
# 		 nIn: 1,	 nOut: 	1	 in 33.8s
# 		 nIn: 1,	 nOut: 	0	 in 34.0s
# 		 nIn: 1,	 nOut: 	1	 in 34.3s
# 		 nIn: 1,	 nOut: 	0	 in 34.6s
# 		 nIn: 1,	 nOut: 	1	 in 34.8s
# 		 nIn: 1,	 nOut: 	0	 in 35.1s
# 		 nIn: 1,	 nOut: 	1	 in 35.3s
# 		 nIn: 1,	 nOut: 	1	 in 35.6s
# 		 nIn: 1,	 nOut: 	1	 in 35.8s
# 		 nIn: 1,	 nOut: 	1	 in 36.1s
# 		 nIn: 1,	 nOut: 	1	 in 36.3s
# 		 nIn: 1,	 nOut: 	0	 in 36.6s
# 		 nIn: 1,	 nOut: 	1	 in 36.9s
# 		 nIn: 1,	 nOut: 	1	 in 37.1s
# 		 nIn: 1,	 nOut: 	1	 in 37.4s
# 		 nIn: 1,	 nOut: 	0	 in 37.6s
# 		 nIn: 1,	 nOut: 	1	 in 37.9s
# 		 nIn: 1,	 nOut: 	1	 in 38.2s
# 		 nIn: 1,	 nOut: 	0	 in 38.4s
# 		 nIn: 1,	 nOut: 	1	 in 38.7s
# 		 nIn: 1,	 nOut: 	1	 in 38.9s
# 		 nIn: 1,	 nOut: 	1	 in 39.1s
# 		 nIn: 1,	 nOut: 	1	 in 39.4s
# 		 nIn: 1,	 nOut: 	1	 in 39.6s
# 		 nIn: 1,	 nOut: 	0	 in 39.8s
# 		 nIn: 1,	 nOut: 	1	 in 40.0s
# 		 nIn: 1,	 nOut: 	0	 in 40.3s
# 		 nIn: 1,	 nOut: 	1	 in 40.5s
# 		 nIn: 1,	 nOut: 	0	 in 40.7s
# 		 nIn: 1,	 nOut: 	1	 in 41.1s
# 		 nIn: 1,	 nOut: 	1	 in 41.4s
# 		 nIn: 1,	 nOut: 	1	 in 41.6s
# 		 nIn: 1,	 nOut: 	0	 in 41.8s
# 		 nIn: 1,	 nOut: 	1	 in 42.1s
# 		 nIn: 1,	 nOut: 	1	 in 42.4s
# 		 nIn: 1,	 nOut: 	0	 in 42.6s
# 		 nIn: 1,	 nOut: 	1	 in 42.8s
# 		 nIn: 1,	 nOut: 	1	 in 43.0s
# 		 nIn: 1,	 nOut: 	1	 in 43.3s
# 		 nIn: 1,	 nOut: 	0	 in 43.6s
# 		 nIn: 1,	 nOut: 	0	 in 43.8s
# 		 nIn: 1,	 nOut: 	1	 in 44.0s
# 		 nIn: 1,	 nOut: 	1	 in 44.4s
# 		 nIn: 1,	 nOut: 	1	 in 44.6s
# 		 nIn: 1,	 nOut: 	0	 in 44.8s
# 		 nIn: 1,	 nOut: 	0	 in 45.0s
# 		 nIn: 1,	 nOut: 	0	 in 45.3s
# 		 nIn: 1,	 nOut: 	0	 in 45.5s
# 		 nIn: 1,	 nOut: 	0	 in 45.7s
# 		 nIn: 1,	 nOut: 	1	 in 46.0s
# 		 nIn: 1,	 nOut: 	1	 in 46.2s
# 		 nIn: 1,	 nOut: 	1	 in 46.4s
# 		 nIn: 1,	 nOut: 	1	 in 46.7s
# 		 nIn: 1,	 nOut: 	0	 in 46.9s
# 		 nIn: 1,	 nOut: 	0	 in 47.1s
# 		 nIn: 1,	 nOut: 	1	 in 47.6s
# 		 nIn: 1,	 nOut: 	1	 in 47.8s
# 		 nIn: 1,	 nOut: 	0	 in 48.0s
# 		 nIn: 1,	 nOut: 	1	 in 48.3s
# 		 nIn: 1,	 nOut: 	0	 in 48.6s
# 		 nIn: 1,	 nOut: 	0	 in 48.8s
# 		 nIn: 1,	 nOut: 	0	 in 49.0s
# 		 nIn: 1,	 nOut: 	1	 in 49.3s
# 		 nIn: 1,	 nOut: 	1	 in 49.5s
# 		 nIn: 1,	 nOut: 	1	 in 49.7s
# 		 nIn: 1,	 nOut: 	0	 in 50.0s
# 		 nIn: 1,	 nOut: 	0	 in 50.2s
# 		 nIn: 1,	 nOut: 	1	 in 50.4s
# 		 nIn: 1,	 nOut: 	0	 in 50.8s
# 		 nIn: 1,	 nOut: 	1	 in 51.0s
# 		 nIn: 1,	 nOut: 	1	 in 51.3s
# 		 nIn: 1,	 nOut: 	1	 in 51.5s
# 		 nIn: 1,	 nOut: 	1	 in 51.7s
# 		 nIn: 1,	 nOut: 	0	 in 52.0s
# 		 nIn: 1,	 nOut: 	0	 in 52.2s
# 		 nIn: 1,	 nOut: 	1	 in 52.5s
# 		 nIn: 1,	 nOut: 	1	 in 52.8s
# 		 nIn: 1,	 nOut: 	1	 in 53.0s
# 		 nIn: 1,	 nOut: 	0	 in 53.3s
# 		 nIn: 1,	 nOut: 	0	 in 53.5s
# 		 nIn: 1,	 nOut: 	1	 in 54.0s
# 		 nIn: 1,	 nOut: 	0	 in 54.3s
# 		 nIn: 1,	 nOut: 	1	 in 54.6s
# 		 nIn: 1,	 nOut: 	1	 in 54.8s
# 		 nIn: 1,	 nOut: 	1	 in 55.1s
# 		 nIn: 1,	 nOut: 	1	 in 55.3s
# 		 nIn: 1,	 nOut: 	1	 in 55.6s
# 		 nIn: 1,	 nOut: 	1	 in 55.8s
# 		 nIn: 1,	 nOut: 	0	 in 56.0s
# 		 nIn: 1,	 nOut: 	1	 in 56.3s
# 		 nIn: 1,	 nOut: 	1	 in 56.6s
# 		 nIn: 1,	 nOut: 	0	 in 56.8s
# 		 nIn: 1,	 nOut: 	1	 in 57.0s
# 		 nIn: 1,	 nOut: 	0	 in 57.4s
# 		 nIn: 1,	 nOut: 	0	 in 57.7s
# 		 nIn: 1,	 nOut: 	1	 in 58.0s
# 		 nIn: 1,	 nOut: 	1	 in 58.2s
# 		 nIn: 1,	 nOut: 	1	 in 58.5s
# 		 nIn: 1,	 nOut: 	1	 in 58.7s
# 		 nIn: 1,	 nOut: 	0	 in 59.0s
# 		 nIn: 1,	 nOut: 	0	 in 59.2s
# 		 nIn: 1,	 nOut: 	0	 in 59.5s
# 		 nIn: 1,	 nOut: 	1	 in 59.8s
# 		 nIn: 1,	 nOut: 	1	 in 60.0s
# 		 nIn: 1,	 nOut: 	1	 in 60.2s
# 		 nIn: 1,	 nOut: 	1	 in 60.5s
# 		 nIn: 1,	 nOut: 	1	 in 60.9s
# 		 nIn: 1,	 nOut: 	1	 in 61.1s
# 		 nIn: 1,	 nOut: 	1	 in 61.3s
# 		 nIn: 1,	 nOut: 	1	 in 61.6s
# 		 nIn: 1,	 nOut: 	1	 in 61.8s
# 		 nIn: 1,	 nOut: 	0	 in 62.0s
# 		 nIn: 1,	 nOut: 	0	 in 62.3s
# 		 nIn: 1,	 nOut: 	1	 in 62.5s
# 		 nIn: 1,	 nOut: 	1	 in 62.8s
# 		 nIn: 1,	 nOut: 	1	 in 63.0s
# 		 nIn: 1,	 nOut: 	1	 in 63.2s
# 		 nIn: 1,	 nOut: 	1	 in 63.5s
# 		 nIn: 1,	 nOut: 	0	 in 63.8s
# 	Processing: data_D
# 		 nIn: 1,	 nOut: 	1	 in 5.7s
# 		 nIn: 1,	 nOut: 	0	 in 6.4s
# 		 nIn: 1,	 nOut: 	0	 in 6.7s
# 		 nIn: 1,	 nOut: 	1	 in 7.0s
# 		 nIn: 1,	 nOut: 	0	 in 7.3s
# 		 nIn: 1,	 nOut: 	0	 in 7.7s
# 		 nIn: 1,	 nOut: 	0	 in 7.9s
# 		 nIn: 1,	 nOut: 	0	 in 8.2s
# 		 nIn: 1,	 nOut: 	0	 in 8.5s
# 		 nIn: 1,	 nOut: 	1	 in 8.8s
# 		 nIn: 1,	 nOut: 	0	 in 9.1s
# 		 nIn: 1,	 nOut: 	1	 in 9.3s
# 		 nIn: 1,	 nOut: 	0	 in 9.6s
# 		 nIn: 1,	 nOut: 	1	 in 9.9s
# 		 nIn: 1,	 nOut: 	1	 in 10.1s
# 		 nIn: 1,	 nOut: 	0	 in 10.4s
# 		 nIn: 1,	 nOut: 	0	 in 10.7s
# 		 nIn: 1,	 nOut: 	1	 in 11.0s
# 		 nIn: 1,	 nOut: 	1	 in 11.5s
# 		 nIn: 1,	 nOut: 	0	 in 11.8s
# 		 nIn: 1,	 nOut: 	1	 in 12.1s
# 		 nIn: 1,	 nOut: 	0	 in 12.4s
# 		 nIn: 1,	 nOut: 	1	 in 12.7s
# 		 nIn: 1,	 nOut: 	0	 in 13.0s
# 		 nIn: 1,	 nOut: 	1	 in 13.4s
# 		 nIn: 1,	 nOut: 	0	 in 13.7s
# 		 nIn: 1,	 nOut: 	0	 in 14.0s
# 		 nIn: 1,	 nOut: 	1	 in 14.3s
# 		 nIn: 1,	 nOut: 	0	 in 14.6s
# 		 nIn: 1,	 nOut: 	1	 in 14.8s
# 		 nIn: 1,	 nOut: 	0	 in 15.1s
# 		 nIn: 1,	 nOut: 	1	 in 15.5s
# 		 nIn: 1,	 nOut: 	0	 in 15.8s
# 		 nIn: 1,	 nOut: 	1	 in 16.0s
# 		 nIn: 1,	 nOut: 	1	 in 16.3s
# 		 nIn: 1,	 nOut: 	1	 in 16.6s
# 		 nIn: 1,	 nOut: 	1	 in 16.9s
# 		 nIn: 1,	 nOut: 	1	 in 17.2s
# 		 nIn: 1,	 nOut: 	1	 in 17.5s
# 		 nIn: 1,	 nOut: 	0	 in 17.8s
# 		 nIn: 1,	 nOut: 	0	 in 18.0s
# 		 nIn: 1,	 nOut: 	0	 in 18.3s
# 		 nIn: 1,	 nOut: 	1	 in 18.5s
# 		 nIn: 1,	 nOut: 	1	 in 18.8s
# 		 nIn: 1,	 nOut: 	1	 in 19.1s
# 		 nIn: 1,	 nOut: 	1	 in 19.4s
# 		 nIn: 1,	 nOut: 	1	 in 19.6s
# 		 nIn: 1,	 nOut: 	1	 in 19.9s
# 		 nIn: 1,	 nOut: 	1	 in 20.1s
# 		 nIn: 1,	 nOut: 	1	 in 20.4s
# 		 nIn: 1,	 nOut: 	1	 in 20.6s
# 		 nIn: 1,	 nOut: 	1	 in 20.9s
# 		 nIn: 1,	 nOut: 	1	 in 21.1s
# 		 nIn: 1,	 nOut: 	0	 in 21.4s
# 		 nIn: 1,	 nOut: 	1	 in 21.6s
# 		 nIn: 1,	 nOut: 	0	 in 21.8s
# 		 nIn: 1,	 nOut: 	0	 in 22.0s
# 		 nIn: 1,	 nOut: 	1	 in 22.3s
# 		 nIn: 1,	 nOut: 	1	 in 22.7s
# 		 nIn: 1,	 nOut: 	1	 in 22.9s
# 		 nIn: 1,	 nOut: 	0	 in 23.2s
# 		 nIn: 1,	 nOut: 	1	 in 23.4s
# 		 nIn: 1,	 nOut: 	0	 in 23.7s
# 		 nIn: 1,	 nOut: 	1	 in 23.9s
# 		 nIn: 1,	 nOut: 	0	 in 24.2s
# 		 nIn: 1,	 nOut: 	1	 in 24.4s
# 		 nIn: 1,	 nOut: 	0	 in 24.8s
# 		 nIn: 1,	 nOut: 	1	 in 25.0s
# 		 nIn: 1,	 nOut: 	1	 in 25.2s
# 		 nIn: 1,	 nOut: 	1	 in 25.5s
# 		 nIn: 1,	 nOut: 	0	 in 25.8s
# 		 nIn: 1,	 nOut: 	0	 in 26.0s
# 		 nIn: 1,	 nOut: 	1	 in 26.3s
# 		 nIn: 1,	 nOut: 	0	 in 26.5s
# 		 nIn: 1,	 nOut: 	0	 in 26.8s
# 		 nIn: 1,	 nOut: 	1	 in 27.0s
# 		 nIn: 1,	 nOut: 	1	 in 27.3s
# 		 nIn: 1,	 nOut: 	1	 in 27.6s
# 		 nIn: 1,	 nOut: 	0	 in 27.8s
# 		 nIn: 1,	 nOut: 	1	 in 28.1s
# 		 nIn: 1,	 nOut: 	0	 in 28.3s
# 		 nIn: 1,	 nOut: 	1	 in 28.6s
# 		 nIn: 1,	 nOut: 	0	 in 28.8s
# 		 nIn: 1,	 nOut: 	1	 in 29.0s
# 		 nIn: 1,	 nOut: 	1	 in 29.4s
# 		 nIn: 1,	 nOut: 	1	 in 29.7s
# 		 nIn: 1,	 nOut: 	1	 in 29.9s
# 		 nIn: 1,	 nOut: 	1	 in 30.1s
# 		 nIn: 1,	 nOut: 	1	 in 30.4s
# 		 nIn: 1,	 nOut: 	0	 in 30.6s
# 		 nIn: 1,	 nOut: 	0	 in 30.9s
# 		 nIn: 1,	 nOut: 	0	 in 31.1s
# 		 nIn: 1,	 nOut: 	0	 in 31.3s
# 		 nIn: 1,	 nOut: 	1	 in 31.6s
# 		 nIn: 1,	 nOut: 	1	 in 31.9s
# 		 nIn: 1,	 nOut: 	0	 in 32.2s
# 		 nIn: 1,	 nOut: 	1	 in 32.5s
# 		 nIn: 1,	 nOut: 	0	 in 32.8s
# 		 nIn: 1,	 nOut: 	0	 in 33.0s
# 		 nIn: 1,	 nOut: 	0	 in 33.2s
# 		 nIn: 1,	 nOut: 	0	 in 33.5s
# 		 nIn: 1,	 nOut: 	1	 in 33.7s
# 		 nIn: 1,	 nOut: 	1	 in 34.0s
# 		 nIn: 1,	 nOut: 	1	 in 34.2s
# 		 nIn: 1,	 nOut: 	0	 in 34.5s
# 		 nIn: 1,	 nOut: 	1	 in 34.7s
# 		 nIn: 1,	 nOut: 	1	 in 35.0s
# 		 nIn: 1,	 nOut: 	1	 in 35.2s
# 		 nIn: 1,	 nOut: 	0	 in 35.5s
# 		 nIn: 1,	 nOut: 	1	 in 35.7s
# 		 nIn: 1,	 nOut: 	0	 in 36.0s
# 		 nIn: 1,	 nOut: 	0	 in 36.3s
# 		 nIn: 1,	 nOut: 	1	 in 36.5s
# 		 nIn: 1,	 nOut: 	1	 in 36.8s
# 		 nIn: 1,	 nOut: 	1	 in 37.0s
# 		 nIn: 1,	 nOut: 	1	 in 37.3s
# 		 nIn: 1,	 nOut: 	0	 in 37.5s
# 		 nIn: 1,	 nOut: 	1	 in 37.8s
# 		 nIn: 1,	 nOut: 	0	 in 38.2s
# 		 nIn: 1,	 nOut: 	1	 in 38.5s
# 		 nIn: 1,	 nOut: 	0	 in 38.8s
# 		 nIn: 1,	 nOut: 	0	 in 39.1s
# 		 nIn: 1,	 nOut: 	1	 in 39.3s
# 		 nIn: 1,	 nOut: 	1	 in 39.7s
# 		 nIn: 1,	 nOut: 	1	 in 39.9s
# 		 nIn: 1,	 nOut: 	0	 in 40.1s
# 		 nIn: 1,	 nOut: 	1	 in 40.4s
# 		 nIn: 1,	 nOut: 	1	 in 40.6s
# 		 nIn: 1,	 nOut: 	0	 in 40.9s
# 		 nIn: 1,	 nOut: 	1	 in 41.1s
# 		 nIn: 1,	 nOut: 	1	 in 41.4s
# 		 nIn: 1,	 nOut: 	0	 in 41.6s
# 		 nIn: 1,	 nOut: 	0	 in 41.8s
# 		 nIn: 1,	 nOut: 	1	 in 42.1s
# 		 nIn: 1,	 nOut: 	1	 in 42.3s
# 		 nIn: 1,	 nOut: 	1	 in 42.5s
# 		 nIn: 1,	 nOut: 	1	 in 42.9s
# 		 nIn: 1,	 nOut: 	1	 in 43.1s
# 		 nIn: 1,	 nOut: 	1	 in 43.3s
# 		 nIn: 1,	 nOut: 	0	 in 43.6s
# 		 nIn: 1,	 nOut: 	1	 in 43.8s
# 		 nIn: 1,	 nOut: 	1	 in 44.1s
# 		 nIn: 1,	 nOut: 	1	 in 44.5s
# 		 nIn: 1,	 nOut: 	0	 in 44.7s
# 		 nIn: 1,	 nOut: 	1	 in 44.9s
# 		 nIn: 1,	 nOut: 	1	 in 45.2s
# 		 nIn: 1,	 nOut: 	1	 in 45.5s
# 		 nIn: 1,	 nOut: 	1	 in 45.7s
# 		 nIn: 1,	 nOut: 	1	 in 46.1s
# 		 nIn: 1,	 nOut: 	0	 in 46.3s
# 		 nIn: 1,	 nOut: 	0	 in 46.6s
# 		 nIn: 1,	 nOut: 	1	 in 46.8s
# 		 nIn: 1,	 nOut: 	0	 in 47.0s
# 		 nIn: 1,	 nOut: 	0	 in 47.3s
# 		 nIn: 1,	 nOut: 	0	 in 47.6s
# 		 nIn: 1,	 nOut: 	1	 in 47.8s
# 		 nIn: 1,	 nOut: 	1	 in 48.1s
# 		 nIn: 1,	 nOut: 	1	 in 48.3s
# 		 nIn: 1,	 nOut: 	1	 in 48.6s
# 		 nIn: 1,	 nOut: 	1	 in 48.8s
# 		 nIn: 1,	 nOut: 	1	 in 49.1s
# 		 nIn: 1,	 nOut: 	0	 in 49.4s
# 		 nIn: 1,	 nOut: 	1	 in 49.6s
# 		 nIn: 1,	 nOut: 	0	 in 49.9s
# 		 nIn: 1,	 nOut: 	0	 in 50.1s
# 		 nIn: 1,	 nOut: 	1	 in 50.5s
# 		 nIn: 1,	 nOut: 	0	 in 50.7s
# 		 nIn: 1,	 nOut: 	0	 in 50.9s
# 		 nIn: 1,	 nOut: 	1	 in 51.1s
# 		 nIn: 1,	 nOut: 	0	 in 51.4s
# 		 nIn: 1,	 nOut: 	0	 in 51.6s
# 		 nIn: 1,	 nOut: 	0	 in 51.9s
# 		 nIn: 1,	 nOut: 	1	 in 52.3s
# 		 nIn: 1,	 nOut: 	1	 in 52.5s
# 		 nIn: 1,	 nOut: 	1	 in 52.7s
# 		 nIn: 1,	 nOut: 	1	 in 52.9s
# 		 nIn: 1,	 nOut: 	1	 in 53.0s
# 		 nIn: 1,	 nOut: 	1	 in 53.2s
# 		 nIn: 1,	 nOut: 	1	 in 53.5s
# 		 nIn: 1,	 nOut: 	1	 in 53.7s
# 		 nIn: 1,	 nOut: 	0	 in 53.9s
# 		 nIn: 1,	 nOut: 	1	 in 54.0s
# 		 nIn: 1,	 nOut: 	1	 in 54.2s
# 		 nIn: 1,	 nOut: 	1	 in 54.4s
# 		 nIn: 1,	 nOut: 	0	 in 54.5s
# 		 nIn: 1,	 nOut: 	0	 in 54.7s
# 		 nIn: 1,	 nOut: 	1	 in 54.8s
# 		 nIn: 1,	 nOut: 	0	 in 54.9s
# 		 nIn: 1,	 nOut: 	0	 in 55.1s
# 		 nIn: 1,	 nOut: 	0	 in 55.3s
# 		 nIn: 1,	 nOut: 	0	 in 55.5s
# 		 nIn: 1,	 nOut: 	1	 in 55.7s
# 		 nIn: 1,	 nOut: 	1	 in 55.8s
# 		 nIn: 1,	 nOut: 	0	 in 56.0s
# 		 nIn: 1,	 nOut: 	1	 in 56.1s
# 		 nIn: 1,	 nOut: 	1	 in 56.3s
# 		 nIn: 1,	 nOut: 	1	 in 56.4s
# 		 nIn: 1,	 nOut: 	0	 in 56.6s
# 		 nIn: 1,	 nOut: 	1	 in 56.7s
# 		 nIn: 1,	 nOut: 	1	 in 56.9s
# 		 nIn: 1,	 nOut: 	1	 in 57.0s
# 		 nIn: 1,	 nOut: 	1	 in 57.1s
# 		 nIn: 1,	 nOut: 	0	 in 57.3s
# 		 nIn: 1,	 nOut: 	0	 in 57.6s
# 		 nIn: 1,	 nOut: 	1	 in 57.7s
# 		 nIn: 1,	 nOut: 	0	 in 57.9s
# 		 nIn: 1,	 nOut: 	1	 in 58.0s
# 		 nIn: 1,	 nOut: 	0	 in 58.1s
# 		 nIn: 1,	 nOut: 	1	 in 58.3s
# 		 nIn: 1,	 nOut: 	0	 in 58.5s
# 		 nIn: 1,	 nOut: 	1	 in 58.6s
# 		 nIn: 1,	 nOut: 	1	 in 58.8s
# 		 nIn: 1,	 nOut: 	0	 in 58.9s
# 		 nIn: 1,	 nOut: 	0	 in 59.0s
# 		 nIn: 1,	 nOut: 	0	 in 59.2s
# 		 nIn: 1,	 nOut: 	0	 in 59.4s
# 		 nIn: 1,	 nOut: 	1	 in 59.5s
# 		 nIn: 1,	 nOut: 	0	 in 59.7s
# 		 nIn: 1,	 nOut: 	1	 in 59.8s
# 		 nIn: 1,	 nOut: 	1	 in 60.0s
# 		 nIn: 1,	 nOut: 	1	 in 60.1s
# 		 nIn: 1,	 nOut: 	1	 in 60.3s
# 		 nIn: 1,	 nOut: 	1	 in 60.4s
# 		 nIn: 1,	 nOut: 	1	 in 60.6s
# 		 nIn: 1,	 nOut: 	0	 in 60.8s
# 		 nIn: 1,	 nOut: 	1	 in 60.9s
# 		 nIn: 1,	 nOut: 	0	 in 61.0s
# 		 nIn: 1,	 nOut: 	1	 in 61.2s
# 		 nIn: 1,	 nOut: 	1	 in 61.3s
# 		 nIn: 1,	 nOut: 	0	 in 61.5s
# 		 nIn: 1,	 nOut: 	1	 in 61.7s
# 		 nIn: 1,	 nOut: 	1	 in 61.8s
# 		 nIn: 1,	 nOut: 	1	 in 61.9s
# 		 nIn: 1,	 nOut: 	0	 in 62.0s
# 		 nIn: 1,	 nOut: 	0	 in 62.2s
# 		 nIn: 1,	 nOut: 	1	 in 62.4s
# 		 nIn: 1,	 nOut: 	0	 in 62.5s
# 		 nIn: 1,	 nOut: 	1	 in 62.7s
# 		 nIn: 1,	 nOut: 	1	 in 62.8s
# 		 nIn: 1,	 nOut: 	1	 in 63.0s
# 		 nIn: 1,	 nOut: 	0	 in 63.1s
# 		 nIn: 1,	 nOut: 	1	 in 63.2s
# 		 nIn: 1,	 nOut: 	1	 in 63.5s
# 		 nIn: 1,	 nOut: 	1	 in 63.7s
# 		 nIn: 1,	 nOut: 	0	 in 63.8s
# 		 nIn: 1,	 nOut: 	1	 in 64.1s
# 		 nIn: 1,	 nOut: 	1	 in 64.2s
# 		 nIn: 1,	 nOut: 	1	 in 64.4s
# 		 nIn: 1,	 nOut: 	0	 in 64.7s
# 		 nIn: 1,	 nOut: 	1	 in 64.9s
# 		 nIn: 1,	 nOut: 	1	 in 65.0s
# 		 nIn: 1,	 nOut: 	1	 in 65.1s
# 		 nIn: 1,	 nOut: 	0	 in 65.3s
# 		 nIn: 1,	 nOut: 	1	 in 65.5s
# 		 nIn: 1,	 nOut: 	1	 in 65.6s
# 		 nIn: 1,	 nOut: 	0	 in 65.8s
# 		 nIn: 1,	 nOut: 	0	 in 65.9s
# 		 nIn: 1,	 nOut: 	1	 in 66.1s
# 		 nIn: 1,	 nOut: 	1	 in 66.4s
# 		 nIn: 1,	 nOut: 	0	 in 66.6s
# 		 nIn: 1,	 nOut: 	1	 in 66.9s
# 		 nIn: 1,	 nOut: 	1	 in 67.1s
# 		 nIn: 1,	 nOut: 	1	 in 67.4s
# 		 nIn: 1,	 nOut: 	1	 in 67.6s
# 		 nIn: 1,	 nOut: 	1	 in 67.9s
# 		 nIn: 1,	 nOut: 	1	 in 68.3s
# 		 nIn: 1,	 nOut: 	0	 in 68.5s
# 		 nIn: 1,	 nOut: 	0	 in 68.8s
# 		 nIn: 1,	 nOut: 	1	 in 69.0s
# 		 nIn: 1,	 nOut: 	0	 in 69.3s
# 		 nIn: 1,	 nOut: 	1	 in 69.6s
# 		 nIn: 1,	 nOut: 	1	 in 69.8s
# 		 nIn: 1,	 nOut: 	1	 in 70.2s
# 		 nIn: 1,	 nOut: 	0	 in 70.5s
# 		 nIn: 1,	 nOut: 	1	 in 70.7s
# 		 nIn: 1,	 nOut: 	0	 in 71.0s
# 		 nIn: 1,	 nOut: 	1	 in 71.2s
# 		 nIn: 1,	 nOut: 	1	 in 71.5s
# 		 nIn: 1,	 nOut: 	0	 in 71.7s
# 		 nIn: 1,	 nOut: 	1	 in 72.0s
# 		 nIn: 1,	 nOut: 	0	 in 72.2s
# 		 nIn: 1,	 nOut: 	0	 in 72.5s
# 		 nIn: 1,	 nOut: 	1	 in 72.8s
# 		 nIn: 1,	 nOut: 	1	 in 73.2s
# 		 nIn: 1,	 nOut: 	1	 in 73.5s
# 		 nIn: 1,	 nOut: 	1	 in 73.8s
# 		 nIn: 1,	 nOut: 	1	 in 74.1s
# 		 nIn: 1,	 nOut: 	0	 in 74.3s
# 		 nIn: 1,	 nOut: 	1	 in 74.6s
# 		 nIn: 1,	 nOut: 	0	 in 74.9s
# 		 nIn: 1,	 nOut: 	1	 in 75.2s
# 		 nIn: 1,	 nOut: 	1	 in 75.5s
# 		 nIn: 1,	 nOut: 	0	 in 75.8s
# 		 nIn: 1,	 nOut: 	1	 in 76.0s
# 		 nIn: 1,	 nOut: 	1	 in 76.2s
# 		 nIn: 1,	 nOut: 	1	 in 76.5s
# 		 nIn: 1,	 nOut: 	0	 in 76.9s
# 		 nIn: 1,	 nOut: 	1	 in 77.1s
# 		 nIn: 1,	 nOut: 	1	 in 77.4s
# 		 nIn: 1,	 nOut: 	1	 in 77.6s
# 		 nIn: 1,	 nOut: 	1	 in 77.9s
# 		 nIn: 1,	 nOut: 	0	 in 78.1s
# 		 nIn: 1,	 nOut: 	1	 in 78.4s
# 		 nIn: 1,	 nOut: 	0	 in 78.6s
# 		 nIn: 1,	 nOut: 	1	 in 78.9s
# 		 nIn: 1,	 nOut: 	1	 in 79.1s
# 		 nIn: 1,	 nOut: 	0	 in 79.3s
# 		 nIn: 1,	 nOut: 	0	 in 79.6s
# 		 nIn: 1,	 nOut: 	0	 in 79.9s
# 		 nIn: 1,	 nOut: 	1	 in 80.3s
# 		 nIn: 1,	 nOut: 	1	 in 80.5s
# 		 nIn: 1,	 nOut: 	0	 in 80.8s
# 		 nIn: 1,	 nOut: 	0	 in 81.0s
# 		 nIn: 1,	 nOut: 	1	 in 81.3s
# 		 nIn: 1,	 nOut: 	1	 in 81.7s
# 		 nIn: 1,	 nOut: 	1	 in 81.9s
# 		 nIn: 1,	 nOut: 	1	 in 82.1s
# 		 nIn: 1,	 nOut: 	1	 in 82.4s
# 		 nIn: 1,	 nOut: 	1	 in 82.6s
# 		 nIn: 1,	 nOut: 	1	 in 82.9s
# 		 nIn: 1,	 nOut: 	1	 in 83.1s
# 		 nIn: 1,	 nOut: 	1	 in 83.4s
# 		 nIn: 1,	 nOut: 	1	 in 83.8s
# 		 nIn: 1,	 nOut: 	1	 in 84.1s
# 		 nIn: 1,	 nOut: 	0	 in 84.4s
# 		 nIn: 1,	 nOut: 	1	 in 84.6s
# 		 nIn: 1,	 nOut: 	1	 in 84.9s
# 		 nIn: 1,	 nOut: 	1	 in 85.2s
# 		 nIn: 1,	 nOut: 	1	 in 85.4s
# 		 nIn: 1,	 nOut: 	0	 in 85.7s
# 		 nIn: 1,	 nOut: 	0	 in 85.9s
# 		 nIn: 1,	 nOut: 	0	 in 86.1s
# 		 nIn: 1,	 nOut: 	0	 in 86.4s
# 		 nIn: 1,	 nOut: 	0	 in 86.6s
# 		 nIn: 1,	 nOut: 	0	 in 86.9s
# 		 nIn: 1,	 nOut: 	0	 in 87.1s
# 		 nIn: 1,	 nOut: 	1	 in 87.5s
# 		 nIn: 1,	 nOut: 	1	 in 87.8s
# 		 nIn: 1,	 nOut: 	0	 in 88.0s
# 		 nIn: 1,	 nOut: 	1	 in 88.3s
# 		 nIn: 1,	 nOut: 	1	 in 88.5s
# 		 nIn: 1,	 nOut: 	0	 in 88.8s
# 		 nIn: 1,	 nOut: 	1	 in 89.1s
# 		 nIn: 1,	 nOut: 	1	 in 89.3s
# 		 nIn: 1,	 nOut: 	0	 in 89.6s
# 		 nIn: 1,	 nOut: 	1	 in 89.9s
# 		 nIn: 1,	 nOut: 	0	 in 90.1s
# 		 nIn: 1,	 nOut: 	1	 in 90.4s
# 		 nIn: 1,	 nOut: 	1	 in 90.6s
# 		 nIn: 1,	 nOut: 	1	 in 91.1s
# 		 nIn: 1,	 nOut: 	1	 in 91.3s
# 		 nIn: 1,	 nOut: 	0	 in 91.6s
# 		 nIn: 1,	 nOut: 	1	 in 91.9s
# 		 nIn: 1,	 nOut: 	1	 in 92.1s
# 		 nIn: 1,	 nOut: 	1	 in 92.4s
# 		 nIn: 1,	 nOut: 	1	 in 92.6s
# 		 nIn: 1,	 nOut: 	1	 in 92.9s
# 		 nIn: 1,	 nOut: 	1	 in 93.1s
# 		 nIn: 1,	 nOut: 	0	 in 93.4s
# 		 nIn: 1,	 nOut: 	1	 in 93.6s
# 		 nIn: 1,	 nOut: 	1	 in 93.9s
# 		 nIn: 1,	 nOut: 	1	 in 94.1s
# 		 nIn: 1,	 nOut: 	1	 in 94.5s
# 		 nIn: 1,	 nOut: 	0	 in 94.7s
# 		 nIn: 1,	 nOut: 	1	 in 95.0s
# 		 nIn: 1,	 nOut: 	0	 in 95.2s
# 		 nIn: 1,	 nOut: 	1	 in 95.5s
# 		 nIn: 1,	 nOut: 	1	 in 95.8s
# 		 nIn: 1,	 nOut: 	0	 in 96.0s
# 		 nIn: 1,	 nOut: 	0	 in 96.2s
# 		 nIn: 1,	 nOut: 	1	 in 96.5s
# 		 nIn: 1,	 nOut: 	1	 in 96.7s
# 		 nIn: 1,	 nOut: 	1	 in 97.0s
# 		 nIn: 1,	 nOut: 	1	 in 97.2s
# 		 nIn: 1,	 nOut: 	1	 in 97.5s
# 		 nIn: 1,	 nOut: 	1	 in 97.8s
# 		 nIn: 1,	 nOut: 	1	 in 98.1s
# 		 nIn: 1,	 nOut: 	1	 in 98.3s
# 		 nIn: 1,	 nOut: 	0	 in 98.6s
# 		 nIn: 1,	 nOut: 	0	 in 98.9s
# 		 nIn: 1,	 nOut: 	1	 in 99.1s
# 		 nIn: 1,	 nOut: 	1	 in 99.3s
# 		 nIn: 1,	 nOut: 	1	 in 99.6s
# 		 nIn: 1,	 nOut: 	0	 in 99.9s
# 		 nIn: 1,	 nOut: 	1	 in 100.1s
# 		 nIn: 1,	 nOut: 	0	 in 100.3s
# 		 nIn: 1,	 nOut: 	1	 in 100.6s
# 		 nIn: 1,	 nOut: 	0	 in 101.0s
# 		 nIn: 1,	 nOut: 	1	 in 101.2s
# 		 nIn: 1,	 nOut: 	1	 in 101.6s
# 		 nIn: 1,	 nOut: 	0	 in 101.8s
# 		 nIn: 1,	 nOut: 	0	 in 102.1s
# 		 nIn: 1,	 nOut: 	0	 in 102.3s
# 		 nIn: 1,	 nOut: 	0	 in 102.6s
# 		 nIn: 1,	 nOut: 	1	 in 102.9s
# 		 nIn: 1,	 nOut: 	1	 in 103.1s
# 		 nIn: 1,	 nOut: 	1	 in 103.3s
# 		 nIn: 1,	 nOut: 	0	 in 103.6s
# 		 nIn: 1,	 nOut: 	1	 in 103.8s
# 		 nIn: 1,	 nOut: 	0	 in 104.1s
# Processing Background $Z,t\bar{t}$ samples
# 	Processing: Zee
# 		 nIn: 1,	 nOut: 	0	 in 10.3s
# 		 nIn: 1,	 nOut: 	0	 in 12.5s
# 		 nIn: 1,	 nOut: 	0	 in 12.7s
# 		 nIn: 1,	 nOut: 	1	 in 13.0s
# 		 nIn: 1,	 nOut: 	0	 in 13.2s
# 		 nIn: 1,	 nOut: 	0	 in 13.5s
# 		 nIn: 1,	 nOut: 	0	 in 13.8s
# 		 nIn: 1,	 nOut: 	0	 in 14.0s
# 		 nIn: 1,	 nOut: 	0	 in 14.2s
# 		 nIn: 1,	 nOut: 	0	 in 14.5s
# 		 nIn: 1,	 nOut: 	0	 in 14.7s
# 		 nIn: 1,	 nOut: 	1	 in 14.9s
# 		 nIn: 1,	 nOut: 	0	 in 15.2s
# 		 nIn: 1,	 nOut: 	0	 in 15.4s
# 		 nIn: 1,	 nOut: 	1	 in 15.7s
# 		 nIn: 1,	 nOut: 	0	 in 16.0s
# 		 nIn: 1,	 nOut: 	1	 in 16.3s
# 		 nIn: 1,	 nOut: 	1	 in 16.5s
# 		 nIn: 1,	 nOut: 	0	 in 16.7s
# 		 nIn: 1,	 nOut: 	0	 in 17.0s
# 		 nIn: 1,	 nOut: 	1	 in 17.3s
# 		 nIn: 1,	 nOut: 	1	 in 17.5s
# 		 nIn: 1,	 nOut: 	0	 in 17.7s
# 		 nIn: 1,	 nOut: 	1	 in 18.0s
# 		 nIn: 1,	 nOut: 	0	 in 18.2s
# 		 nIn: 1,	 nOut: 	0	 in 18.5s
# 		 nIn: 1,	 nOut: 	0	 in 18.7s
# 		 nIn: 1,	 nOut: 	0	 in 19.0s
# 		 nIn: 1,	 nOut: 	0	 in 19.2s
# 		 nIn: 1,	 nOut: 	0	 in 19.4s
# 		 nIn: 1,	 nOut: 	0	 in 19.6s
# 		 nIn: 1,	 nOut: 	0	 in 19.9s
# 		 nIn: 1,	 nOut: 	0	 in 20.2s
# 		 nIn: 1,	 nOut: 	0	 in 20.4s
# 		 nIn: 1,	 nOut: 	0	 in 20.7s
# 		 nIn: 1,	 nOut: 	0	 in 20.9s
# 		 nIn: 1,	 nOut: 	0	 in 21.2s
# 		 nIn: 1,	 nOut: 	0	 in 21.4s
# 		 nIn: 1,	 nOut: 	0	 in 21.6s
# 		 nIn: 1,	 nOut: 	0	 in 21.9s
# 		 nIn: 1,	 nOut: 	1	 in 22.2s
# 		 nIn: 1,	 nOut: 	0	 in 22.4s
# 		 nIn: 1,	 nOut: 	1	 in 22.6s
# 		 nIn: 1,	 nOut: 	0	 in 22.8s
# 		 nIn: 1,	 nOut: 	1	 in 23.1s
# 		 nIn: 1,	 nOut: 	0	 in 23.5s
# 		 nIn: 1,	 nOut: 	0	 in 23.7s
# 		 nIn: 1,	 nOut: 	1	 in 24.0s
# 		 nIn: 1,	 nOut: 	1	 in 24.3s
# 		 nIn: 1,	 nOut: 	0	 in 24.6s
# 		 nIn: 1,	 nOut: 	0	 in 24.9s
# 		 nIn: 1,	 nOut: 	0	 in 25.1s
# 		 nIn: 1,	 nOut: 	0	 in 25.4s
# 		 nIn: 1,	 nOut: 	0	 in 25.6s
# 		 nIn: 1,	 nOut: 	1	 in 25.9s
# 		 nIn: 1,	 nOut: 	0	 in 26.1s
# 		 nIn: 1,	 nOut: 	0	 in 26.4s
# 		 nIn: 1,	 nOut: 	0	 in 26.6s
# 		 nIn: 1,	 nOut: 	0	 in 26.8s
# 		 nIn: 1,	 nOut: 	0	 in 27.1s
# 		 nIn: 1,	 nOut: 	1	 in 27.3s
# 		 nIn: 1,	 nOut: 	0	 in 27.6s
# 		 nIn: 1,	 nOut: 	0	 in 27.9s
# 		 nIn: 1,	 nOut: 	0	 in 28.1s
# 		 nIn: 1,	 nOut: 	0	 in 28.4s
# 		 nIn: 1,	 nOut: 	0	 in 28.6s
# 		 nIn: 1,	 nOut: 	0	 in 28.8s
# 		 nIn: 1,	 nOut: 	0	 in 29.1s
# 		 nIn: 1,	 nOut: 	0	 in 29.3s
# 		 nIn: 1,	 nOut: 	0	 in 29.6s
# 		 nIn: 1,	 nOut: 	0	 in 29.9s
# 		 nIn: 1,	 nOut: 	0	 in 30.1s
# 		 nIn: 1,	 nOut: 	1	 in 30.4s
# 		 nIn: 1,	 nOut: 	0	 in 30.7s
# 		 nIn: 1,	 nOut: 	0	 in 30.9s
# 		 nIn: 1,	 nOut: 	1	 in 31.1s
# 		 nIn: 1,	 nOut: 	0	 in 31.5s
# 		 nIn: 1,	 nOut: 	0	 in 31.7s
# 		 nIn: 1,	 nOut: 	0	 in 32.0s
# 		 nIn: 1,	 nOut: 	0	 in 32.2s
# 		 nIn: 1,	 nOut: 	0	 in 32.7s
# 		 nIn: 1,	 nOut: 	1	 in 32.9s
# 		 nIn: 1,	 nOut: 	1	 in 33.1s
# 		 nIn: 1,	 nOut: 	0	 in 33.3s
# 		 nIn: 1,	 nOut: 	0	 in 33.6s
# 		 nIn: 1,	 nOut: 	0	 in 33.8s
# 		 nIn: 1,	 nOut: 	0	 in 34.1s
# 		 nIn: 1,	 nOut: 	0	 in 34.3s
# 		 nIn: 1,	 nOut: 	1	 in 34.6s
# 		 nIn: 1,	 nOut: 	0	 in 34.8s
# 		 nIn: 1,	 nOut: 	0	 in 35.0s
# 		 nIn: 1,	 nOut: 	0	 in 35.3s
# 		 nIn: 1,	 nOut: 	0	 in 35.5s
# 		 nIn: 1,	 nOut: 	0	 in 35.8s
# 		 nIn: 1,	 nOut: 	0	 in 36.0s
# 		 nIn: 1,	 nOut: 	0	 in 36.4s
# 		 nIn: 1,	 nOut: 	1	 in 36.7s
# 		 nIn: 1,	 nOut: 	0	 in 36.9s
# 		 nIn: 1,	 nOut: 	1	 in 37.2s
# 		 nIn: 1,	 nOut: 	1	 in 37.5s
# 		 nIn: 1,	 nOut: 	0	 in 37.7s
# 		 nIn: 1,	 nOut: 	0	 in 37.9s
# 		 nIn: 1,	 nOut: 	1	 in 38.2s
# 		 nIn: 1,	 nOut: 	1	 in 38.4s
# 		 nIn: 1,	 nOut: 	1	 in 38.7s
# 		 nIn: 1,	 nOut: 	0	 in 38.9s
# 		 nIn: 1,	 nOut: 	0	 in 39.2s
# 		 nIn: 1,	 nOut: 	0	 in 39.6s
# 		 nIn: 1,	 nOut: 	1	 in 39.8s
# 		 nIn: 1,	 nOut: 	0	 in 40.0s
# 		 nIn: 1,	 nOut: 	0	 in 40.3s
# 		 nIn: 1,	 nOut: 	0	 in 40.5s
# 		 nIn: 1,	 nOut: 	0	 in 40.7s
# 		 nIn: 1,	 nOut: 	1	 in 41.0s
# 		 nIn: 1,	 nOut: 	0	 in 41.2s
# 		 nIn: 1,	 nOut: 	0	 in 41.4s
# 		 nIn: 1,	 nOut: 	0	 in 41.7s
# 		 nIn: 1,	 nOut: 	0	 in 41.9s
# 		 nIn: 1,	 nOut: 	0	 in 42.2s
# 		 nIn: 1,	 nOut: 	0	 in 42.4s
# 		 nIn: 1,	 nOut: 	0	 in 42.9s
# 		 nIn: 1,	 nOut: 	0	 in 43.1s
# 		 nIn: 1,	 nOut: 	0	 in 43.3s
# 		 nIn: 1,	 nOut: 	1	 in 43.6s
# 		 nIn: 1,	 nOut: 	0	 in 43.9s
# 		 nIn: 1,	 nOut: 	0	 in 44.1s
# 		 nIn: 1,	 nOut: 	0	 in 44.3s
# 		 nIn: 1,	 nOut: 	0	 in 44.6s
# 		 nIn: 1,	 nOut: 	0	 in 44.8s
# 		 nIn: 1,	 nOut: 	0	 in 45.1s
# 		 nIn: 1,	 nOut: 	0	 in 45.3s
# 		 nIn: 1,	 nOut: 	0	 in 45.5s
# 		 nIn: 1,	 nOut: 	0	 in 45.9s
# 		 nIn: 1,	 nOut: 	0	 in 46.1s
# 		 nIn: 1,	 nOut: 	0	 in 46.4s
# 		 nIn: 1,	 nOut: 	1	 in 46.6s
# 		 nIn: 1,	 nOut: 	0	 in 46.9s
# 		 nIn: 1,	 nOut: 	0	 in 47.1s
# 		 nIn: 1,	 nOut: 	0	 in 47.3s
# 		 nIn: 1,	 nOut: 	0	 in 47.6s
# 		 nIn: 1,	 nOut: 	0	 in 47.8s
# 		 nIn: 1,	 nOut: 	1	 in 48.1s
# 		 nIn: 1,	 nOut: 	0	 in 48.3s
# 		 nIn: 1,	 nOut: 	0	 in 48.5s
# 		 nIn: 1,	 nOut: 	0	 in 48.9s
# 		 nIn: 1,	 nOut: 	0	 in 49.1s
# 		 nIn: 1,	 nOut: 	1	 in 49.4s
# 		 nIn: 1,	 nOut: 	1	 in 49.6s
# 		 nIn: 1,	 nOut: 	1	 in 49.9s
# 		 nIn: 1,	 nOut: 	0	 in 50.1s
# 		 nIn: 1,	 nOut: 	0	 in 50.5s
# 		 nIn: 1,	 nOut: 	1	 in 50.8s
# 		 nIn: 1,	 nOut: 	1	 in 51.0s
# 		 nIn: 1,	 nOut: 	0	 in 51.2s
# 		 nIn: 1,	 nOut: 	0	 in 51.5s
# 		 nIn: 1,	 nOut: 	0	 in 51.7s
# 		 nIn: 1,	 nOut: 	1	 in 52.0s
# 		 nIn: 1,	 nOut: 	0	 in 52.2s
# 		 nIn: 1,	 nOut: 	1	 in 52.5s
# 		 nIn: 1,	 nOut: 	0	 in 52.7s
# 		 nIn: 1,	 nOut: 	0	 in 52.9s
# 		 nIn: 1,	 nOut: 	0	 in 53.2s
# 		 nIn: 1,	 nOut: 	1	 in 53.4s
# 		 nIn: 1,	 nOut: 	0	 in 53.6s
# 		 nIn: 1,	 nOut: 	1	 in 53.9s
# 		 nIn: 1,	 nOut: 	1	 in 54.1s
# 		 nIn: 1,	 nOut: 	0	 in 54.3s
# 		 nIn: 1,	 nOut: 	0	 in 54.6s
# 		 nIn: 1,	 nOut: 	0	 in 54.9s
# 		 nIn: 1,	 nOut: 	1	 in 55.1s
# 		 nIn: 1,	 nOut: 	0	 in 55.5s
# 		 nIn: 1,	 nOut: 	0	 in 55.7s
# 		 nIn: 1,	 nOut: 	0	 in 56.0s
# 		 nIn: 1,	 nOut: 	0	 in 56.2s
# 		 nIn: 1,	 nOut: 	0	 in 56.4s
# 		 nIn: 1,	 nOut: 	0	 in 56.7s
# 		 nIn: 1,	 nOut: 	0	 in 56.9s
# 		 nIn: 1,	 nOut: 	0	 in 57.2s
# 		 nIn: 1,	 nOut: 	0	 in 57.4s
# 		 nIn: 1,	 nOut: 	0	 in 57.6s
# 		 nIn: 1,	 nOut: 	0	 in 57.9s
# 		 nIn: 1,	 nOut: 	1	 in 58.1s
# 		 nIn: 1,	 nOut: 	0	 in 58.3s
# 		 nIn: 1,	 nOut: 	0	 in 58.6s
# 		 nIn: 1,	 nOut: 	1	 in 58.8s
# 		 nIn: 1,	 nOut: 	0	 in 59.1s
# 		 nIn: 1,	 nOut: 	0	 in 59.4s
# 		 nIn: 1,	 nOut: 	0	 in 59.6s
# 		 nIn: 1,	 nOut: 	0	 in 59.9s
# 		 nIn: 1,	 nOut: 	1	 in 60.1s
# 		 nIn: 1,	 nOut: 	0	 in 60.4s
# 		 nIn: 1,	 nOut: 	1	 in 60.7s
# 		 nIn: 1,	 nOut: 	0	 in 61.0s
# 		 nIn: 1,	 nOut: 	0	 in 61.2s
# 		 nIn: 1,	 nOut: 	0	 in 61.4s
# 		 nIn: 1,	 nOut: 	0	 in 61.7s
# 		 nIn: 1,	 nOut: 	0	 in 61.9s
# 		 nIn: 1,	 nOut: 	0	 in 62.2s
# 		 nIn: 1,	 nOut: 	0	 in 62.4s
# 		 nIn: 1,	 nOut: 	1	 in 62.7s
# 		 nIn: 1,	 nOut: 	0	 in 63.0s
# 		 nIn: 1,	 nOut: 	0	 in 63.2s
# 		 nIn: 1,	 nOut: 	1	 in 63.5s
# 		 nIn: 1,	 nOut: 	0	 in 63.7s
# 		 nIn: 1,	 nOut: 	0	 in 64.0s
# 		 nIn: 1,	 nOut: 	0	 in 64.3s
# 		 nIn: 1,	 nOut: 	0	 in 64.5s
# 		 nIn: 1,	 nOut: 	0	 in 64.7s
# 		 nIn: 1,	 nOut: 	0	 in 65.0s
# 		 nIn: 1,	 nOut: 	1	 in 65.2s
# 		 nIn: 1,	 nOut: 	0	 in 65.4s
# 		 nIn: 1,	 nOut: 	1	 in 65.7s
# 		 nIn: 1,	 nOut: 	0	 in 65.9s
# 		 nIn: 1,	 nOut: 	0	 in 66.2s
# 		 nIn: 1,	 nOut: 	0	 in 66.4s
# 		 nIn: 1,	 nOut: 	0	 in 66.8s
# 		 nIn: 1,	 nOut: 	0	 in 67.1s
# 		 nIn: 1,	 nOut: 	0	 in 67.4s
# 		 nIn: 1,	 nOut: 	0	 in 67.6s
# 		 nIn: 1,	 nOut: 	0	 in 67.8s
# 		 nIn: 1,	 nOut: 	0	 in 68.1s
# 		 nIn: 1,	 nOut: 	1	 in 68.3s
# 		 nIn: 1,	 nOut: 	0	 in 68.6s
# 		 nIn: 1,	 nOut: 	0	 in 68.8s
# 		 nIn: 1,	 nOut: 	1	 in 69.1s
# 		 nIn: 1,	 nOut: 	1	 in 69.3s
# 		 nIn: 1,	 nOut: 	0	 in 69.6s
# 		 nIn: 1,	 nOut: 	1	 in 69.8s
# 		 nIn: 1,	 nOut: 	0	 in 70.1s
# 		 nIn: 1,	 nOut: 	0	 in 70.3s
# 		 nIn: 1,	 nOut: 	1	 in 70.6s
# 		 nIn: 1,	 nOut: 	1	 in 70.8s
# 		 nIn: 1,	 nOut: 	0	 in 71.2s
# 		 nIn: 1,	 nOut: 	0	 in 71.4s
# 		 nIn: 1,	 nOut: 	0	 in 71.6s
# 		 nIn: 1,	 nOut: 	1	 in 71.8s
# 		 nIn: 1,	 nOut: 	1	 in 72.1s
# 		 nIn: 1,	 nOut: 	1	 in 72.4s
# 		 nIn: 1,	 nOut: 	0	 in 72.6s
# 		 nIn: 1,	 nOut: 	1	 in 73.0s
# 		 nIn: 1,	 nOut: 	0	 in 73.2s
# 		 nIn: 1,	 nOut: 	0	 in 73.4s
# 		 nIn: 1,	 nOut: 	0	 in 73.6s
# 		 nIn: 1,	 nOut: 	0	 in 73.9s
# 		 nIn: 1,	 nOut: 	0	 in 74.1s
# 		 nIn: 1,	 nOut: 	0	 in 74.5s
# 		 nIn: 1,	 nOut: 	0	 in 74.7s
# 		 nIn: 1,	 nOut: 	0	 in 74.9s
# 		 nIn: 1,	 nOut: 	0	 in 75.2s
# 		 nIn: 1,	 nOut: 	0	 in 75.5s
# 		 nIn: 1,	 nOut: 	0	 in 75.7s
# 		 nIn: 1,	 nOut: 	0	 in 75.9s
# 		 nIn: 1,	 nOut: 	0	 in 76.2s
# 		 nIn: 1,	 nOut: 	1	 in 76.4s
# 		 nIn: 1,	 nOut: 	0	 in 76.6s
# 		 nIn: 1,	 nOut: 	1	 in 76.9s
# 		 nIn: 1,	 nOut: 	0	 in 77.1s
# 		 nIn: 1,	 nOut: 	0	 in 77.4s
# 		 nIn: 1,	 nOut: 	0	 in 77.6s
# 		 nIn: 1,	 nOut: 	0	 in 77.8s
# 		 nIn: 1,	 nOut: 	0	 in 78.1s
# 		 nIn: 1,	 nOut: 	0	 in 78.4s
# 		 nIn: 1,	 nOut: 	0	 in 78.6s
# 		 nIn: 1,	 nOut: 	0	 in 79.0s
# 		 nIn: 1,	 nOut: 	0	 in 79.2s
# 		 nIn: 1,	 nOut: 	0	 in 79.5s
# 		 nIn: 1,	 nOut: 	0	 in 79.7s
# 		 nIn: 1,	 nOut: 	0	 in 80.0s
# 		 nIn: 1,	 nOut: 	0	 in 80.2s
# 		 nIn: 1,	 nOut: 	0	 in 80.5s
# 		 nIn: 1,	 nOut: 	0	 in 80.7s
# 		 nIn: 1,	 nOut: 	0	 in 80.9s
# 		 nIn: 1,	 nOut: 	1	 in 81.3s
# 		 nIn: 1,	 nOut: 	0	 in 81.5s
# 		 nIn: 1,	 nOut: 	0	 in 81.8s
# 		 nIn: 1,	 nOut: 	0	 in 82.1s
# 		 nIn: 1,	 nOut: 	0	 in 82.3s
# 		 nIn: 1,	 nOut: 	1	 in 82.6s
# 		 nIn: 1,	 nOut: 	0	 in 82.8s
# 		 nIn: 1,	 nOut: 	0	 in 83.1s
# 		 nIn: 1,	 nOut: 	0	 in 83.3s
# 		 nIn: 1,	 nOut: 	1	 in 83.5s
# 		 nIn: 1,	 nOut: 	0	 in 83.8s
# 		 nIn: 1,	 nOut: 	0	 in 84.1s
# 		 nIn: 1,	 nOut: 	0	 in 84.4s
# 		 nIn: 1,	 nOut: 	0	 in 84.7s
# 		 nIn: 1,	 nOut: 	0	 in 85.0s
# 		 nIn: 1,	 nOut: 	0	 in 85.4s
# 		 nIn: 1,	 nOut: 	0	 in 85.6s
# 		 nIn: 1,	 nOut: 	1	 in 85.8s
# 		 nIn: 1,	 nOut: 	1	 in 86.0s
# 		 nIn: 1,	 nOut: 	1	 in 86.3s
# 		 nIn: 1,	 nOut: 	1	 in 86.5s
# 		 nIn: 1,	 nOut: 	0	 in 86.8s
# 		 nIn: 1,	 nOut: 	0	 in 87.0s
# 		 nIn: 1,	 nOut: 	1	 in 87.2s
# 		 nIn: 1,	 nOut: 	0	 in 87.5s
# 		 nIn: 1,	 nOut: 	0	 in 87.7s
# 		 nIn: 1,	 nOut: 	0	 in 87.9s
# 		 nIn: 1,	 nOut: 	0	 in 88.1s
# 		 nIn: 1,	 nOut: 	0	 in 88.4s
# 		 nIn: 1,	 nOut: 	0	 in 88.6s
# 		 nIn: 1,	 nOut: 	0	 in 88.8s
# 		 nIn: 1,	 nOut: 	0	 in 89.1s
# 		 nIn: 1,	 nOut: 	0	 in 89.4s
# 		 nIn: 1,	 nOut: 	1	 in 89.7s
# 		 nIn: 1,	 nOut: 	1	 in 90.0s
# 		 nIn: 1,	 nOut: 	0	 in 90.3s
# 		 nIn: 1,	 nOut: 	0	 in 90.5s
# 		 nIn: 1,	 nOut: 	0	 in 90.7s
# 		 nIn: 1,	 nOut: 	0	 in 91.0s
# 		 nIn: 1,	 nOut: 	1	 in 91.3s
# 		 nIn: 1,	 nOut: 	1	 in 91.6s
# 		 nIn: 1,	 nOut: 	1	 in 91.8s
# 		 nIn: 1,	 nOut: 	1	 in 92.1s
# 		 nIn: 1,	 nOut: 	0	 in 92.4s
# 		 nIn: 1,	 nOut: 	0	 in 92.7s
# 		 nIn: 1,	 nOut: 	0	 in 92.9s
# 		 nIn: 1,	 nOut: 	1	 in 93.2s
# 		 nIn: 1,	 nOut: 	0	 in 93.4s
# 		 nIn: 1,	 nOut: 	1	 in 93.7s
# 		 nIn: 1,	 nOut: 	1	 in 93.9s
# 		 nIn: 1,	 nOut: 	1	 in 94.2s
# 		 nIn: 1,	 nOut: 	0	 in 94.4s
# 		 nIn: 1,	 nOut: 	0	 in 94.6s
# 		 nIn: 1,	 nOut: 	0	 in 94.9s
# 		 nIn: 1,	 nOut: 	0	 in 95.1s
# 		 nIn: 1,	 nOut: 	0	 in 95.4s
# 		 nIn: 1,	 nOut: 	1	 in 95.6s
# 		 nIn: 1,	 nOut: 	0	 in 95.8s
# 		 nIn: 1,	 nOut: 	0	 in 96.0s
# 		 nIn: 1,	 nOut: 	1	 in 96.3s
# 		 nIn: 1,	 nOut: 	0	 in 96.5s
# 		 nIn: 1,	 nOut: 	0	 in 96.8s
# 		 nIn: 1,	 nOut: 	0	 in 97.2s
# 		 nIn: 1,	 nOut: 	0	 in 97.5s
# 		 nIn: 1,	 nOut: 	1	 in 97.7s
# 		 nIn: 1,	 nOut: 	0	 in 97.9s
# 		 nIn: 1,	 nOut: 	0	 in 98.3s
# 		 nIn: 1,	 nOut: 	0	 in 98.6s
# 		 nIn: 1,	 nOut: 	0	 in 98.9s
# 		 nIn: 1,	 nOut: 	1	 in 99.3s
# 		 nIn: 1,	 nOut: 	0	 in 99.6s
# 		 nIn: 1,	 nOut: 	0	 in 99.8s
# 		 nIn: 1,	 nOut: 	0	 in 100.1s
# 		 nIn: 1,	 nOut: 	0	 in 100.3s
# 		 nIn: 1,	 nOut: 	0	 in 100.6s
# 		 nIn: 1,	 nOut: 	0	 in 100.8s
# 		 nIn: 1,	 nOut: 	0	 in 101.1s
# 		 nIn: 1,	 nOut: 	0	 in 101.3s
# 		 nIn: 1,	 nOut: 	0	 in 101.7s
# 		 nIn: 1,	 nOut: 	0	 in 101.9s
# 		 nIn: 1,	 nOut: 	0	 in 102.2s
# 		 nIn: 1,	 nOut: 	1	 in 102.4s
# 		 nIn: 1,	 nOut: 	0	 in 102.7s
# 		 nIn: 1,	 nOut: 	1	 in 102.9s
# 		 nIn: 1,	 nOut: 	0	 in 103.1s
# 		 nIn: 1,	 nOut: 	0	 in 103.5s
# 		 nIn: 1,	 nOut: 	0	 in 103.8s
# 		 nIn: 1,	 nOut: 	0	 in 104.1s
# 		 nIn: 1,	 nOut: 	1	 in 104.4s
# 		 nIn: 1,	 nOut: 	0	 in 104.7s
# 		 nIn: 1,	 nOut: 	1	 in 104.9s
# 		 nIn: 1,	 nOut: 	0	 in 105.2s
# 		 nIn: 1,	 nOut: 	0	 in 105.4s
# 		 nIn: 1,	 nOut: 	0	 in 105.7s
# 		 nIn: 1,	 nOut: 	1	 in 105.9s
# 		 nIn: 1,	 nOut: 	1	 in 106.2s
# 		 nIn: 1,	 nOut: 	0	 in 106.6s
# 		 nIn: 1,	 nOut: 	0	 in 106.8s
# 		 nIn: 1,	 nOut: 	0	 in 107.1s
# 		 nIn: 1,	 nOut: 	0	 in 107.3s
# 		 nIn: 1,	 nOut: 	0	 in 107.6s
# 		 nIn: 1,	 nOut: 	1	 in 107.9s
# 		 nIn: 1,	 nOut: 	0	 in 108.1s
# 		 nIn: 1,	 nOut: 	0	 in 108.4s
# 		 nIn: 1,	 nOut: 	1	 in 108.7s
# 		 nIn: 1,	 nOut: 	0	 in 109.0s
# 		 nIn: 1,	 nOut: 	0	 in 109.2s
# 		 nIn: 1,	 nOut: 	0	 in 109.5s
# 		 nIn: 1,	 nOut: 	0	 in 109.8s
# 		 nIn: 1,	 nOut: 	0	 in 110.1s
# 		 nIn: 1,	 nOut: 	0	 in 110.3s
# 		 nIn: 1,	 nOut: 	1	 in 110.6s
# 		 nIn: 1,	 nOut: 	0	 in 110.8s
# 		 nIn: 1,	 nOut: 	0	 in 111.0s
# 		 nIn: 1,	 nOut: 	0	 in 111.2s
# 		 nIn: 1,	 nOut: 	0	 in 111.4s
# 		 nIn: 1,	 nOut: 	1	 in 111.7s
# 		 nIn: 1,	 nOut: 	1	 in 112.0s
# 		 nIn: 1,	 nOut: 	0	 in 112.2s
# 		 nIn: 1,	 nOut: 	0	 in 112.4s
# 		 nIn: 1,	 nOut: 	1	 in 112.7s
# 		 nIn: 1,	 nOut: 	1	 in 112.9s
# 		 nIn: 1,	 nOut: 	0	 in 113.3s
# 		 nIn: 1,	 nOut: 	0	 in 113.5s
# 		 nIn: 1,	 nOut: 	0	 in 113.8s
# 		 nIn: 1,	 nOut: 	1	 in 114.1s
# 		 nIn: 1,	 nOut: 	0	 in 114.3s
# 		 nIn: 1,	 nOut: 	0	 in 114.5s
# 		 nIn: 1,	 nOut: 	0	 in 114.8s
# 		 nIn: 1,	 nOut: 	0	 in 115.0s
# 		 nIn: 1,	 nOut: 	1	 in 115.3s
# 		 nIn: 1,	 nOut: 	0	 in 115.5s
# 		 nIn: 1,	 nOut: 	0	 in 115.8s
# 		 nIn: 1,	 nOut: 	0	 in 116.0s
# 		 nIn: 1,	 nOut: 	0	 in 116.4s
# 		 nIn: 1,	 nOut: 	1	 in 116.7s
# 		 nIn: 1,	 nOut: 	0	 in 117.1s
# 		 nIn: 1,	 nOut: 	0	 in 117.4s
# 		 nIn: 1,	 nOut: 	0	 in 117.7s
# 		 nIn: 1,	 nOut: 	1	 in 117.9s
# 		 nIn: 1,	 nOut: 	1	 in 118.1s
# 		 nIn: 1,	 nOut: 	1	 in 118.4s
# 		 nIn: 1,	 nOut: 	0	 in 118.6s
# 		 nIn: 1,	 nOut: 	0	 in 118.8s
# 		 nIn: 1,	 nOut: 	0	 in 119.1s
# 		 nIn: 1,	 nOut: 	1	 in 119.3s
# 		 nIn: 1,	 nOut: 	1	 in 119.7s
# 		 nIn: 1,	 nOut: 	0	 in 119.9s
# 		 nIn: 1,	 nOut: 	0	 in 120.2s
# 		 nIn: 1,	 nOut: 	0	 in 120.4s
# 		 nIn: 1,	 nOut: 	0	 in 120.7s
# 		 nIn: 1,	 nOut: 	1	 in 120.9s
# 		 nIn: 1,	 nOut: 	0	 in 121.2s
# 		 nIn: 1,	 nOut: 	0	 in 121.4s
# 		 nIn: 1,	 nOut: 	0	 in 121.7s
# 		 nIn: 1,	 nOut: 	1	 in 121.9s
# 		 nIn: 1,	 nOut: 	0	 in 122.2s
# 		 nIn: 1,	 nOut: 	0	 in 122.5s
# 		 nIn: 1,	 nOut: 	0	 in 122.8s
# 		 nIn: 1,	 nOut: 	1	 in 123.0s
# 		 nIn: 1,	 nOut: 	0	 in 123.3s
# 		 nIn: 1,	 nOut: 	0	 in 123.5s
# 		 nIn: 1,	 nOut: 	0	 in 123.8s
# 		 nIn: 1,	 nOut: 	0	 in 124.0s
# 		 nIn: 1,	 nOut: 	0	 in 124.2s
# 		 nIn: 1,	 nOut: 	0	 in 124.5s
# 		 nIn: 1,	 nOut: 	0	 in 124.8s
# 		 nIn: 1,	 nOut: 	0	 in 125.0s
# 		 nIn: 1,	 nOut: 	0	 in 125.2s
# 		 nIn: 1,	 nOut: 	1	 in 125.4s
# 		 nIn: 1,	 nOut: 	0	 in 125.7s
# 		 nIn: 1,	 nOut: 	1	 in 125.9s
# 		 nIn: 1,	 nOut: 	0	 in 126.1s
# 		 nIn: 1,	 nOut: 	0	 in 126.4s
# 		 nIn: 1,	 nOut: 	0	 in 126.7s
# 		 nIn: 1,	 nOut: 	0	 in 126.9s
# 		 nIn: 1,	 nOut: 	1	 in 127.2s
# 		 nIn: 1,	 nOut: 	0	 in 127.4s
# 		 nIn: 1,	 nOut: 	0	 in 127.7s
# 		 nIn: 1,	 nOut: 	0	 in 127.9s
# 		 nIn: 1,	 nOut: 	0	 in 128.1s
# 		 nIn: 1,	 nOut: 	0	 in 128.4s
# 		 nIn: 1,	 nOut: 	0	 in 128.7s
# 		 nIn: 1,	 nOut: 	0	 in 129.0s
# 		 nIn: 1,	 nOut: 	0	 in 129.2s
# 		 nIn: 1,	 nOut: 	0	 in 129.5s
# 		 nIn: 1,	 nOut: 	0	 in 129.7s
# 		 nIn: 1,	 nOut: 	0	 in 130.0s
# 		 nIn: 1,	 nOut: 	1	 in 130.3s
# 		 nIn: 1,	 nOut: 	1	 in 130.7s
# 		 nIn: 1,	 nOut: 	1	 in 130.9s
# 		 nIn: 1,	 nOut: 	0	 in 131.2s
# 		 nIn: 1,	 nOut: 	0	 in 131.4s
# 		 nIn: 1,	 nOut: 	1	 in 131.8s
# 		 nIn: 1,	 nOut: 	0	 in 132.0s
# 		 nIn: 1,	 nOut: 	1	 in 132.3s
# 		 nIn: 1,	 nOut: 	1	 in 132.6s
# 		 nIn: 1,	 nOut: 	0	 in 132.8s
# 		 nIn: 1,	 nOut: 	0	 in 133.1s
# 		 nIn: 1,	 nOut: 	0	 in 133.3s
# 		 nIn: 1,	 nOut: 	0	 in 133.6s
# 		 nIn: 1,	 nOut: 	0	 in 133.9s
# 		 nIn: 1,	 nOut: 	1	 in 134.2s
# 		 nIn: 1,	 nOut: 	0	 in 134.5s
# 		 nIn: 1,	 nOut: 	0	 in 134.8s
# 		 nIn: 1,	 nOut: 	0	 in 135.0s
# 		 nIn: 1,	 nOut: 	0	 in 135.3s
# 		 nIn: 1,	 nOut: 	1	 in 135.5s
# 		 nIn: 1,	 nOut: 	0	 in 135.8s
# 		 nIn: 1,	 nOut: 	1	 in 136.1s
# 		 nIn: 1,	 nOut: 	1	 in 136.3s
# 		 nIn: 1,	 nOut: 	0	 in 136.5s
# 		 nIn: 1,	 nOut: 	0	 in 136.9s
# 		 nIn: 1,	 nOut: 	1	 in 137.1s
# 		 nIn: 1,	 nOut: 	1	 in 137.4s
# 		 nIn: 1,	 nOut: 	0	 in 137.6s
# 		 nIn: 1,	 nOut: 	0	 in 137.9s
# 		 nIn: 1,	 nOut: 	0	 in 138.1s
# 		 nIn: 1,	 nOut: 	0	 in 138.4s
# 		 nIn: 1,	 nOut: 	0	 in 138.7s
# 		 nIn: 1,	 nOut: 	1	 in 139.0s
# 		 nIn: 1,	 nOut: 	0	 in 139.2s
# 		 nIn: 1,	 nOut: 	1	 in 139.5s
# 		 nIn: 1,	 nOut: 	0	 in 139.8s
# 		 nIn: 1,	 nOut: 	0	 in 140.1s
# 		 nIn: 1,	 nOut: 	0	 in 140.3s
# 		 nIn: 1,	 nOut: 	0	 in 140.7s
# 		 nIn: 1,	 nOut: 	0	 in 141.0s
# 		 nIn: 1,	 nOut: 	0	 in 141.3s
# 		 nIn: 1,	 nOut: 	1	 in 141.5s
# 		 nIn: 1,	 nOut: 	0	 in 141.8s
# 		 nIn: 1,	 nOut: 	0	 in 142.0s
# 		 nIn: 1,	 nOut: 	0	 in 142.3s
# 		 nIn: 1,	 nOut: 	0	 in 142.5s
# 		 nIn: 1,	 nOut: 	0	 in 142.8s
# 		 nIn: 1,	 nOut: 	1	 in 143.0s
# 		 nIn: 1,	 nOut: 	0	 in 143.3s
# 		 nIn: 1,	 nOut: 	0	 in 143.5s
# 		 nIn: 1,	 nOut: 	0	 in 143.8s
# 		 nIn: 1,	 nOut: 	0	 in 144.1s
# 		 nIn: 1,	 nOut: 	0	 in 144.3s
# 		 nIn: 1,	 nOut: 	1	 in 144.6s
# 		 nIn: 1,	 nOut: 	0	 in 144.9s
# 		 nIn: 1,	 nOut: 	0	 in 145.2s
# 		 nIn: 1,	 nOut: 	0	 in 145.4s
# 		 nIn: 1,	 nOut: 	1	 in 145.7s
# 		 nIn: 1,	 nOut: 	0	 in 146.0s
# 		 nIn: 1,	 nOut: 	1	 in 146.3s
# 		 nIn: 1,	 nOut: 	1	 in 146.5s
# 		 nIn: 1,	 nOut: 	1	 in 146.9s
# 		 nIn: 1,	 nOut: 	0	 in 147.1s
# 		 nIn: 1,	 nOut: 	0	 in 147.3s
# 		 nIn: 1,	 nOut: 	0	 in 147.5s
# 		 nIn: 1,	 nOut: 	1	 in 147.8s
# 		 nIn: 1,	 nOut: 	0	 in 148.1s
# 		 nIn: 1,	 nOut: 	1	 in 148.3s
# 		 nIn: 1,	 nOut: 	0	 in 148.5s
# 		 nIn: 1,	 nOut: 	1	 in 148.7s
# 		 nIn: 1,	 nOut: 	1	 in 149.0s
# 		 nIn: 1,	 nOut: 	0	 in 149.2s
# 		 nIn: 1,	 nOut: 	0	 in 149.6s
# 		 nIn: 1,	 nOut: 	0	 in 149.9s
# 		 nIn: 1,	 nOut: 	0	 in 150.1s
# 		 nIn: 1,	 nOut: 	0	 in 150.4s
# 		 nIn: 1,	 nOut: 	1	 in 150.7s
# 		 nIn: 1,	 nOut: 	0	 in 150.9s
# 		 nIn: 1,	 nOut: 	0	 in 151.2s
# 		 nIn: 1,	 nOut: 	1	 in 151.4s
# 		 nIn: 1,	 nOut: 	0	 in 151.7s
# 		 nIn: 1,	 nOut: 	0	 in 152.0s
# 		 nIn: 1,	 nOut: 	0	 in 152.2s
# 		 nIn: 1,	 nOut: 	0	 in 152.5s
# 		 nIn: 1,	 nOut: 	0	 in 152.7s
# 		 nIn: 1,	 nOut: 	0	 in 153.0s
# 		 nIn: 1,	 nOut: 	0	 in 153.4s
# 		 nIn: 1,	 nOut: 	0	 in 153.7s
# 		 nIn: 1,	 nOut: 	1	 in 154.0s
# 		 nIn: 1,	 nOut: 	0	 in 154.5s
# 		 nIn: 1,	 nOut: 	0	 in 154.9s
# 		 nIn: 1,	 nOut: 	0	 in 155.1s
# 		 nIn: 1,	 nOut: 	0	 in 155.3s
# 		 nIn: 1,	 nOut: 	1	 in 155.6s
# 		 nIn: 1,	 nOut: 	0	 in 155.8s
# 		 nIn: 1,	 nOut: 	0	 in 156.0s
# 		 nIn: 1,	 nOut: 	1	 in 156.3s
# 		 nIn: 1,	 nOut: 	1	 in 156.5s
# 		 nIn: 1,	 nOut: 	0	 in 156.8s
# 		 nIn: 1,	 nOut: 	1	 in 157.0s
# 		 nIn: 1,	 nOut: 	0	 in 157.3s
# 		 nIn: 1,	 nOut: 	0	 in 157.6s
# 		 nIn: 1,	 nOut: 	1	 in 157.8s
# 		 nIn: 1,	 nOut: 	0	 in 158.1s
# 		 nIn: 1,	 nOut: 	1	 in 158.4s
# 		 nIn: 1,	 nOut: 	1	 in 158.7s
# 		 nIn: 1,	 nOut: 	0	 in 159.1s
# 		 nIn: 1,	 nOut: 	1	 in 159.4s
# 		 nIn: 1,	 nOut: 	0	 in 159.8s
# 		 nIn: 1,	 nOut: 	1	 in 160.1s
# 		 nIn: 1,	 nOut: 	0	 in 160.4s
# 		 nIn: 1,	 nOut: 	0	 in 160.8s
# 		 nIn: 1,	 nOut: 	0	 in 161.1s
# 		 nIn: 1,	 nOut: 	0	 in 161.3s
# 		 nIn: 1,	 nOut: 	0	 in 161.6s
# 		 nIn: 1,	 nOut: 	0	 in 161.9s
# 		 nIn: 1,	 nOut: 	0	 in 162.1s
# 		 nIn: 1,	 nOut: 	0	 in 162.3s
# 		 nIn: 1,	 nOut: 	0	 in 162.6s
# 		 nIn: 1,	 nOut: 	1	 in 162.9s
# 		 nIn: 1,	 nOut: 	0	 in 163.3s
# 		 nIn: 1,	 nOut: 	0	 in 163.5s
# 		 nIn: 1,	 nOut: 	0	 in 163.8s
# 		 nIn: 1,	 nOut: 	0	 in 164.1s
# 		 nIn: 1,	 nOut: 	1	 in 164.3s
# 		 nIn: 1,	 nOut: 	0	 in 164.6s
# 		 nIn: 1,	 nOut: 	1	 in 164.9s
# 		 nIn: 1,	 nOut: 	0	 in 165.2s
# 		 nIn: 1,	 nOut: 	0	 in 165.4s
# 		 nIn: 1,	 nOut: 	0	 in 165.7s
# 		 nIn: 1,	 nOut: 	0	 in 166.0s
# 		 nIn: 1,	 nOut: 	0	 in 166.2s
# 		 nIn: 1,	 nOut: 	0	 in 166.5s
# 		 nIn: 1,	 nOut: 	0	 in 166.8s
# 		 nIn: 1,	 nOut: 	1	 in 167.1s
# 		 nIn: 1,	 nOut: 	1	 in 167.3s
# 		 nIn: 1,	 nOut: 	1	 in 167.5s
# 		 nIn: 1,	 nOut: 	0	 in 167.8s
# 		 nIn: 1,	 nOut: 	1	 in 168.0s
# 		 nIn: 1,	 nOut: 	1	 in 168.2s
# 		 nIn: 1,	 nOut: 	0	 in 168.5s
# 		 nIn: 1,	 nOut: 	0	 in 168.9s
# 		 nIn: 1,	 nOut: 	1	 in 169.2s
# 		 nIn: 1,	 nOut: 	0	 in 169.4s
# 		 nIn: 1,	 nOut: 	1	 in 169.7s
# 		 nIn: 1,	 nOut: 	0	 in 169.9s
# 		 nIn: 1,	 nOut: 	0	 in 170.2s
# 		 nIn: 1,	 nOut: 	0	 in 170.4s
# 		 nIn: 1,	 nOut: 	0	 in 170.7s
# 		 nIn: 1,	 nOut: 	0	 in 171.0s
# 		 nIn: 1,	 nOut: 	0	 in 171.2s
# 		 nIn: 1,	 nOut: 	1	 in 171.4s
# 		 nIn: 1,	 nOut: 	0	 in 171.7s
# 		 nIn: 1,	 nOut: 	0	 in 172.0s
# 		 nIn: 1,	 nOut: 	1	 in 172.3s
# 		 nIn: 1,	 nOut: 	0	 in 172.5s
# 		 nIn: 1,	 nOut: 	1	 in 173.0s
# 		 nIn: 1,	 nOut: 	0	 in 173.2s
# 		 nIn: 1,	 nOut: 	0	 in 173.4s
# 		 nIn: 1,	 nOut: 	0	 in 173.6s
# 		 nIn: 1,	 nOut: 	0	 in 173.9s
# 		 nIn: 1,	 nOut: 	0	 in 174.1s
# 		 nIn: 1,	 nOut: 	0	 in 174.4s
# 		 nIn: 1,	 nOut: 	1	 in 174.7s
# 		 nIn: 1,	 nOut: 	1	 in 175.0s
# 		 nIn: 1,	 nOut: 	0	 in 175.2s
# 		 nIn: 1,	 nOut: 	0	 in 175.4s
# 		 nIn: 1,	 nOut: 	0	 in 175.7s
# 		 nIn: 1,	 nOut: 	0	 in 176.0s
# 		 nIn: 1,	 nOut: 	0	 in 176.2s
# 		 nIn: 1,	 nOut: 	0	 in 176.5s
# 		 nIn: 1,	 nOut: 	1	 in 176.7s
# 		 nIn: 1,	 nOut: 	1	 in 177.1s
# 		 nIn: 1,	 nOut: 	1	 in 177.4s
# 		 nIn: 1,	 nOut: 	0	 in 177.6s
# 		 nIn: 1,	 nOut: 	1	 in 177.9s
# 		 nIn: 1,	 nOut: 	1	 in 178.2s
# 		 nIn: 1,	 nOut: 	0	 in 178.4s
# 		 nIn: 1,	 nOut: 	1	 in 178.6s
# 		 nIn: 1,	 nOut: 	0	 in 179.0s
# 		 nIn: 1,	 nOut: 	0	 in 179.3s
# 		 nIn: 1,	 nOut: 	1	 in 179.5s
# 		 nIn: 1,	 nOut: 	0	 in 179.8s
# 		 nIn: 1,	 nOut: 	0	 in 180.1s
# 		 nIn: 1,	 nOut: 	1	 in 180.4s
# 		 nIn: 1,	 nOut: 	0	 in 180.6s
# 		 nIn: 1,	 nOut: 	1	 in 180.9s
# 		 nIn: 1,	 nOut: 	0	 in 181.2s
# 		 nIn: 1,	 nOut: 	0	 in 181.5s
# 		 nIn: 1,	 nOut: 	0	 in 181.7s
# 		 nIn: 1,	 nOut: 	0	 in 182.0s
# 		 nIn: 1,	 nOut: 	1	 in 182.3s
# 		 nIn: 1,	 nOut: 	1	 in 182.5s
# 		 nIn: 1,	 nOut: 	0	 in 182.8s
# 		 nIn: 1,	 nOut: 	1	 in 183.1s
# 		 nIn: 1,	 nOut: 	0	 in 183.4s
# 		 nIn: 1,	 nOut: 	0	 in 183.6s
# 		 nIn: 1,	 nOut: 	0	 in 183.9s
# 		 nIn: 1,	 nOut: 	1	 in 184.2s
# 		 nIn: 1,	 nOut: 	0	 in 184.4s
# 		 nIn: 1,	 nOut: 	0	 in 184.7s
# 		 nIn: 1,	 nOut: 	0	 in 185.0s
# 		 nIn: 1,	 nOut: 	1	 in 185.2s
# 		 nIn: 1,	 nOut: 	0	 in 185.6s
# 		 nIn: 1,	 nOut: 	0	 in 185.8s
# 		 nIn: 1,	 nOut: 	1	 in 186.2s
# 		 nIn: 1,	 nOut: 	0	 in 186.5s
# 		 nIn: 1,	 nOut: 	0	 in 186.7s
# 		 nIn: 1,	 nOut: 	0	 in 187.0s
# 		 nIn: 1,	 nOut: 	0	 in 187.3s
# 		 nIn: 1,	 nOut: 	1	 in 187.5s
# 		 nIn: 1,	 nOut: 	0	 in 187.8s
# 		 nIn: 1,	 nOut: 	0	 in 188.0s
# 		 nIn: 1,	 nOut: 	0	 in 188.3s
# 		 nIn: 1,	 nOut: 	0	 in 188.5s
# 		 nIn: 1,	 nOut: 	1	 in 188.8s
# 		 nIn: 1,	 nOut: 	0	 in 189.1s
# 		 nIn: 1,	 nOut: 	0	 in 189.4s
# 		 nIn: 1,	 nOut: 	1	 in 189.7s
# 		 nIn: 1,	 nOut: 	0	 in 190.0s
# 		 nIn: 1,	 nOut: 	0	 in 190.3s
# 		 nIn: 1,	 nOut: 	0	 in 190.6s
# 		 nIn: 1,	 nOut: 	1	 in 190.9s
# 		 nIn: 1,	 nOut: 	0	 in 191.3s
# 		 nIn: 1,	 nOut: 	1	 in 191.5s
# 		 nIn: 1,	 nOut: 	0	 in 191.8s
# 		 nIn: 1,	 nOut: 	0	 in 192.2s
# 		 nIn: 1,	 nOut: 	0	 in 192.4s
# 		 nIn: 1,	 nOut: 	0	 in 192.7s
# 		 nIn: 1,	 nOut: 	0	 in 193.1s
# 		 nIn: 1,	 nOut: 	0	 in 193.4s
# 		 nIn: 1,	 nOut: 	1	 in 193.7s
# 		 nIn: 1,	 nOut: 	0	 in 193.9s
# 		 nIn: 1,	 nOut: 	0	 in 194.1s
# 		 nIn: 1,	 nOut: 	1	 in 194.3s
# 		 nIn: 1,	 nOut: 	0	 in 194.5s
# 		 nIn: 1,	 nOut: 	0	 in 194.9s
# 		 nIn: 1,	 nOut: 	0	 in 195.2s
# 		 nIn: 1,	 nOut: 	1	 in 195.5s
# 		 nIn: 1,	 nOut: 	1	 in 195.8s
# ...
# 		 nIn: 1,	 nOut: 	0	 in 256.0s
# 		 nIn: 1,	 nOut: 	0	 in 256.3s
# 		 nIn: 1,	 nOut: 	0	 in 256.5s
# 		 nIn: 1,	 nOut: 	1	 in 256.8s
# 		 nIn: 1,	 nOut: 	0	 in 257.0s
# 		 nIn: 1,	 nOut: 	1	 in 257.2s
# 		 nIn: 1,	 nOut: 	1	 in 257.4s
# 		 nIn: 1,	 nOut: 	0	 in 257.6s
# 		 nIn: 1,	 nOut: 	0	 in 257.8s
# 		 nIn: 1,	 nOut: 	0	 in 258.0s
# 		 nIn: 1,	 nOut: 	1	 in 258.3s
# 		 nIn: 1,	 nOut: 	0	 in 258.5s
# 		 nIn: 1,	 nOut: 	0	 in 258.7s
# 		 nIn: 1,	 nOut: 	1	 in 259.0s
# 		 nIn: 1,	 nOut: 	0	 in 259.3s
# 		 nIn: 1,	 nOut: 	0	 in 259.5s
# 		 nIn: 1,	 nOut: 	1	 in 259.6s
# 		 nIn: 1,	 nOut: 	1	 in 259.8s
# 		 nIn: 1,	 nOut: 	1	 in 260.1s
# 		 nIn: 1,	 nOut: 	1	 in 260.3s
# 		 nIn: 1,	 nOut: 	0	 in 260.6s
# 		 nIn: 1,	 nOut: 	1	 in 260.8s
# 		 nIn: 1,	 nOut: 	0	 in 261.1s
# 		 nIn: 1,	 nOut: 	0	 in 261.3s
# 		 nIn: 1,	 nOut: 	0	 in 261.6s
# 		 nIn: 1,	 nOut: 	0	 in 261.8s
# 		 nIn: 1,	 nOut: 	0	 in 262.1s
# 		 nIn: 1,	 nOut: 	0	 in 262.4s
# 		 nIn: 1,	 nOut: 	0	 in 262.6s
# 		 nIn: 1,	 nOut: 	1	 in 262.9s
# 		 nIn: 1,	 nOut: 	0	 in 263.1s
# 		 nIn: 1,	 nOut: 	0	 in 263.3s
# 		 nIn: 1,	 nOut: 	0	 in 263.6s
# 		 nIn: 1,	 nOut: 	0	 in 263.9s
# 		 nIn: 1,	 nOut: 	0	 in 264.1s
# 		 nIn: 1,	 nOut: 	1	 in 264.4s
# 		 nIn: 1,	 nOut: 	0	 in 264.7s
# 		 nIn: 1,	 nOut: 	0	 in 264.9s
# 		 nIn: 1,	 nOut: 	0	 in 265.2s
# 		 nIn: 1,	 nOut: 	1	 in 265.5s
# 		 nIn: 1,	 nOut: 	0	 in 265.7s
# 		 nIn: 1,	 nOut: 	0	 in 265.9s
# 		 nIn: 1,	 nOut: 	1	 in 266.1s
# 		 nIn: 1,	 nOut: 	1	 in 266.4s
# 		 nIn: 1,	 nOut: 	0	 in 266.7s
# 		 nIn: 1,	 nOut: 	1	 in 267.0s
# 		 nIn: 1,	 nOut: 	0	 in 267.3s
# 		 nIn: 1,	 nOut: 	0	 in 267.6s
# 		 nIn: 1,	 nOut: 	0	 in 268.0s
# 		 nIn: 1,	 nOut: 	0	 in 268.3s
# 		 nIn: 1,	 nOut: 	1	 in 268.6s
# 		 nIn: 1,	 nOut: 	0	 in 268.8s
# 		 nIn: 1,	 nOut: 	0	 in 269.0s
# 		 nIn: 1,	 nOut: 	1	 in 269.4s
# 		 nIn: 1,	 nOut: 	1	 in 269.7s
# 		 nIn: 1,	 nOut: 	1	 in 270.0s
# 		 nIn: 1,	 nOut: 	0	 in 270.3s
# 		 nIn: 1,	 nOut: 	0	 in 270.5s
# 		 nIn: 1,	 nOut: 	1	 in 270.8s
# 		 nIn: 1,	 nOut: 	0	 in 271.2s
# 		 nIn: 1,	 nOut: 	1	 in 271.5s
# 		 nIn: 1,	 nOut: 	1	 in 271.8s
# 		 nIn: 1,	 nOut: 	0	 in 272.1s
# 		 nIn: 1,	 nOut: 	1	 in 272.4s
# 		 nIn: 1,	 nOut: 	0	 in 272.6s
# 		 nIn: 1,	 nOut: 	0	 in 272.9s
# 		 nIn: 1,	 nOut: 	0	 in 273.2s
# 		 nIn: 1,	 nOut: 	0	 in 273.5s
# 		 nIn: 1,	 nOut: 	0	 in 273.7s
# 		 nIn: 1,	 nOut: 	0	 in 274.0s
# 		 nIn: 1,	 nOut: 	1	 in 274.3s
# 		 nIn: 1,	 nOut: 	1	 in 274.6s
# 		 nIn: 1,	 nOut: 	0	 in 274.9s
# 		 nIn: 1,	 nOut: 	0	 in 275.1s
# 		 nIn: 1,	 nOut: 	0	 in 275.4s
# 		 nIn: 1,	 nOut: 	0	 in 275.8s
# 		 nIn: 1,	 nOut: 	0	 in 276.0s
# 		 nIn: 1,	 nOut: 	1	 in 276.2s
# 		 nIn: 1,	 nOut: 	1	 in 276.6s
# 		 nIn: 1,	 nOut: 	1	 in 276.9s
# 		 nIn: 1,	 nOut: 	1	 in 277.3s
# 		 nIn: 1,	 nOut: 	0	 in 277.6s
# 		 nIn: 1,	 nOut: 	0	 in 277.9s
# 		 nIn: 1,	 nOut: 	0	 in 278.1s
# 		 nIn: 1,	 nOut: 	1	 in 278.3s
# 		 nIn: 1,	 nOut: 	1	 in 278.5s
# 		 nIn: 1,	 nOut: 	0	 in 278.8s
# 		 nIn: 1,	 nOut: 	0	 in 279.0s
# 		 nIn: 1,	 nOut: 	0	 in 279.2s
# 		 nIn: 1,	 nOut: 	1	 in 279.4s
# 		 nIn: 1,	 nOut: 	0	 in 279.6s
# 		 nIn: 1,	 nOut: 	1	 in 279.9s
# 		 nIn: 1,	 nOut: 	0	 in 280.1s
# 		 nIn: 1,	 nOut: 	1	 in 280.3s
# 		 nIn: 1,	 nOut: 	1	 in 280.5s
# 		 nIn: 1,	 nOut: 	0	 in 280.8s
# 		 nIn: 1,	 nOut: 	1	 in 281.0s
# 		 nIn: 1,	 nOut: 	0	 in 281.2s
# 		 nIn: 1,	 nOut: 	1	 in 281.4s
# 		 nIn: 1,	 nOut: 	0	 in 281.5s
# 		 nIn: 1,	 nOut: 	0	 in 281.8s
# 		 nIn: 1,	 nOut: 	1	 in 282.0s
# 		 nIn: 1,	 nOut: 	0	 in 282.3s
# 		 nIn: 1,	 nOut: 	1	 in 282.5s
# 		 nIn: 1,	 nOut: 	1	 in 282.7s
# 		 nIn: 1,	 nOut: 	1	 in 283.0s
# 		 nIn: 1,	 nOut: 	0	 in 283.2s
# 		 nIn: 1,	 nOut: 	0	 in 283.4s
# 		 nIn: 1,	 nOut: 	1	 in 283.6s
# 		 nIn: 1,	 nOut: 	1	 in 283.9s
# 		 nIn: 1,	 nOut: 	0	 in 284.1s
# 		 nIn: 1,	 nOut: 	0	 in 284.4s
# 		 nIn: 1,	 nOut: 	0	 in 284.6s
# 		 nIn: 1,	 nOut: 	0	 in 284.9s
# 		 nIn: 1,	 nOut: 	0	 in 285.1s
# 		 nIn: 1,	 nOut: 	0	 in 285.4s
# 		 nIn: 1,	 nOut: 	0	 in 285.7s
# 		 nIn: 1,	 nOut: 	1	 in 286.0s
# 		 nIn: 1,	 nOut: 	1	 in 286.2s
# 		 nIn: 1,	 nOut: 	1	 in 286.4s
# 		 nIn: 1,	 nOut: 	0	 in 286.6s
# 		 nIn: 1,	 nOut: 	1	 in 286.9s
# 		 nIn: 1,	 nOut: 	0	 in 287.1s
# 		 nIn: 1,	 nOut: 	0	 in 287.4s
# 		 nIn: 1,	 nOut: 	0	 in 287.6s
# 		 nIn: 1,	 nOut: 	0	 in 287.9s
# 		 nIn: 1,	 nOut: 	0	 in 288.2s
# 		 nIn: 1,	 nOut: 	0	 in 288.4s
# 		 nIn: 1,	 nOut: 	0	 in 288.6s
# 		 nIn: 1,	 nOut: 	1	 in 288.9s
# 		 nIn: 1,	 nOut: 	1	 in 289.1s
# 		 nIn: 1,	 nOut: 	0	 in 289.4s
# 		 nIn: 1,	 nOut: 	1	 in 289.6s
# 		 nIn: 1,	 nOut: 	0	 in 289.8s
# 		 nIn: 1,	 nOut: 	0	 in 290.0s
# 		 nIn: 1,	 nOut: 	1	 in 290.3s
# 		 nIn: 1,	 nOut: 	0	 in 290.5s
# 		 nIn: 1,	 nOut: 	0	 in 290.7s
# 		 nIn: 1,	 nOut: 	0	 in 290.9s
# 		 nIn: 1,	 nOut: 	0	 in 291.1s
# 		 nIn: 1,	 nOut: 	0	 in 291.3s
# 		 nIn: 1,	 nOut: 	1	 in 291.5s
# 		 nIn: 1,	 nOut: 	1	 in 291.8s
# 		 nIn: 1,	 nOut: 	0	 in 292.0s
# 		 nIn: 1,	 nOut: 	0	 in 292.3s
# 		 nIn: 1,	 nOut: 	0	 in 292.4s
# 		 nIn: 1,	 nOut: 	1	 in 292.6s
# 		 nIn: 1,	 nOut: 	0	 in 292.9s
# 		 nIn: 1,	 nOut: 	0	 in 293.1s
# 		 nIn: 1,	 nOut: 	0	 in 293.3s
# 		 nIn: 1,	 nOut: 	0	 in 293.5s
# 		 nIn: 1,	 nOut: 	0	 in 293.8s
# 		 nIn: 1,	 nOut: 	1	 in 294.0s
# 		 nIn: 1,	 nOut: 	0	 in 294.3s
# 		 nIn: 1,	 nOut: 	0	 in 294.5s
# 		 nIn: 1,	 nOut: 	0	 in 294.8s
# 		 nIn: 1,	 nOut: 	0	 in 295.0s
# 		 nIn: 1,	 nOut: 	0	 in 295.2s
# 		 nIn: 1,	 nOut: 	1	 in 295.4s
# 		 nIn: 1,	 nOut: 	1	 in 295.6s
# 		 nIn: 1,	 nOut: 	1	 in 295.9s
# 		 nIn: 1,	 nOut: 	0	 in 296.1s
# 		 nIn: 1,	 nOut: 	0	 in 296.4s
# 		 nIn: 1,	 nOut: 	1	 in 296.6s
# 		 nIn: 1,	 nOut: 	0	 in 296.8s
# 		 nIn: 1,	 nOut: 	0	 in 297.0s
# 		 nIn: 1,	 nOut: 	1	 in 297.3s
# 		 nIn: 1,	 nOut: 	1	 in 297.5s
# 		 nIn: 1,	 nOut: 	1	 in 297.7s
# 		 nIn: 1,	 nOut: 	1	 in 298.0s
# 		 nIn: 1,	 nOut: 	0	 in 298.2s
# 		 nIn: 1,	 nOut: 	0	 in 298.4s
# 		 nIn: 1,	 nOut: 	0	 in 298.6s
# 		 nIn: 1,	 nOut: 	0	 in 298.9s
# 		 nIn: 1,	 nOut: 	0	 in 299.2s
# 		 nIn: 1,	 nOut: 	0	 in 299.4s
# 		 nIn: 1,	 nOut: 	0	 in 299.6s
# 		 nIn: 1,	 nOut: 	0	 in 299.8s
# 		 nIn: 1,	 nOut: 	1	 in 300.1s
# 		 nIn: 1,	 nOut: 	1	 in 300.4s
# 		 nIn: 1,	 nOut: 	1	 in 300.6s
# 		 nIn: 1,	 nOut: 	0	 in 300.9s
# 		 nIn: 1,	 nOut: 	0	 in 301.2s
# 		 nIn: 1,	 nOut: 	1	 in 301.4s
# 		 nIn: 1,	 nOut: 	0	 in 301.6s
# 		 nIn: 1,	 nOut: 	0	 in 301.8s
# 		 nIn: 1,	 nOut: 	1	 in 302.0s
# 		 nIn: 1,	 nOut: 	1	 in 302.3s
# 		 nIn: 1,	 nOut: 	0	 in 302.5s
# 		 nIn: 1,	 nOut: 	0	 in 302.7s
# 		 nIn: 1,	 nOut: 	0	 in 302.9s
# 		 nIn: 1,	 nOut: 	1	 in 303.2s
# 		 nIn: 1,	 nOut: 	1	 in 303.4s
# 		 nIn: 1,	 nOut: 	0	 in 303.6s
# 		 nIn: 1,	 nOut: 	0	 in 303.8s
# 		 nIn: 1,	 nOut: 	0	 in 304.1s
# 		 nIn: 1,	 nOut: 	0	 in 304.3s
# 		 nIn: 1,	 nOut: 	0	 in 304.5s
# 		 nIn: 1,	 nOut: 	0	 in 304.7s
# 		 nIn: 1,	 nOut: 	0	 in 304.9s
# 		 nIn: 1,	 nOut: 	0	 in 305.1s
# 		 nIn: 1,	 nOut: 	0	 in 305.4s
# 		 nIn: 1,	 nOut: 	1	 in 305.6s
# 		 nIn: 1,	 nOut: 	1	 in 305.8s
# 		 nIn: 1,	 nOut: 	0	 in 305.9s
# 		 nIn: 1,	 nOut: 	1	 in 306.2s
# 		 nIn: 1,	 nOut: 	1	 in 306.4s
# 		 nIn: 1,	 nOut: 	0	 in 306.7s
# 		 nIn: 1,	 nOut: 	0	 in 306.9s
# 		 nIn: 1,	 nOut: 	1	 in 307.1s
# 		 nIn: 1,	 nOut: 	0	 in 307.3s
# 		 nIn: 1,	 nOut: 	0	 in 307.5s
# 		 nIn: 1,	 nOut: 	0	 in 307.7s
# 		 nIn: 1,	 nOut: 	0	 in 308.0s
# 		 nIn: 1,	 nOut: 	1	 in 308.2s
# 		 nIn: 1,	 nOut: 	1	 in 308.4s
# 		 nIn: 1,	 nOut: 	0	 in 308.6s
# 		 nIn: 1,	 nOut: 	0	 in 308.8s
# 		 nIn: 1,	 nOut: 	0	 in 309.0s
# 		 nIn: 1,	 nOut: 	1	 in 309.2s
# 		 nIn: 1,	 nOut: 	0	 in 309.7s
# 		 nIn: 1,	 nOut: 	0	 in 309.9s
# 		 nIn: 1,	 nOut: 	0	 in 310.1s
# 		 nIn: 1,	 nOut: 	1	 in 310.3s
# 		 nIn: 1,	 nOut: 	0	 in 310.5s
# 		 nIn: 1,	 nOut: 	0	 in 310.8s
# 		 nIn: 1,	 nOut: 	1	 in 311.0s
# 		 nIn: 1,	 nOut: 	1	 in 311.2s
# 		 nIn: 1,	 nOut: 	0	 in 311.4s
# 		 nIn: 1,	 nOut: 	0	 in 311.7s
# Processing Background $ZZ^*$ samples
# 	Processing: llll
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# Cell In[12], line 2
#       1 start = time.time() # time at start of whole processing
# ----> 2 data = get_data_from_files() # process all files
#       3 elapsed = time.time() - start # time after whole processing
#       4 print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
#
# Cell In[6], line 12, in get_data_from_files()
#      10         prefix = "MC/mc_"+str(infofile.infos[val]["DSID"])+"."
#      11     fileString = tuple_path+prefix+val+".4lep.root" # file name to open
# ---> 12     temp = read_file(fileString,val) # call the function read_file defined below
#      13     frames.append(temp) # append array returned from read_file to list of awkward arrays
#      14 data[s] = ak.concatenate(frames) # dictionary entry is concatenated awkward arrays
#
# Cell In[11], line 7, in read_file(path, sample)
#       4 data_all = [] # define empty list to hold all data for this sample
#       6 # open the tree called mini using a context manager (will automatically close files/resources)
# ----> 7 with uproot.open(path + ":mini") as tree:
#       8     numevents = tree.num_entries # number of events
#       9     if 'data' not in sample: xsec_weight = get_xsec_weight(sample) # get cross-section weight
#
# File ~\AppData\Roaming\Python\Python39\site-packages\uproot\reading.py:155, in open(path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     153     return file.root_directory
#     154 else:
# --> 155     return file.root_directory[object_path]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\uproot\reading.py:2107, in ReadOnlyDirectory.__getitem__(self, where)
#    2104     return step
#    2106 else:
# -> 2107     return self.key(where).get()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\uproot\reading.py:2496, in ReadOnlyKey.get(self)
#    2487     out = ReadOnlyDirectory(
#    2488         (*self._parent.path, self.fName),
#    2489         self.data_cursor,
#    (...)
#    2492         self,
#    2493     )
#    2495 else:
# -> 2496     chunk, cursor = self.get_uncompressed_chunk_cursor()
#    2497     start_cursor = cursor.copy()
#    2498     cls = self._file.class_named(self._fClassName)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\uproot\reading.py:2552, in ReadOnlyKey.get_uncompressed_chunk_cursor(self)
#    2548 chunk = self._file.chunk(data_start, data_stop)
#    2550 if self.is_compressed:
#    2551     # Decompression creates a new buffer; no need to copy any memmap arrays.
# -> 2552     uncompressed_chunk = uproot.compression.decompress(
#    2553         chunk,
#    2554         self.data_cursor,
#    2555         {},
#    2556         self.data_compressed_bytes,
#    2557         self.data_uncompressed_bytes,
#    2558     )
#    2560 else:
#    2561     # Don't return a memmap array; it might get accessed after the file is closed!
#    2562     chunk = chunk.detach_memmap()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\uproot\compression.py:357, in decompress(chunk, cursor, context, compressed_bytes, uncompressed_bytes, block_info)
#     343 decompress.hook_before_block(
#     344     chunk=chunk,
#     345     cursor=cursor,
#    (...)
#     351     num_blocks=num_blocks,
#     352 )
#     354 # https://github.com/root-project/root/blob/master/core/zip/src/RZip.cxx#L217
#     355 # https://github.com/root-project/root/blob/master/core/lzma/src/ZipLZMA.c#L81
#     356 # https://github.com/root-project/root/blob/master/core/lz4/src/ZipLZ4.cxx#L38
# --> 357 algo, method, c1, c2, c3, u1, u2, u3 = cursor.fields(
#     358     chunk, _decompress_header_format, context
#     359 )
#     360 block_compressed_bytes = c1 + (c2 << 8) + (c3 << 16)
#     361 block_uncompressed_bytes = u1 + (u2 << 8) + (u3 << 16)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\uproot\source\cursor.py:194, in Cursor.fields(self, chunk, format, context, move)
#     192 if move:
#     193     self._index = stop
# --> 194 return format.unpack(chunk.get(start, stop, self, context))
#
# File ~\AppData\Roaming\Python\Python39\site-packages\uproot\source\chunk.py:410, in Chunk.get(self, start, stop, cursor, context)
#     388 """
#     389 Args:
#     390     start (int): Seek position of the first byte to include.
#    (...)
#     407 already.
#     408 """
#     409 if (start, stop) in self:
# --> 410     self.wait(insist=stop)
#     411     local_start = start - self._start
#     412     local_stop = stop - self._start
#
# File ~\AppData\Roaming\Python\Python39\site-packages\uproot\source\chunk.py:354, in Chunk.wait(self, insist)
#     343 """
#     344 Args:
#     345     insist (bool or int): If True, raise an OSError if ``raw_data`` does
#    (...)
#     351 :ref:`uproot.source.chunk.Chunk.future` completes).
#     352 """
#     353 if self._raw_data is None:
# --> 354     self._raw_data = numpy.frombuffer(self._future.result(), dtype=self._dtype)
#     355     if insist is True:
#     356         requirement = len(self._raw_data) == self._stop - self._start
#
# File ~\AppData\Roaming\Python\Python39\site-packages\uproot\source\futures.py:115, in Future.result(self, timeout)
#     113     return self._result
#     114 else:
# --> 115     delayed_raise(*self._excinfo)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\uproot\source\futures.py:36, in delayed_raise(exception_class, exception_value, traceback)
#      32 def delayed_raise(exception_class, exception_value, traceback):
#      33     """
#      34     Raise an exception from a background thread on the main thread.
#      35     """
# ---> 36     raise exception_value.with_traceback(traceback)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\uproot\source\futures.py:277, in ResourceFuture._run(self, resource)
#     275 def _run(self, resource):
#     276     try:
# --> 277         self._result = self._task(resource)
#     278     except Exception:
#     279         self._excinfo = sys.exc_info()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\uproot\source\http.py:258, in HTTPResource.future.<locals>.task(resource)
#     257 def task(resource):
# --> 258     return resource.get(connection, start, stop)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\uproot\source\http.py:233, in HTTPResource.get(self, connection, start, stop)
#     226             raise OSError(
#     227                 """remote server responded with status {}, rather than 206 (range requests)
#     228 for URL {}""".format(
#     229                     response.status, self._file_path
#     230                 )
#     231             )
#     232         try:
# --> 233             return response.read()
#     234         finally:
#     235             connection.close()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\http\client.py:471, in HTTPResponse.read(self, amt)
#     469 else:
#     470     try:
# --> 471         s = self._safe_read(self.length)
#     472     except IncompleteRead:
#     473         self._close_conn()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\http\client.py:612, in HTTPResponse._safe_read(self, amt)
#     605 def _safe_read(self, amt):
#     606     """Read the number of bytes requested.
#     607
#     608     This function should be used when <amt> bytes "should" be present for
#     609     reading. If the bytes are truly not available (due to EOF), then the
#     610     IncompleteRead exception can be used to detect the problem.
#     611     """
# --> 612     data = self.fp.read(amt)
#     613     if len(data) < amt:
#     614         raise IncompleteRead(data, amt-len(data))
#
# File ~\AppData\Local\Programs\Python\Python39\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python39\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host

# %% [markdown]
# <a id='plotting'></a>

# %% [markdown]
# <a id='plotting'></a>

# %%
def plot_data(data):

    xmin = 80 * GeV
    xmax = 250 * GeV
    step_size = 5 * GeV

    bin_edges = np.arange(start=xmin, # The interval includes this value
                     stop=xmax+step_size, # The interval doesn't include this value
                     step=step_size ) # Spacing between values
    bin_centres = np.arange(start=xmin+step_size/2, # The interval includes this value
                            stop=xmax+step_size/2, # The interval doesn't include this value
                            step=step_size ) # Spacing between values

    data_x,_ = np.histogram(ak.to_numpy(data['data']['mllll']), 
                            bins=bin_edges ) # histogram the data
    data_x_errors = np.sqrt( data_x ) # statistical error on the data

    signal_x = ak.to_numpy(data[r'Signal ($m_H$ = 125 GeV)']['mllll']) # histogram the signal
    signal_weights = ak.to_numpy(data[r'Signal ($m_H$ = 125 GeV)'].totalWeight) # get the weights of the signal events
    signal_color = samples[r'Signal ($m_H$ = 125 GeV)']['color'] # get the colour for the signal bar

    mc_x = [] # define list to hold the Monte Carlo histogram entries
    mc_weights = [] # define list to hold the Monte Carlo weights
    mc_colors = [] # define list to hold the colors of the Monte Carlo bars
    mc_labels = [] # define list to hold the legend labels of the Monte Carlo bars

    for s in samples: # loop over samples
        if s not in ['data', r'Signal ($m_H$ = 125 GeV)']: # if not data nor signal
            mc_x.append( ak.to_numpy(data[s]['mllll']) ) # append to the list of Monte Carlo histogram entries
            mc_weights.append( ak.to_numpy(data[s].totalWeight) ) # append to the list of Monte Carlo weights
            mc_colors.append( samples[s]['color'] ) # append to the list of Monte Carlo bar colors
            mc_labels.append( s ) # append to the list of Monte Carlo legend labels
    


    # *************
    # Main plot 
    # *************
    main_axes = plt.gca() # get current axes
    
    # plot the data points
    main_axes.errorbar(x=bin_centres, y=data_x, yerr=data_x_errors,
                       fmt='ko', # 'k' means black and 'o' is for circles 
                       label='Data') 
    
    # plot the Monte Carlo bars
    mc_heights = main_axes.hist(mc_x, bins=bin_edges, 
                                weights=mc_weights, stacked=True, 
                                color=mc_colors, label=mc_labels )
    
    mc_x_tot = mc_heights[0][-1] # stacked background MC y-axis value
    
    # calculate MC statistical uncertainty: sqrt(sum w^2)
    mc_x_err = np.sqrt(np.histogram(np.hstack(mc_x), bins=bin_edges, weights=np.hstack(mc_weights)**2)[0])
    
    # plot the signal bar
    main_axes.hist(signal_x, bins=bin_edges, bottom=mc_x_tot, 
                   weights=signal_weights, color=signal_color,
                   label=r'Signal ($m_H$ = 125 GeV)')
    
    # plot the statistical uncertainty
    main_axes.bar(bin_centres, # x
                  2*mc_x_err, # heights
                  alpha=0.5, # half transparency
                  bottom=mc_x_tot-mc_x_err, color='none', 
                  hatch="////", width=step_size, label='Stat. Unc.' )

    # set the x-limit of the main axes
    main_axes.set_xlim( left=xmin, right=xmax ) 
    
    # separation of x axis minor ticks
    main_axes.xaxis.set_minor_locator( AutoMinorLocator() ) 
    
    # set the axis tick parameters for the main axes
    main_axes.tick_params(which='both', # ticks on both x and y axes
                          direction='in', # Put ticks inside and outside the axes
                          top=True, # draw ticks on the top axis
                          right=True ) # draw ticks on right axis
    
    # x-axis label
    main_axes.set_xlabel(r'4-lepton invariant mass $\mathrm{m_{4l}}$ [GeV]',
                        fontsize=13, x=1, horizontalalignment='right' )
    
    # write y-axis label for main axes
    main_axes.set_ylabel('Events / '+str(step_size)+' GeV',
                         y=1, horizontalalignment='right') 
    
    # set y-axis limits for main axes
    main_axes.set_ylim( bottom=0, top=np.amax(data_x)*1.6 )
    
    # add minor ticks on y-axis for main axes
    main_axes.yaxis.set_minor_locator( AutoMinorLocator() ) 

    # Add text 'ATLAS Open Data' on plot
    plt.text(0.05, # x
             0.93, # y             
             'subatomic particles rel', # text
             transform=main_axes.transAxes, # coordinate system used is that of main_axes
             fontsize=13 ) 
    
    # Add text 'for education' on plot
    plt.text(0.05, # x
             0.88, # y
             'CERN Atlas Data',
             transform=main_axes.transAxes, # coordinate system used is that of main_axes
             style='italic',
             fontsize=8 ) 
    
    # Add energy and luminosity
    lumi_used = str(lumi*fraction) # luminosity to write on the plot
    plt.text(0.05, # x
             0.82, # y
             '$\sqrt{s}$=13 TeV,$\int$L dt = '+lumi_used+' fb$^{-1}$', # text
             transform=main_axes.transAxes ) # coordinate system used is that of main_axes
    
    # Add a label for the analysis carried out
    plt.text(0.05, # x
             0.76, # y
             r'$H \rightarrow ZZ^* \rightarrow 4\ell$', # text 
             transform=main_axes.transAxes ) # coordinate system used is that of main_axes

    # draw the legend
    main_axes.legend( frameon=False ) # no box around the legend
    
    return

# %% [markdown]
# Call the function to plot the data

# %%
plot_data(data)

# %% [markdown]
# <a id='going_further'></a>
